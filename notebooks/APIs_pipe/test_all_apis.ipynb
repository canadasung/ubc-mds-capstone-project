# %% [markdown]
# # Test: `get_synonyms()` for all APIs_pipe clients
#
# Run from the **project root** so that `scripts/` is on the Python path.
#
# Covers:
# - COL, GBIF, GenBank, Index Fungorum, ITIS, MushroomObserver, Tropicos
# - FishBase
# - Symbiota portals: MyCoPortal, Lichen, Bryophyte, CCH2, SERNEC, NANSH, Macroalgae, Pterido, NE Herbaria, Mid-Atlantic, SW Biodiversity

# %%
import time
import sys, os
# Ensure the project root is on sys.path when running from notebooks.apis_pipe/
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from IPython.display import display

from scripts.apis_pipe.col import COLAPI
from scripts.apis_pipe.gbif import GBIFAPI
from scripts.apis_pipe.genbank import GenBankAPI
from scripts.apis_pipe.index_fungorum import IndexFungorumAPI
from scripts.apis_pipe.itis import ITISAPI
from scripts.apis_pipe.mushroomobs import MushroomObserverAPI
from scripts.apis_pipe.symbiota import SymbiotaAPI
from scripts.apis_pipe.tropicos import TropicosAPI
from scripts.apis_pipe.fishbase import FishBaseAPI

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)


def show(df):
    """Display a synonym DataFrame with api_link rendered as a clickable anchor."""
    if df.empty:
        display(df)
        return
    display(
        df.style.format(
            {
                "api_link": lambda url: (
                    f'<a href="{url}" target="_blank">{url}</a>'
                    if url and url not in ("U", "")
                    else url
                )
            }
        )
    )

# %% [markdown]
# ---
# ## Standard APIs

# %%
from scripts.apis_pipe.config import (
    COL_PORTAL,
    GBIF_PORTAL,
    INDEX_FUNGORUM_PORTAL,
    ITIS_PORTAL,
    MUSHROOM_OBSERVER_PORTAL,
    TROPICOS_PORTAL,
    FISHBASE_PORTAL
)

STANDARD_QUERIES = [
    # (portal, client, accepted_species, synonym_of_accepted)
    (COL_PORTAL,               COLAPI(),              "Quercus robur",    "Not species"),
    (GBIF_PORTAL,              GBIFAPI(),             "Amanita muscaria", "Not species"),
    (INDEX_FUNGORUM_PORTAL,    IndexFungorumAPI(),    "Amanita muscaria", "Not species"),
    (MUSHROOM_OBSERVER_PORTAL, MushroomObserverAPI(), "Amanita muscaria", "Not species"),
    (TROPICOS_PORTAL,          TropicosAPI(),         "Quercus robur",    "Not species"),
    (FISHBASE_PORTAL,          FishBaseAPI(),         "Gadus morhua",     "Not species"),
    (ITIS_PORTAL,              ITISAPI(),             "Quercus rubra",    "Not species"),
]

# %%
# display(GBIFAPI().get_synonyms("Agaricus muscarius"))

# %%
for portal, client, accepted, synonym in STANDARD_QUERIES:
    for species, name_type in [(accepted, "accepted"), (synonym, "synonym")]:
        print(f"\n{'='*60}")
        print(f"  {portal.display_name}  ({client.__class__.__name__})")
        print(f"  Species:   {species}")
        print(f"  Name type: {name_type}  (synonym of: {accepted})" if name_type == "synonym" else f"  Name type: {name_type}")
        print(f"{'='*60}")
        try:
            result = client.get_synonyms(species)
            print(f"Synonyms returned: {len(result)}")
            show(result)
        except Exception as e:
            print(f"ERROR: {e}")
# Out:
# ============================================================
#   COL  (COLAPI)
#   Species:   Quercus robur
#   Name type: accepted
# ============================================================
# {'offset': 0, 'limit': 10, 'total': 2, 'result': [{'id': '4R5YN', 'classification': [{'id': 'CS5HF', 'name': 'Eukaryota', 'authorship': '(Chatton, 1925) Whittaker & Margulis, 1978', 'rank': 'domain', 'status': 'accepted', 'labelHtml': 'Eukaryota (Chatton, 1925) Whittaker & Margulis, 1978'}, {'id': 'P', 'name': 'Plantae', 'rank': 'kingdom', 'status': 'accepted', 'labelHtml': 'Plantae'}, {'id': 'CMQ8S', 'name': 'Pteridobiotina', 'authorship': 'Britton & Brown', 'rank': 'subkingdom', 'status': 'accepted', 'labelHtml': 'Pteridobiotina Britton & Brown'}, {'id': 'TP', 'name': 'Tracheophyta', 'rank': 'phylum', 'status': 'accepted', 'labelHtml': 'Tracheophyta'}, {'id': 'MG', 'name': 'Magnoliopsida', 'rank': 'class', 'status': 'accepted', 'labelHtml': 'Magnoliopsida'}, {'id': '384', 'name': 'Fagales', 'authorship': 'Engl.', 'rank': 'order', 'code': 'botanical', 'status': 'accepted', 'labelHtml': 'Fagales Engl.'}, {'id': 'NPBN9', 'name': 'Fagaceae', 'authorship': 'Dumort.', 'rank': 'family', 'code': 'botanical', 'status': 'accepted', 'labelHtml': 'Fagaceae Dumort.'}, {'id': 'V58RW', 'name': 'Quercoideae', 'authorship': 'Irvine', 'rank': 'subfamily', 'code': 'botanical', 'status': 'accepted', 'labelHtml': 'Quercoideae Irvine'}, {'id': '8W2YL', 'name': 'Quercus', 'authorship': 'L.', 'rank': 'genus', 'code': 'botanical', 'status': 'accepted', 'labelHtml': '<i>Quercus</i> L.'}, {'id': '4R5YN', 'name': 'Quercus robur', 'authorship': 'L.', 'rank': 'species', 'code': 'botanical', 'status': 'accepted', 'labelHtml': '<i>Quercus robur</i> L.'}], 'usage': {'created': '2026-04-14T22:05:53.134642', 'createdBy': 102, 'modified': '2026-04-14T22:05:53.134642', 'modifiedBy': 102, 'datasetKey': 315192, 'id': '4R5YN', 'sectorKey': 66228, 'verbatimSourceKey': 320776883, 'name': {'created': '2026-04-14T22:05:53.134642', 'createdBy': 102, 'modified': '2026-04-14T22:05:53.134642', 'modifiedBy': 102, 'datasetKey': 315192, 'id': 'O3PF8o6GnVvM2OAvyXqEP1', 'sectorKey': 66228, 'verbatimSourceKey': 320776883, 'namesIndexId': 18938128, 'namesIndexType': 'exact', 'scientificName': 'Quercus robur', 'authorship': 'L.', 'rank': 'species', 'genus': 'Quercus', 'specificEpithet': 'robur', 'combinationAuthorship': {'authors': ['L.']}, 'code': 'botanical', 'publishedInId': '58d80489-b216-4ebf-b05a-22945345c325', 'origin': 'source', 'type': 'scientific', 'link': 'http://www.worldplants.de/?deeplink=Quercus-robur', 'parsed': True}, 'status': 'accepted', 'origin': 'source', 'parentId': '8W2YL', 'identifier': ['wfo:wfo-0000292858-2025-12', 'grin:sp:30739'], 'link': 'http://www.worldplants.de/?deeplink=Quercus-robur', 'referenceIds': ['58d80489-b216-4ebf-b05a-22945345c325'], 'label': 'Quercus robur L.', 'labelHtml': '<i>Quercus robur</i> L.', 'merged': False}, 'sectorDatasetKey': 1141, 'group': 'angiosperms', 'vernacularNames': [{'name': 'Chene pedoncule', 'language': 'fra'}, {'name': 'Dub Cereščatyj', 'language': 'rus'}, {'name': 'Pelarek', 'language': 'swe'}, {'name': 'dub čereščatyj', 'language': 'rus'}, {'name': 'xia li', 'language': 'zho'}, {'name': 'carvalho', 'language': 'por'}, {'name': 'carvalho-alemão', 'language': 'por'}, {'name': 'carvalho-comum', 'language': 'por'}, {'name': 'carvalho-da-europa', 'language': 'por'}, {'name': 'carvalho-europeu', 'language': 'por'}, {'name': 'carvalho-inglês', 'language': 'por'}, {'name': 'English oak', 'language': 'eng'}, {'name': 'European oak', 'language': 'eng'}, {'name': 'chêne pédonculé', 'language': 'fra'}, {'name': 'pedunculate oak', 'language': 'eng'}, {'name': 'Almindelig eg', 'language': 'dan'}, {'name': 'Stilk-eg/almindelig eg', 'language': 'dan'}, {'name': 'ek', 'language': 'swe'}, {'name': 'skogsek', 'language': 'swe'}, {'name': 'sommarek', 'language': 'swe'}, {'name': 'stjälkek', 'language': 'swe'}, {'name': 'Zomereik', 'language': 'nld'}, {'name': 'metsätammi', 'language': 'fin'}, {'name': 'sommareik', 'language': 'nno'}, {'name': 'sommereik', 'language': 'nob'}, {'name': 'Common Oak', 'language': 'eng'}, {'name': 'Derw ...
# Synonyms returned: 17
# <style type="text/css">
# </style>
# <table id="T_543d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_543d2_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_543d2_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_543d2_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_543d2_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_543d2_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_543d2_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_543d2_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_543d2_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_543d2_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_543d2_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_543d2_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_543d2_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_543d2_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_543d2_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_543d2_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_543d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_543d2_row0_col0" class="data row0 col0" >COL</td>
#       <td id="T_543d2_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_543d2_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_543d2_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_543d2_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_543d2_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_543d2_row0_col6" class="data row0 col6" >Quercus</td>
#       <td id="T_543d2_row0_col7" class="data row0 col7" >robur</td>
#       <td id="T_543d2_row0_col8" class="data row0 col8" >L.</td>
#       <td id="T_543d2_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_543d2_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_543d2_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_543d2_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_543d2_row0_col13" class="data row0 col13" ><a href="https://www.catalogueoflife.org/data/taxon/4R5YN" target="_blank">https://www.catalogueoflife.org/data/taxon/4R5YN</a></td>
#       <td id="T_543d2_row0_col14" class="data row0 col14" >4R5YN</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_543d2_row1_col0" class="data row1 col0" >COL</td>
#       <td id="T_543d2_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_543d2_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_543d2_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_543d2_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_543d2_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_543d2_row1_col6" class="data row1 col6" >Quercus</td>
#       <td id="T_543d2_row1_col7" class="data row1 col7" >atrosanguinea</td>
#       <td id="T_543d2_row1_col8" class="data row1 col8" >hort.</td>
#       <td id="T_543d2_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_543d2_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_543d2_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_543d2_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_543d2_row1_col13" class="data row1 col13" ><a href="https://www.catalogueoflife.org/data/taxon/SF5RP" target="_blank">https://www.catalogueoflife.org/data/taxon/SF5RP</a></td>
#       <td id="T_543d2_row1_col14" class="data row1 col14" >SF5RP</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_543d2_row2_col0" class="data row2 col0" >COL</td>
#       <td id="T_543d2_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_543d2_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_543d2_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_543d2_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_543d2_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_543d2_row2_col6" class="data row2 col6" >Quercus</td>
#       <td id="T_543d2_row2_col7" class="data row2 col7" >belgica</td>
#       <td id="T_543d2_row2_col8" class="data row2 col8" >Gand.</td>
#       <td id="T_543d2_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_543d2_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_543d2_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_543d2_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_543d2_row2_col13" class="data row2 col13" ><a href="https://www.catalogueoflife.org/data/taxon/8X4Z4" target="_blank">https://www.catalogueoflife.org/data/taxon/8X4Z4</a></td>
#       <td id="T_543d2_row2_col14" class="data row2 col14" >8X4Z4</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_543d2_row3_col0" class="data row3 col0" >COL</td>
#       <td id="T_543d2_row3_col1" class="data row3 col1" >U</td>
#       <td id="T_543d2_row3_col2" class="data row3 col2" >U</td>
#       <td id="T_543d2_row3_col3" class="data row3 col3" >U</td>
#       <td id="T_543d2_row3_col4" class="data row3 col4" >U</td>
#       <td id="T_543d2_row3_col5" class="data row3 col5" >U</td>
#       <td id="T_543d2_row3_col6" class="data row3 col6" >Quercus</td>
#       <td id="T_543d2_row3_col7" class="data row3 col7" >cupressoides</td>
#       <td id="T_543d2_row3_col8" class="data row3 col8" >hort.</td>
#       <td id="T_543d2_row3_col9" class="data row3 col9" >U</td>
#       <td id="T_543d2_row3_col10" class="data row3 col10" >U</td>
#       <td id="T_543d2_row3_col11" class="data row3 col11" >U</td>
#       <td id="T_543d2_row3_col12" class="data row3 col12" >U</td>
#       <td id="T_543d2_row3_col13" class="data row3 col13" ><a href="https://www.catalogueoflife.org/data/taxon/SFBKJ" target="_blank">https://www.catalogueoflife.org/data/taxon/SFBKJ</a></td>
#       <td id="T_543d2_row3_col14" class="data row3 col14" >SFBKJ</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_543d2_row4_col0" class="data row4 col0" >COL</td>
#       <td id="T_543d2_row4_col1" class="data row4 col1" >U</td>
#       <td id="T_543d2_row4_col2" class="data row4 col2" >U</td>
#       <td id="T_543d2_row4_col3" class="data row4 col3" >U</td>
#       <td id="T_543d2_row4_col4" class="data row4 col4" >U</td>
#       <td id="T_543d2_row4_col5" class="data row4 col5" >U</td>
#       <td id="T_543d2_row4_col6" class="data row4 col6" >Quercus</td>
#       <td id="T_543d2_row4_col7" class="data row4 col7" >feminea</td>
#       <td id="T_543d2_row4_col8" class="data row4 col8" >Mill.</td>
#       <td id="T_543d2_row4_col9" class="data row4 col9" >U</td>
#       <td id="T_543d2_row4_col10" class="data row4 col10" >U</td>
#       <td id="T_543d2_row4_col11" class="data row4 col11" >U</td>
#       <td id="T_543d2_row4_col12" class="data row4 col12" >U</td>
#       <td id="T_543d2_row4_col13" class="data row4 col13" ><a href="https://www.catalogueoflife.org/data/taxon/SFDVF" target="_blank">https://www.catalogueoflife.org/data/taxon/SFDVF</a></td>
#       <td id="T_543d2_row4_col14" class="data row4 col14" >SFDVF</td>
#     </tr>
#     <tr>
#       <th id="T_543d2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_543d2_row5_col0" class="data row5 col0" >COL</td>
#       <td id="T_543d2_row5_col1" class="data row5 col1" >U</td>
#       <td id="T_543d2_row5_col2" class="data row5 col2" >U</td>
#       <td id="T_543d2_row5_col3" class="data row5 col3" >U</td>
#       <td id="T_543d2_row5_col4" class="data row5 col4" >U</td>
#       <td id="T_543d2_row5_col5" class="data row5 col5" >U</td>
#       <td id="T_543d2_row5_col6" class="data row5 col6" >Quercus<
# ============================================================
#   COL  (COLAPI)
#   Species:   Not species
#   Name type: synonym  (synonym of: Quercus robur)
# ============================================================
# {'offset': 0, 'limit': 10, 'total': 0, 'empty': True, 'last': True}
# ERROR: 'result'
#
# ============================================================
#   GBIF  (GBIFAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# {'usageKey': 8168319, 'scientificName': 'Amanita muscaria (L.) Lam.', 'canonicalName': 'Amanita muscaria', 'rank': 'SPECIES', 'status': 'ACCEPTED', 'confidence': 98, 'matchType': 'EXACT', 'kingdom': 'Fungi', 'phylum': 'Basidiomycota', 'order': 'Agaricales', 'family': 'Amanitaceae', 'genus': 'Amanita', 'species': 'Amanita muscaria', 'kingdomKey': 5, 'phylumKey': 34, 'classKey': 186, 'orderKey': 1499, 'familyKey': 4171, 'genusKey': 6005964, 'speciesKey': 8168319, 'class': 'Agaricomycetes'}
# Synonyms returned: 15
# <style type="text/css">
# </style>
# <table id="T_54428">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54428_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_54428_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_54428_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_54428_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_54428_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_54428_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_54428_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_54428_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_54428_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_54428_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_54428_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_54428_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_54428_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_54428_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_54428_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54428_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54428_row0_col0" class="data row0 col0" >GBIF</td>
#       <td id="T_54428_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_54428_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_54428_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_54428_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_54428_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_54428_row0_col6" class="data row0 col6" >Amanita</td>
#       <td id="T_54428_row0_col7" class="data row0 col7" >muscaria</td>
#       <td id="T_54428_row0_col8" class="data row0 col8" ></td>
#       <td id="T_54428_row0_col9" class="data row0 col9" ></td>
#       <td id="T_54428_row0_col10" class="data row0 col10" ></td>
#       <td id="T_54428_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_54428_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_54428_row0_col13" class="data row0 col13" ><a href="https://www.gbif.org/species/8168319" target="_blank">https://www.gbif.org/species/8168319</a></td>
#       <td id="T_54428_row0_col14" class="data row0 col14" >8168319</td>
#     </tr>
#     <tr>
#       <th id="T_54428_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54428_row1_col0" class="data row1 col0" >GBIF</td>
#       <td id="T_54428_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_54428_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_54428_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_54428_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_54428_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_54428_row1_col6" class="data row1 col6" >Agaricus</td>
#       <td id="T_54428_row1_col7" class="data row1 col7" >aureolus</td>
#       <td id="T_54428_row1_col8" class="data row1 col8" >Kalchbr.</td>
#       <td id="T_54428_row1_col9" class="data row1 col9" >Icon. Sel. Hymenomyc. Hung. (Budapest) 1: 9.</td>
#       <td id="T_54428_row1_col10" class="data row1 col10" >1873</td>
#       <td id="T_54428_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_54428_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_54428_row1_col13" class="data row1 col13" ><a href="https://www.gbif.org/species/5455639" target="_blank">https://www.gbif.org/species/5455639</a></td>
#       <td id="T_54428_row1_col14" class="data row1 col14" >5455639</td>
#     </tr>
#     <tr>
#       <th id="T_54428_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54428_row2_col0" class="data row2 col0" >GBIF</td>
#       <td id="T_54428_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_54428_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_54428_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_54428_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_54428_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_54428_row2_col6" class="data row2 col6" >Agaricus</td>
#       <td id="T_54428_row2_col7" class="data row2 col7" >imperialis</td>
#       <td id="T_54428_row2_col8" class="data row2 col8" >Batsch</td>
#       <td id="T_54428_row2_col9" class="data row2 col9" >Elench. Fung. (Halle): 59.</td>
#       <td id="T_54428_row2_col10" class="data row2 col10" >1783</td>
#       <td id="T_54428_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_54428_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_54428_row2_col13" class="data row2 col13" ><a href="https://www.gbif.org/species/5955425" target="_blank">https://www.gbif.org/species/5955425</a></td>
#       <td id="T_54428_row2_col14" class="data row2 col14" >5955425</td>
#     </tr>
#     <tr>
#       <th id="T_54428_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54428_row3_col0" class="data row3 col0" >GBIF</td>
#       <td id="T_54428_row3_col1" class="data row3 col1" >U</td>
#       <td id="T_54428_row3_col2" class="data row3 col2" >U</td>
#       <td id="T_54428_row3_col3" class="data row3 col3" >U</td>
#       <td id="T_54428_row3_col4" class="data row3 col4" >U</td>
#       <td id="T_54428_row3_col5" class="data row3 col5" >U</td>
#       <td id="T_54428_row3_col6" class="data row3 col6" >Agaricus</td>
#       <td id="T_54428_row3_col7" class="data row3 col7" >muscarius</td>
#       <td id="T_54428_row3_col8" class="data row3 col8" >L.</td>
#       <td id="T_54428_row3_col9" class="data row3 col9" >Sp. Pl. 2: 1172.</td>
#       <td id="T_54428_row3_col10" class="data row3 col10" >1753</td>
#       <td id="T_54428_row3_col11" class="data row3 col11" >U</td>
#       <td id="T_54428_row3_col12" class="data row3 col12" >U</td>
#       <td id="T_54428_row3_col13" class="data row3 col13" ><a href="https://www.gbif.org/species/5451774" target="_blank">https://www.gbif.org/species/5451774</a></td>
#       <td id="T_54428_row3_col14" class="data row3 col14" >5451774</td>
#     </tr>
#     <tr>
#       <th id="T_54428_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_54428_row4_col0" class="data row4 col0" >GBIF</td>
#       <td id="T_54428_row4_col1" class="data row4 col1" >U</td>
#       <td id="T_54428_row4_col2" class="data row4 col2" >U</td>
#       <td id="T_54428_row4_col3" class="data row4 col3" >U</td>
#       <td id="T_54428_row4_col4" class="data row4 col4" >U</td>
#       <td id="T_54428_row4_col5" class="data row4 col5" >U</td>
#       <td id="T_54428_row4_col6" class="data row4 col6" >Agaricus</td>
#       <td id="T_54428_row4_col7" class="data row4 col7" >nobilis</td>
#       <td id="T_54428_row4_col8" class="data row4 col8" >Bolton</td>
#       <td id="T_54428_row4_col9" class="data row4 col9" >Hist. Fung. Halifax (Huddersfield) 2: 46, Tab. 46.</td>
#       <td id="T_54428_row4_col10" class="data row4 col10" >1788</td>
#       <td id="T_54428_row4_col11" class="data row4 col11" >U</td>
#       <td id="T_54428_row4_col12" class="data row4 col12" >U</td>
#       <td id="T_54428_row4_col13" class="data row4 col13" ><a href="https://www.gbif.org/species/3329091" target="_blank">https://www.gbif.org/species/3329091</a></td>
#       <td id="T_54428_row4_col14" class="data row4 col14" >3329091</td>
#     </tr>
#     <tr>
#       <th id="T_54428_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_54428_row5_col0" class="data row5 col0" >GBIF</td>
#       <td id="T_54428_row5_col1" class="data row5 col1" >U</td>
#       <td id="T_54428_row5_col2" class="data row5 col2" >U</td>
#       <td id="T_54428_row5_col3" class="data row5 col3" >U</td>
#       <td id="T_54428_row5_col4" class="data row5 col4" >U</td>
#       <td id="T_54428_row5_col5" class="data row5 col5" >U</td>
#       <td id="T_54428_row
# ============================================================
#   GBIF  (GBIFAPI)
#   Species:   Not species
#   Name type: synonym  (synonym of: Amanita muscaria)
# ============================================================
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   Index Fungorum  (IndexFungorumAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# <Element 'IndexFungorum' at 0x17fad9a80>
# Synonyms returned: 13
# <style type="text/css">
# </style>
# <table id="T_d5c96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5c96_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_d5c96_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_d5c96_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_d5c96_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_d5c96_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_d5c96_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_d5c96_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_d5c96_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_d5c96_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_d5c96_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_d5c96_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_d5c96_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_d5c96_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_d5c96_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_d5c96_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5c96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5c96_row0_col0" class="data row0 col0" >Index Fungorum</td>
#       <td id="T_d5c96_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_d5c96_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_d5c96_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_d5c96_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_d5c96_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_d5c96_row0_col6" class="data row0 col6" >Agaricus</td>
#       <td id="T_d5c96_row0_col7" class="data row0 col7" >aureolus</td>
#       <td id="T_d5c96_row0_col8" class="data row0 col8" >Kalchbr.</td>
#       <td id="T_d5c96_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_d5c96_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_d5c96_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_d5c96_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_d5c96_row0_col13" class="data row0 col13" ><a href="https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=298478" target="_blank">https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=298478</a></td>
#       <td id="T_d5c96_row0_col14" class="data row0 col14" >298478</td>
#     </tr>
#     <tr>
#       <th id="T_d5c96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5c96_row1_col0" class="data row1 col0" >Index Fungorum</td>
#       <td id="T_d5c96_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_d5c96_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_d5c96_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_d5c96_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_d5c96_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_d5c96_row1_col6" class="data row1 col6" >Agaricus</td>
#       <td id="T_d5c96_row1_col7" class="data row1 col7" >imperialis</td>
#       <td id="T_d5c96_row1_col8" class="data row1 col8" >Batsch</td>
#       <td id="T_d5c96_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_d5c96_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_d5c96_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_d5c96_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_d5c96_row1_col13" class="data row1 col13" ><a href="https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=495382" target="_blank">https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=495382</a></td>
#       <td id="T_d5c96_row1_col14" class="data row1 col14" >495382</td>
#     </tr>
#     <tr>
#       <th id="T_d5c96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5c96_row2_col0" class="data row2 col0" >Index Fungorum</td>
#       <td id="T_d5c96_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_d5c96_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_d5c96_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_d5c96_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_d5c96_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_d5c96_row2_col6" class="data row2 col6" >Agaricus</td>
#       <td id="T_d5c96_row2_col7" class="data row2 col7" >muscarius</td>
#       <td id="T_d5c96_row2_col8" class="data row2 col8" >L.</td>
#       <td id="T_d5c96_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_d5c96_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_d5c96_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_d5c96_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_d5c96_row2_col13" class="data row2 col13" ><a href="https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=375287" target="_blank">https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=375287</a></td>
#       <td id="T_d5c96_row2_col14" class="data row2 col14" >375287</td>
#     </tr>
#     <tr>
#       <th id="T_d5c96_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5c96_row3_col0" class="data row3 col0" >Index Fungorum</td>
#       <td id="T_d5c96_row3_col1" class="data row3 col1" >U</td>
#       <td id="T_d5c96_row3_col2" class="data row3 col2" >U</td>
#       <td id="T_d5c96_row3_col3" class="data row3 col3" >U</td>
#       <td id="T_d5c96_row3_col4" class="data row3 col4" >U</td>
#       <td id="T_d5c96_row3_col5" class="data row3 col5" >U</td>
#       <td id="T_d5c96_row3_col6" class="data row3 col6" >Agaricus</td>
#       <td id="T_d5c96_row3_col7" class="data row3 col7" >nobilis</td>
#       <td id="T_d5c96_row3_col8" class="data row3 col8" >Bolton</td>
#       <td id="T_d5c96_row3_col9" class="data row3 col9" >U</td>
#       <td id="T_d5c96_row3_col10" class="data row3 col10" >U</td>
#       <td id="T_d5c96_row3_col11" class="data row3 col11" >U</td>
#       <td id="T_d5c96_row3_col12" class="data row3 col12" >U</td>
#       <td id="T_d5c96_row3_col13" class="data row3 col13" ><a href="https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=450473" target="_blank">https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=450473</a></td>
#       <td id="T_d5c96_row3_col14" class="data row3 col14" >450473</td>
#     </tr>
#     <tr>
#       <th id="T_d5c96_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5c96_row4_col0" class="data row4 col0" >Index Fungorum</td>
#       <td id="T_d5c96_row4_col1" class="data row4 col1" >U</td>
#       <td id="T_d5c96_row4_col2" class="data row4 col2" >U</td>
#       <td id="T_d5c96_row4_col3" class="data row4 col3" >U</td>
#       <td id="T_d5c96_row4_col4" class="data row4 col4" >U</td>
#       <td id="T_d5c96_row4_col5" class="data row4 col5" >U</td>
#       <td id="T_d5c96_row4_col6" class="data row4 col6" >Agaricus</td>
#       <td id="T_d5c96_row4_col7" class="data row4 col7" >pseudoaurantiacus</td>
#       <td id="T_d5c96_row4_col8" class="data row4 col8" >Bull.</td>
#       <td id="T_d5c96_row4_col9" class="data row4 col9" >U</td>
#       <td id="T_d5c96_row4_col10" class="data row4 col10" >U</td>
#       <td id="T_d5c96_row4_col11" class="data row4 col11" >U</td>
#       <td id="T_d5c96_row4_col12" class="data row4 col12" >U</td>
#       <td id="T_d5c96_row4_col13" class="data row4 col13" ><a href="https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=494787" target="_blank">https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=494787</a></td>
#       <td id="T_d5c96_row4_col14" class="data row4 col14" >494787</td>
#     </tr>
#     <tr>
#       <th id="T_d5c96_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d5c96_row5_col0" class="data row5 col0" >Index Fungorum</td>
#       <td id="T_d5c96_row5_col1" class="data row5 col1" >U</td>
#       <td id="T_d5c96_row5_col2" class="dat
# ============================================================
#   Index Fungorum  (IndexFungorumAPI)
#   Species:   Not species
#   Name type: synonym  (synonym of: Amanita muscaria)
# ============================================================
# <Element 'empty' at 0x17f813060>
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   Mushroom Observer  (MushroomObserverAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# {'version': 2.0, 'run_date': '2026-06-10T16:51:11.479Z', 'query': 'SELECT DISTINCT `names`.* FROM `names` WHERE (`names`.`id` IN (374, 5066, 16015, 28495, 41324, 59384, 373, 31199, 59289, 109028, 110413, 111780)) AND (`names`.`correct_spelling_id` IS NULL) AND (`names`.`correct_spelling_id` IS NULL) ORDER BY `names`.`id` ASC', 'number_of_records': 7, 'number_of_pages': 1, 'page_number': 1, 'results': [{'id': 373, 'type': 'name', 'name': 'Amanita muscaria', 'author': '(L.) Lam.', 'rank': 'species', 'deprecated': False, 'misspelled': False, 'citation': '<a href="https://biodiversitylibrary.org/page/716703"><cite>Encycl. Méth. Bot.</cite> (Paris) 1: 111</a> (1783)', 'created_at': '2007-01-10T05:03:59.000Z', 'updated_at': '2025-04-02T17:58:46.000Z', 'number_of_views': 7419, 'last_viewed': '2026-05-25T18:28:25.000Z', 'ok_for_export': True, 'parents': [{'name': 'Eukarya', 'rank': 'domain'}, {'name': 'Fungi', 'rank': 'kingdom'}, {'name': 'Basidiomycota', 'rank': 'phylum'}, {'name': 'Agaricomycotina', 'rank': 'subphylum'}, {'name': 'Agaricomycetes', 'rank': 'class'}, {'name': 'Agaricomycetidae', 'rank': 'subclass'}, {'name': 'Agaricales', 'rank': 'order'}, {'name': 'Amanitineae', 'rank': 'suborder'}, {'name': 'Amanitaceae', 'rank': 'family'}], 'synonyms': [{'id': 31199, 'name': 'Amanita muscarea', 'rank': 'species', 'deprecated': True, 'misspelled': True, 'synonym_id': 9473}, {'id': 59289, 'name': 'Amanita mascaria', 'rank': 'species', 'deprecated': True, 'misspelled': True, 'synonym_id': 9473}, {'id': 109028, 'name': 'Aminata mascura', 'rank': 'species', 'deprecated': True, 'misspelled': True, 'synonym_id': 9473}, {'id': 110413, 'name': 'Aminita muscaria', 'rank': 'species', 'deprecated': True, 'misspelled': True, 'synonym_id': 9473}, {'id': 111780, 'name': 'Amanita', 'author': 'Musccaria', 'rank': 'genus', 'deprecated': True, 'misspelled': True, 'synonym_id': 9473}], 'comments': [{'id': 43620, 'summary': 'Approved', 'content': 'I understand that the botanical code says that you should use the infra-species autonym, but there is still value in have a page the species as a whole. Consequently, I am approving this name.', 'created_at': '2011-11-02T21:02:01.000Z', 'updated_at': '2011-11-02T21:02:01.000Z', 'owner': {'id': 1, 'login_name': 'nathan', 'legal_name': 'Nathan Wilson'}}]}, {'id': 374, 'type': 'name', 'name': 'Amanita muscaria var. flavivolvata', 'author': '(Singer) Dav. T. Jenkins', 'rank': 'variety', 'deprecated': True, 'misspelled': False, 'citation': 'Bibliotheca Mycologica 57: 56 (1977) [MB#487346]', 'created_at': '2007-01-10T05:03:59.000Z', 'updated_at': '2025-05-23T22:24:35.000Z', 'number_of_views': 1024, 'last_viewed': '2025-12-17T19:19:52.000Z', 'ok_for_export': True, 'parents': [{'name': 'Eukarya', 'rank': 'domain'}, {'name': 'Fungi', 'rank': 'kingdom'}, {'name': 'Basidiomycota', 'rank': 'phylum'}, {'name': 'Agaricomycotina', 'rank': 'subphylum'}, {'name': 'Agaricomycetes', 'rank': 'class'}, {'name': 'Agaricomycetidae', 'rank': 'subclass'}, {'name': 'Agaricales', 'rank': 'order'}, {'name': 'Amanitineae', 'rank': 'suborder'}, {'name': 'Amanitaceae', 'rank': 'family'}], 'synonyms': [{'id': 5066, 'name': 'Amanita muscaria subsp. flavivolvata', 'author': 'Singer', 'rank': 'subspecies', 'synonym_id': 4383}, {'id': 16015, 'name': 'Amanita amerimuscaria', 'author': 'Tulloss & Geml nom. prov.', 'rank': 'species', 'deprecated': True, 'synonym_id': 4383}, {'id': 28495, 'name': 'Amanita muscaria', 'author': 'sensu auct. amer.', 'rank': 'species', 'deprecated': True, 'synonym_id': 4383}, {'id': 41324, 'name': 'Amanita muscaria f. flavivolvata', 'author': '(Singer) Neville & Poumarat', 'rank': 'form', 'deprecated': True, 'synonym_id': 4383}, {'id': 59384, 'name': "Amanita sp. 'LG882'", 'author': 'Tulloss crypt. temp.', 'rank': 'species', 'deprecated': True, 'synonym_id': 4383}], 'comments': [{'id': 45557, 'summary': 'Deprecated', 'content': 'Technically both <a href="https://mushroomobserver.org/lookups/lookup_name/Amanita+muscaria ...
# Synonyms returned: 3
# <style type="text/css">
# </style>
# <table id="T_d16c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d16c0_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_d16c0_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_d16c0_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_d16c0_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_d16c0_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_d16c0_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_d16c0_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_d16c0_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_d16c0_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_d16c0_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_d16c0_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_d16c0_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_d16c0_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_d16c0_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_d16c0_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d16c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d16c0_row0_col0" class="data row0 col0" >Mushroom Observer</td>
#       <td id="T_d16c0_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_d16c0_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_d16c0_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_d16c0_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_d16c0_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_d16c0_row0_col6" class="data row0 col6" >Amanita</td>
#       <td id="T_d16c0_row0_col7" class="data row0 col7" >muscaria</td>
#       <td id="T_d16c0_row0_col8" class="data row0 col8" >(L.) Lam.</td>
#       <td id="T_d16c0_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_d16c0_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_d16c0_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_d16c0_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_d16c0_row0_col13" class="data row0 col13" >U</td>
#       <td id="T_d16c0_row0_col14" class="data row0 col14" >373</td>
#     </tr>
#     <tr>
#       <th id="T_d16c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d16c0_row1_col0" class="data row1 col0" >Mushroom Observer</td>
#       <td id="T_d16c0_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_d16c0_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_d16c0_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_d16c0_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_d16c0_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_d16c0_row1_col6" class="data row1 col6" >Amanita</td>
#       <td id="T_d16c0_row1_col7" class="data row1 col7" >amerimuscaria</td>
#       <td id="T_d16c0_row1_col8" class="data row1 col8" >Tulloss & Geml nom. prov.</td>
#       <td id="T_d16c0_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_d16c0_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_d16c0_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_d16c0_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_d16c0_row1_col13" class="data row1 col13" >U</td>
#       <td id="T_d16c0_row1_col14" class="data row1 col14" >16015</td>
#     </tr>
#     <tr>
#       <th id="T_d16c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d16c0_row2_col0" class="data row2 col0" >Mushroom Observer</td>
#       <td id="T_d16c0_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_d16c0_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_d16c0_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_d16c0_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_d16c0_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_d16c0_row2_col6" class="data row2 col6" >Amanita</td>
#       <td id="T_d16c0_row2_col7" class="data row2 col7" >muscaria</td>
#       <td id="T_d16c0_row2_col8" class="data row2 col8" >sensu auct. amer.</td>
#       <td id="T_d16c0_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_d16c0_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_d16c0_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_d16c0_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_d16c0_row2_col13" class="data row2 col13" >U</td>
#       <td id="T_d16c0_row2_col14" class="data row2 col14" >28495</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   Mushroom Observer  (MushroomObserverAPI)
#   Species:   Not species
#   Name type: synonym  (synonym of: Amanita muscaria)
# ============================================================
# {'version': 2.0, 'run_date': '2026-06-10T16:51:12.479Z', 'errors': [{'code': 'API2::ObjectNotFoundByString', 'details': 'Name "Not species" does not exist, or someone has deleted it.', 'fatal': 'true', 'trace': "/var/web/mo/app/classes/api2/parsers/name_parser.rb:23:in 'API2::Parsers::NameParser#try_finding_by_string'\n/var/web/mo/app/classes/api2/parsers/name_parser.rb:13:in 'API2::Parsers::NameParser#find_object'\n/var/web/mo/app/classes/api2/parsers/object_base.rb:10:in 'API2::Parsers::ObjectBase#parse'\n/var/web/mo/app/classes/api2/parsers/base.rb:25:in 'API2::Parsers::Base#parse_scalar'\n/var/web/mo/app/classes/api2/parsers/base.rb:45:in 'API2::Parsers::Base#parse_array'\n/var/web/mo/app/classes/api2/core/parameters.rb:94:in 'API2::Parameters#parse_array'\n/var/web/mo/app/classes/api2/name_api.rb:23:in 'API2::NameAPI#query_params'\n/var/web/mo/app/classes/api2/model_api.rb:39:in 'API2::ModelAPI#build_query'\n/var/web/mo/app/classes/api2/model_api.rb:11:in 'API2::ModelAPI#get'\n/var/web/mo/app/classes/api2/core/base.rb:295:in 'API2::Base#process_request'\n/var/web/mo/app/classes/api2/core/base.rb:226:in 'API2::Base::ClassMethods#execute'\n/var/web/mo/app/controllers/api2_controller.rb:155:in 'API2Controller#render_api_results'\n/var/web/mo/app/controllers/api2_controller.rb:120:in 'API2Controller#rest_query'\n/var/web/mo/app/controllers/api2_controller.rb:69:in 'API2Controller#names'\n/home/mo/.gem/ruby/3.4.9/gems/actionpack-7.2.3.1/lib/action_controller/metal/basic_implicit_render.rb:8:in 'ActionController::BasicImplicitRender#send_action'\n/home/mo/.gem/ruby/3.4.9/gems/actionpack-7.2.3.1/lib/abstract_controller/base.rb:215:in 'AbstractController::Base#process_action'\n/home/mo/.gem/ruby/3.4.9/gems/actionpack-7.2.3.1/lib/action_controller/metal/rendering.rb:193:in 'ActionController::Rendering#process_action'\n/home/mo/.gem/ruby/3.4.9/gems/actionpack-7.2.3.1/lib/abstract_controller/callbacks.rb:261:in 'block in AbstractController::Callbacks#process_action'\n/home/mo/.gem/ruby/3.4.9/gems/activesupport-7.2.3.1/lib/active_support/callbacks.rb:121:in 'block in ActiveSupport::Callbacks#run_callbacks'\n/var/web/mo/app/controllers/application_controller.rb:147:in 'ApplicationController#catch_errors_and_log_request_stats'\n/home/mo/.gem/ruby/3.4.9/gems/activesupport-7.2.3.1/lib/active_support/callbacks.rb:130:in 'block in ActiveSupport::Callbacks#run_callbacks'\n/home/mo/.gem/ruby/3.4.9/gems/turbo-rails-2.0.23/lib/turbo-rails.rb:24:in 'Turbo.with_request_id'\n/home/mo/.gem/ruby/3.4.9/gems/turbo-rails-2.0.23/app/controllers/concerns/turbo/request_id_tracking.rb:10:in 'Turbo::RequestIdTracking#turbo_tracking_request_id'\n/home/mo/.gem/ruby/3.4.9/gems/activesupport-7.2.3.1/lib/active_support/callbacks.rb:130:in 'block in ActiveSupport::Callbacks#run_callbacks'\n/home/mo/.gem/ruby/3.4.9/gems/activesupport-7.2.3.1/lib/active_support/callbacks.rb:141:in 'ActiveSupport::Callbacks#run_callbacks'\n/home/mo/.gem/ruby/3.4.9/gems/actionpack-7.2.3.1/lib/abstract_controller/callbacks.rb:260:in 'AbstractController::Callbacks#process_action'\n/home/mo/.gem/ruby/3.4.9/gems/actionpack-7.2.3.1/lib/action_controller/metal/rescue.rb:27:in 'ActionController::Rescue#process_action'\n/home/mo/.gem/ruby/3.4.9/gems/actionpack-7.2.3.1/lib/action_controller/metal/instrumentation.rb:77:in 'block in ActionController::Instrumentation#process_action'\n/home/mo/.gem/ruby/3.4.9/gems/activesupport-7.2.3.1/lib/active_support/notifications.rb:210:in 'block in ActiveSupport::Notifications.instrument'\n/home/mo/.gem/ruby/3.4.9/gems/activesupport-7.2.3.1/lib/active_support/notifications/instrumenter.rb:58:in 'ActiveSupport::Notifications::Instrumenter#instrument'\n/home/mo/.gem/ruby/3.4.9/gems/activesupport-7.2.3.1/lib/active_support/notifications.rb:210:in 'ActiveSupport::Notifications.instrument'\n/home/mo/.gem/ruby/3.4.9/gems/actionpack-7.2.3.1/lib/action_controller/metal/instrumentation.rb:76:in 'ActionController::Instrumentation#process_action'\n/home/mo/.gem/ruby/ ...
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   Tropicos  (TropicosAPI)
#   Species:   Quercus robur
#   Name type: accepted
# ============================================================
# [{'NameId': 13100004, 'ScientificName': 'Quercus robur', 'ScientificNameWithAuthors': 'Quercus robur L.', 'Family': 'Fagaceae', 'RankAbbreviation': 'sp.', 'NomenclatureStatusID': 1, 'NomenclatureStatusName': 'Legitimate', 'Symbol': '!', 'Author': 'L.', 'DisplayReference': 'Sp. Pl. 2: 996', 'DisplayDate': '1753', 'TotalRows': 2}, {'NameId': 50280607, 'ScientificName': 'Quercus robur', 'ScientificNameWithAuthors': 'Quercus robur (Ten.) A. DC.', 'Family': 'Fagaceae', 'RankAbbreviation': 'sp.', 'NomenclatureStatusName': 'No opinion', 'Author': '(Ten.) A. DC.', 'DisplayReference': 'Prodr. 16(2): 5', 'DisplayDate': '1864', 'TotalRows': 2}]
# Synonyms returned: 2
# <style type="text/css">
# </style>
# <table id="T_cc27a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc27a_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_cc27a_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_cc27a_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_cc27a_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_cc27a_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_cc27a_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_cc27a_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_cc27a_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_cc27a_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_cc27a_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_cc27a_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_cc27a_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_cc27a_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_cc27a_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_cc27a_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc27a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc27a_row0_col0" class="data row0 col0" >Tropicos</td>
#       <td id="T_cc27a_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_cc27a_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_cc27a_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_cc27a_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_cc27a_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_cc27a_row0_col6" class="data row0 col6" >Quercus</td>
#       <td id="T_cc27a_row0_col7" class="data row0 col7" >robur</td>
#       <td id="T_cc27a_row0_col8" class="data row0 col8" >L.</td>
#       <td id="T_cc27a_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_cc27a_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_cc27a_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_cc27a_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_cc27a_row0_col13" class="data row0 col13" ><a href="https://www.tropicos.org/name/13100004" target="_blank">https://www.tropicos.org/name/13100004</a></td>
#       <td id="T_cc27a_row0_col14" class="data row0 col14" >13100004</td>
#     </tr>
#     <tr>
#       <th id="T_cc27a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc27a_row1_col0" class="data row1 col0" >Tropicos</td>
#       <td id="T_cc27a_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_cc27a_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_cc27a_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_cc27a_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_cc27a_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_cc27a_row1_col6" class="data row1 col6" >Quercus</td>
#       <td id="T_cc27a_row1_col7" class="data row1 col7" >pedunculata</td>
#       <td id="T_cc27a_row1_col8" class="data row1 col8" ></td>
#       <td id="T_cc27a_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_cc27a_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_cc27a_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_cc27a_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_cc27a_row1_col13" class="data row1 col13" ><a href="https://www.tropicos.org/name/13100434" target="_blank">https://www.tropicos.org/name/13100434</a></td>
#       <td id="T_cc27a_row1_col14" class="data row1 col14" >13100434</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   Tropicos  (TropicosAPI)
#   Species:   Not species
#   Name type: synonym  (synonym of: Quercus robur)
# ============================================================
# [{'Error': 'No names were found'}]
# ERROR: TropicosAPI error: could not extract NameId from record.
#
# ============================================================
#   FishBase  (FishBaseAPI)
#   Species:   Gadus morhua
#   Name type: accepted
# ============================================================
# {'spec_code': '69', 'accepted_genus': 'Gadus', 'accepted_species': 'morhua'}
# Synonyms returned: 12
# <style type="text/css">
# </style>
# <table id="T_f8d12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8d12_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_f8d12_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_f8d12_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_f8d12_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_f8d12_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_f8d12_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_f8d12_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_f8d12_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_f8d12_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_f8d12_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_f8d12_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_f8d12_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_f8d12_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_f8d12_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_f8d12_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8d12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8d12_row0_col0" class="data row0 col0" >FishBase</td>
#       <td id="T_f8d12_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_f8d12_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_f8d12_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_f8d12_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_f8d12_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_f8d12_row0_col6" class="data row0 col6" >Gadus</td>
#       <td id="T_f8d12_row0_col7" class="data row0 col7" >morhua</td>
#       <td id="T_f8d12_row0_col8" class="data row0 col8" >Linnaeus</td>
#       <td id="T_f8d12_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_f8d12_row0_col10" class="data row0 col10" >1758</td>
#       <td id="T_f8d12_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_f8d12_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_f8d12_row0_col13" class="data row0 col13" ><a href="https://www.fishbase.se/nomenclature/69" target="_blank">https://www.fishbase.se/nomenclature/69</a></td>
#       <td id="T_f8d12_row0_col14" class="data row0 col14" >69</td>
#     </tr>
#     <tr>
#       <th id="T_f8d12_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8d12_row1_col0" class="data row1 col0" >FishBase</td>
#       <td id="T_f8d12_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_f8d12_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_f8d12_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_f8d12_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_f8d12_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_f8d12_row1_col6" class="data row1 col6" >Asellus</td>
#       <td id="T_f8d12_row1_col7" class="data row1 col7" >major</td>
#       <td id="T_f8d12_row1_col8" class="data row1 col8" >Not given</td>
#       <td id="T_f8d12_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_f8d12_row1_col10" class="data row1 col10" ></td>
#       <td id="T_f8d12_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_f8d12_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_f8d12_row1_col13" class="data row1 col13" ><a href="https://www.fishbase.se/nomenclature/69" target="_blank">https://www.fishbase.se/nomenclature/69</a></td>
#       <td id="T_f8d12_row1_col14" class="data row1 col14" >69</td>
#     </tr>
#     <tr>
#       <th id="T_f8d12_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8d12_row2_col0" class="data row2 col0" >FishBase</td>
#       <td id="T_f8d12_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_f8d12_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_f8d12_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_f8d12_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_f8d12_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_f8d12_row2_col6" class="data row2 col6" >Gadus</td>
#       <td id="T_f8d12_row2_col7" class="data row2 col7" >callarias</td>
#       <td id="T_f8d12_row2_col8" class="data row2 col8" >Linnaeus</td>
#       <td id="T_f8d12_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_f8d12_row2_col10" class="data row2 col10" >1758</td>
#       <td id="T_f8d12_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_f8d12_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_f8d12_row2_col13" class="data row2 col13" ><a href="https://www.fishbase.se/nomenclature/69" target="_blank">https://www.fishbase.se/nomenclature/69</a></td>
#       <td id="T_f8d12_row2_col14" class="data row2 col14" >69</td>
#     </tr>
#     <tr>
#       <th id="T_f8d12_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8d12_row3_col0" class="data row3 col0" >FishBase</td>
#       <td id="T_f8d12_row3_col1" class="data row3 col1" >U</td>
#       <td id="T_f8d12_row3_col2" class="data row3 col2" >U</td>
#       <td id="T_f8d12_row3_col3" class="data row3 col3" >U</td>
#       <td id="T_f8d12_row3_col4" class="data row3 col4" >U</td>
#       <td id="T_f8d12_row3_col5" class="data row3 col5" >U</td>
#       <td id="T_f8d12_row3_col6" class="data row3 col6" >Gadus</td>
#       <td id="T_f8d12_row3_col7" class="data row3 col7" >vertagus</td>
#       <td id="T_f8d12_row3_col8" class="data row3 col8" >Walbaum</td>
#       <td id="T_f8d12_row3_col9" class="data row3 col9" >U</td>
#       <td id="T_f8d12_row3_col10" class="data row3 col10" >1792</td>
#       <td id="T_f8d12_row3_col11" class="data row3 col11" >U</td>
#       <td id="T_f8d12_row3_col12" class="data row3 col12" >U</td>
#       <td id="T_f8d12_row3_col13" class="data row3 col13" ><a href="https://www.fishbase.se/nomenclature/69" target="_blank">https://www.fishbase.se/nomenclature/69</a></td>
#       <td id="T_f8d12_row3_col14" class="data row3 col14" >69</td>
#     </tr>
#     <tr>
#       <th id="T_f8d12_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8d12_row4_col0" class="data row4 col0" >FishBase</td>
#       <td id="T_f8d12_row4_col1" class="data row4 col1" >U</td>
#       <td id="T_f8d12_row4_col2" class="data row4 col2" >U</td>
#       <td id="T_f8d12_row4_col3" class="data row4 col3" >U</td>
#       <td id="T_f8d12_row4_col4" class="data row4 col4" >U</td>
#       <td id="T_f8d12_row4_col5" class="data row4 col5" >U</td>
#       <td id="T_f8d12_row4_col6" class="data row4 col6" >Gadus</td>
#       <td id="T_f8d12_row4_col7" class="data row4 col7" >heteroglossus</td>
#       <td id="T_f8d12_row4_col8" class="data row4 col8" >Walbaum</td>
#       <td id="T_f8d12_row4_col9" class="data row4 col9" >U</td>
#       <td id="T_f8d12_row4_col10" class="data row4 col10" >1792</td>
#       <td id="T_f8d12_row4_col11" class="data row4 col11" >U</td>
#       <td id="T_f8d12_row4_col12" class="data row4 col12" >U</td>
#       <td id="T_f8d12_row4_col13" class="data row4 col13" ><a href="https://www.fishbase.se/nomenclature/69" target="_blank">https://www.fishbase.se/nomenclature/69</a></td>
#       <td id="T_f8d12_row4_col14" class="data row4 col14" >69</td>
#     </tr>
#     <tr>
#       <th id="T_f8d12_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f8d12_row5_col0" class="data row5 col0" >FishBase</td>
#       <td id="T_f8d12_row5_col1" class="data row5 col1" >U</td>
#       <td id="T_f8d12_row5_col2" class="data row5 col2" >U</td>
#       <td id="T_f8d12_row5_col3" class="data row5 col3" >U</td>
#       <td id="T_f8d12_row5_col4" class="data row5 col4" >U</td>
#       <td id="T_f8d12_row5_col5" class="data row5 col5" >U</td>
#       <td id="T_f8d12_row5_col6" class="data row5 col6" >Gadus</td>
#       <td id="T_f8d12_row5_col7" class="data row5 col7"
# ============================================================
#   FishBase  (FishBaseAPI)
#   Species:   Not species
#   Name type: synonym  (synonym of: Gadus morhua)
# ============================================================
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   ITIS  (ITISAPI)
#   Species:   Quercus rubra
#   Name type: accepted
# ============================================================
# {'author': 'L.', 'class': 'gov.usgs.itis.itis_service.data.SvcItisTerm', 'commonNames': ['northern red oak'], 'nameUsage': 'accepted', 'scientificName': 'Quercus rubra', 'tsn': '19408'}
# Synonyms returned: 3
# <style type="text/css">
# </style>
# <table id="T_51e12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51e12_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_51e12_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_51e12_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_51e12_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_51e12_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_51e12_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_51e12_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_51e12_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_51e12_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_51e12_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_51e12_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_51e12_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_51e12_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_51e12_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_51e12_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51e12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51e12_row0_col0" class="data row0 col0" >ITIS</td>
#       <td id="T_51e12_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_51e12_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_51e12_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_51e12_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_51e12_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_51e12_row0_col6" class="data row0 col6" >Quercus</td>
#       <td id="T_51e12_row0_col7" class="data row0 col7" >rubra</td>
#       <td id="T_51e12_row0_col8" class="data row0 col8" >L.</td>
#       <td id="T_51e12_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_51e12_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_51e12_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_51e12_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_51e12_row0_col13" class="data row0 col13" ><a href="https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=19408" target="_blank">https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=19408</a></td>
#       <td id="T_51e12_row0_col14" class="data row0 col14" >19408</td>
#     </tr>
#     <tr>
#       <th id="T_51e12_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51e12_row1_col0" class="data row1 col0" >ITIS</td>
#       <td id="T_51e12_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_51e12_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_51e12_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_51e12_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_51e12_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_51e12_row1_col6" class="data row1 col6" >Quercus</td>
#       <td id="T_51e12_row1_col7" class="data row1 col7" >borealis</td>
#       <td id="T_51e12_row1_col8" class="data row1 col8" >F. Michx.</td>
#       <td id="T_51e12_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_51e12_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_51e12_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_51e12_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_51e12_row1_col13" class="data row1 col13" ><a href="https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=19303" target="_blank">https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=19303</a></td>
#       <td id="T_51e12_row1_col14" class="data row1 col14" >19303</td>
#     </tr>
#     <tr>
#       <th id="T_51e12_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51e12_row2_col0" class="data row2 col0" >ITIS</td>
#       <td id="T_51e12_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_51e12_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_51e12_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_51e12_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_51e12_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_51e12_row2_col6" class="data row2 col6" >Quercus</td>
#       <td id="T_51e12_row2_col7" class="data row2 col7" >maxima</td>
#       <td id="T_51e12_row2_col8" class="data row2 col8" >(Marshall) Ashe</td>
#       <td id="T_51e12_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_51e12_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_51e12_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_51e12_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_51e12_row2_col13" class="data row2 col13" ><a href="https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=195132" target="_blank">https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=195132</a></td>
#       <td id="T_51e12_row2_col14" class="data row2 col14" >195132</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   ITIS  (ITISAPI)
#   Species:   Not species
#   Name type: synonym  (synonym of: Quercus rubra)
# ============================================================
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []

# %%
from scripts.apis_pipe.config import GENBANK_PORTAL

# GenBank is run separately because NCBI rate-limits unauthenticated callers
# to 3 req/s. Each get_synonyms() makes 2 requests (esearch + efetch), so we
# sleep 1s between calls to stay well under the limit.
GENBANK_QUERIES = [
    ("Amanita muscaria",   "accepted"),
    ("Not species", "synonym"),
]
genbank_client = GenBankAPI()
for species, name_type in GENBANK_QUERIES:
    print(f"\n{'='*60}")
    print(f"  {GENBANK_PORTAL.display_name}  (GenBankAPI)")
    print(f"  Species:   {species}")
    print(f"  Name type: {name_type}")
    print(f"{'='*60}")
    try:
        result = genbank_client.get_synonyms(species)
        print(f"Synonyms returned: {len(result)}")
        show(result)
    except Exception as e:
        print(f"ERROR: {e}")
    time.sleep(1.0)  # NCBI rate limit: max 3 req/s; each call makes 2 requests
# Out:
# ============================================================
#   GenBank  (GenBankAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# {'header': {'type': 'esearch', 'version': '0.3'}, 'esearchresult': {'count': '1', 'retmax': '1', 'retstart': '0', 'idlist': ['41956'], 'translationset': [], 'translationstack': [{'term': 'Amanita muscaria[Scientific Name]', 'field': 'Scientific Name', 'count': '1', 'explode': 'N'}, 'GROUP'], 'querytranslation': 'Amanita muscaria[Scientific Name]'}}
# Synonyms returned: 2
# <style type="text/css">
# </style>
# <table id="T_0960c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0960c_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_0960c_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_0960c_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_0960c_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_0960c_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_0960c_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_0960c_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_0960c_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_0960c_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_0960c_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_0960c_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_0960c_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_0960c_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_0960c_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_0960c_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0960c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0960c_row0_col0" class="data row0 col0" >GenBank</td>
#       <td id="T_0960c_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_0960c_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_0960c_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_0960c_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_0960c_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_0960c_row0_col6" class="data row0 col6" >Amanita</td>
#       <td id="T_0960c_row0_col7" class="data row0 col7" >muscaria</td>
#       <td id="T_0960c_row0_col8" class="data row0 col8" >U</td>
#       <td id="T_0960c_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_0960c_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_0960c_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_0960c_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_0960c_row0_col13" class="data row0 col13" ><a href="https://www.ncbi.nlm.nih.gov/taxonomy/41956" target="_blank">https://www.ncbi.nlm.nih.gov/taxonomy/41956</a></td>
#       <td id="T_0960c_row0_col14" class="data row0 col14" >41956</td>
#     </tr>
#     <tr>
#       <th id="T_0960c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0960c_row1_col0" class="data row1 col0" >GenBank</td>
#       <td id="T_0960c_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_0960c_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_0960c_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_0960c_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_0960c_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_0960c_row1_col6" class="data row1 col6" >Agaricus</td>
#       <td id="T_0960c_row1_col7" class="data row1 col7" >muscarius</td>
#       <td id="T_0960c_row1_col8" class="data row1 col8" >U</td>
#       <td id="T_0960c_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_0960c_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_0960c_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_0960c_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_0960c_row1_col13" class="data row1 col13" ><a href="https://www.ncbi.nlm.nih.gov/taxonomy/41956" target="_blank">https://www.ncbi.nlm.nih.gov/taxonomy/41956</a></td>
#       <td id="T_0960c_row1_col14" class="data row1 col14" >41956</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   GenBank  (GenBankAPI)
#   Species:   Not species
#   Name type: synonym
# ============================================================
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []

# %% [markdown]
# ---
# ## Symbiota Portals

# %%
from scripts.apis_pipe.config import SYMBIOTA_PORTAL_BY_NAME

_SYMBIOTA_QUERIES = [
    # (portal, accepted_species, synonym_of_accepted)
    (SYMBIOTA_PORTAL_BY_NAME["MyCoPortal"],                    "Agaricus campestris",     "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["Lichen Portal"],                 "Xanthoria parietina",     "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["Bryophyte Portal"],              "Pohlia nutans",           "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["CCH2"],                          "Heteromeles arbutifolia", "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["SERNEC"],                        "Magnolia grandiflora",    "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["NANSH"],                         "Rudbeckia hirta",         "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["Algae Herbarium Portal"],        "Ulva intestinalis",       "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["Pterido Portal"],                "Dryopteris filix-mas",    "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["CNH"],                           "Impatiens capensis",      "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["Mid-Atlantic Herbaria Consortium"], "Quercus rubra",         "Not species"),
    (SYMBIOTA_PORTAL_BY_NAME["swbiodiversity"],                "Larrea tridentata",       "Not species"),
]

# %%
for portal, accepted, synonym in _SYMBIOTA_QUERIES:
    for species, name_type in [(accepted, "accepted"), (synonym, "synonym")]:
        print(f"\n{'='*60}")
        print(f"  symbiota / {portal.display_name}")
        print(f"  URL:       {portal.base_url}")
        print(f"  Species:   {species}")
        print(f"  Name type: {name_type}  (synonym of: {accepted})" if name_type == "synonym" else f"  Name type: {name_type}")
        print(f"{'='*60}")
        try:
            client = SymbiotaAPI(portal.display_name)
            result = client.get_synonyms(species)
            print(f"Synonyms returned: {len(result)}")
            show(result)
        except Exception as e:
            print(f"ERROR: {e}")
# Out:
# ============================================================
#   symbiota / MyCoPortal
#   URL:       https://mycoportal.org/portal
#   Species:   Agaricus campestris
#   Name type: accepted
# ============================================================
# [MyCoPortal] 'api/v2/taxonomy/search' returned results for 'Agaricus campestris'.
# {'tid': 214862, 'kingdomName': 'Fungi', 'rankID': 220, 'rankName': None, 'unitInd1': None, 'unitName1': 'Agaricus', 'unitInd2': None, 'unitName2': 'campestris', 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': 'L.', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': None, 'notes': None, 'securityStatus': 0, 'modifiedTimestamp': None, 'initialTimestamp': '2011-11-18 23:38:57', 'scientificName': 'Agaricus campestris'}
# Synonyms returned: 2
# <style type="text/css">
# </style>
# <table id="T_76277">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76277_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_76277_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_76277_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_76277_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_76277_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_76277_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_76277_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_76277_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_76277_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_76277_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_76277_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_76277_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_76277_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_76277_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_76277_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76277_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76277_row0_col0" class="data row0 col0" >MyCoPortal</td>
#       <td id="T_76277_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_76277_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_76277_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_76277_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_76277_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_76277_row0_col6" class="data row0 col6" >Agaricus</td>
#       <td id="T_76277_row0_col7" class="data row0 col7" >campestris</td>
#       <td id="T_76277_row0_col8" class="data row0 col8" >L.</td>
#       <td id="T_76277_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_76277_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_76277_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_76277_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_76277_row0_col13" class="data row0 col13" ><a href="https://mycoportal.org/portal/taxa/index.php?tid=214862" target="_blank">https://mycoportal.org/portal/taxa/index.php?tid=214862</a></td>
#       <td id="T_76277_row0_col14" class="data row0 col14" >214862</td>
#     </tr>
#     <tr>
#       <th id="T_76277_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76277_row1_col0" class="data row1 col0" >MyCoPortal</td>
#       <td id="T_76277_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_76277_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_76277_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_76277_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_76277_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_76277_row1_col6" class="data row1 col6" >Psalliota</td>
#       <td id="T_76277_row1_col7" class="data row1 col7" >villatica</td>
#       <td id="T_76277_row1_col8" class="data row1 col8" >(Brond.) Bres.]</td>
#       <td id="T_76277_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_76277_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_76277_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_76277_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_76277_row1_col13" class="data row1 col13" ><a href="https://mycoportal.org/portal/taxa/index.php?taxon=214862" target="_blank">https://mycoportal.org/portal/taxa/index.php?taxon=214862</a></td>
#       <td id="T_76277_row1_col14" class="data row1 col14" >214862</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   symbiota / MyCoPortal
#   URL:       https://mycoportal.org/portal
#   Species:   Not species
#   Name type: synonym  (synonym of: Agaricus campestris)
# ============================================================
# [MyCoPortal] 'api/v2/taxonomy/search' returned no results for 'Not species'.
# [MyCoPortal] 'api/v2/taxonomy' returned results for 'Not species'.
# {'tid': 1, 'kingdomName': 'Algae', 'rankID': 10, 'rankName': None, 'unitInd1': None, 'unitName1': 'Algae', 'unitInd2': None, 'unitName2': None, 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': '', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': 'Index Fungorum', 'notes': None, 'securityStatus': 0, 'modifiedTimestamp': None, 'initialTimestamp': '2011-11-15 19:32:56', 'scientificName': 'Algae'}
# ERROR: Expected at least two tokens in scientific name, got 'Algae'
#
# ============================================================
#   symbiota / Lichen Portal
#   URL:       https://lichenportal.org/portal
#   Species:   Xanthoria parietina
#   Name type: accepted
# ============================================================
# [Lichen Portal] 'api/v2/taxonomy/search' returned no results for 'Xanthoria parietina'.
# [Lichen Portal] 'api/v2/taxonomy' returned results for 'Xanthoria parietina'.
# {'tid': 56389, 'kingdomName': 'Fungi', 'rankID': 220, 'rankName': None, 'unitInd1': None, 'unitName1': 'Xanthoria', 'unitInd2': None, 'unitName2': 'parietina', 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': '(L.) Th. Fr.', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': 'USDA PLANTS DB', 'sourceIdentifier': None, 'notes': None, 'securityStatus': 0, 'modifiedTimestamp': None, 'initialTimestamp': '2008-09-29 12:52:57', 'scientificName': 'Xanthoria parietina'}
# Synonyms returned: 15
# <style type="text/css">
# </style>
# <table id="T_30dea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30dea_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_30dea_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_30dea_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_30dea_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_30dea_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_30dea_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_30dea_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_30dea_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_30dea_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_30dea_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_30dea_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_30dea_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_30dea_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_30dea_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_30dea_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30dea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30dea_row0_col0" class="data row0 col0" >Lichen Portal</td>
#       <td id="T_30dea_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_30dea_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_30dea_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_30dea_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_30dea_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_30dea_row0_col6" class="data row0 col6" >Xanthoria</td>
#       <td id="T_30dea_row0_col7" class="data row0 col7" >parietina</td>
#       <td id="T_30dea_row0_col8" class="data row0 col8" >(L.) Th. Fr.</td>
#       <td id="T_30dea_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_30dea_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_30dea_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_30dea_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_30dea_row0_col13" class="data row0 col13" ><a href="https://lichenportal.org/portal/taxa/index.php?tid=56389" target="_blank">https://lichenportal.org/portal/taxa/index.php?tid=56389</a></td>
#       <td id="T_30dea_row0_col14" class="data row0 col14" >56389</td>
#     </tr>
#     <tr>
#       <th id="T_30dea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30dea_row1_col0" class="data row1 col0" >Lichen Portal</td>
#       <td id="T_30dea_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_30dea_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_30dea_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_30dea_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_30dea_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_30dea_row1_col6" class="data row1 col6" >Blasteniospora</td>
#       <td id="T_30dea_row1_col7" class="data row1 col7" >parietina</td>
#       <td id="T_30dea_row1_col8" class="data row1 col8" >(L.) Trevis.</td>
#       <td id="T_30dea_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_30dea_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_30dea_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_30dea_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_30dea_row1_col13" class="data row1 col13" ><a href="https://lichenportal.org/portal/taxa/index.php?taxon=56389" target="_blank">https://lichenportal.org/portal/taxa/index.php?taxon=56389</a></td>
#       <td id="T_30dea_row1_col14" class="data row1 col14" >56389</td>
#     </tr>
#     <tr>
#       <th id="T_30dea_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_30dea_row2_col0" class="data row2 col0" >Lichen Portal</td>
#       <td id="T_30dea_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_30dea_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_30dea_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_30dea_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_30dea_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_30dea_row2_col6" class="data row2 col6" >Geissodea</td>
#       <td id="T_30dea_row2_col7" class="data row2 col7" >parietina</td>
#       <td id="T_30dea_row2_col8" class="data row2 col8" >(L.) J. St.-Hill.</td>
#       <td id="T_30dea_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_30dea_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_30dea_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_30dea_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_30dea_row2_col13" class="data row2 col13" ><a href="https://lichenportal.org/portal/taxa/index.php?taxon=56389" target="_blank">https://lichenportal.org/portal/taxa/index.php?taxon=56389</a></td>
#       <td id="T_30dea_row2_col14" class="data row2 col14" >56389</td>
#     </tr>
#     <tr>
#       <th id="T_30dea_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_30dea_row3_col0" class="data row3 col0" >Lichen Portal</td>
#       <td id="T_30dea_row3_col1" class="data row3 col1" >U</td>
#       <td id="T_30dea_row3_col2" class="data row3 col2" >U</td>
#       <td id="T_30dea_row3_col3" class="data row3 col3" >U</td>
#       <td id="T_30dea_row3_col4" class="data row3 col4" >U</td>
#       <td id="T_30dea_row3_col5" class="data row3 col5" >U</td>
#       <td id="T_30dea_row3_col6" class="data row3 col6" >Imbricaria</td>
#       <td id="T_30dea_row3_col7" class="data row3 col7" >parietina</td>
#       <td id="T_30dea_row3_col8" class="data row3 col8" >(L.) DC.</td>
#       <td id="T_30dea_row3_col9" class="data row3 col9" >U</td>
#       <td id="T_30dea_row3_col10" class="data row3 col10" >U</td>
#       <td id="T_30dea_row3_col11" class="data row3 col11" >U</td>
#       <td id="T_30dea_row3_col12" class="data row3 col12" >U</td>
#       <td id="T_30dea_row3_col13" class="data row3 col13" ><a href="https://lichenportal.org/portal/taxa/index.php?taxon=56389" target="_blank">https://lichenportal.org/portal/taxa/index.php?taxon=56389</a></td>
#       <td id="T_30dea_row3_col14" class="data row3 col14" >56389</td>
#     </tr>
#     <tr>
#       <th id="T_30dea_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_30dea_row4_col0" class="data row4 col0" >Lichen Portal</td>
#       <td id="T_30dea_row4_col1" class="data row4 col1" >U</td>
#       <td id="T_30dea_row4_col2" class="data row4 col2" >U</td>
#       <td id="T_30dea_row4_col3" class="data row4 col3" >U</td>
#       <td id="T_30dea_row4_col4" class="data row4 col4" >U</td>
#       <td id="T_30dea_row4_col5" class="data row4 col5" >U</td>
#       <td id="T_30dea_row4_col6" class="data row4 col6" >Lecanora</td>
#       <td id="T_30dea_row4_col7" class="data row4 col7" >rutilans</td>
#       <td id="T_30dea_row4_col8" class="data row4 col8" >(Ach.) Ach.</td>
#       <td id="T_30dea_row4_col9" class="data row4 col9" >U</td>
#       <td id="T_30dea_row4_col10" class="data row4 col10" >U</td>
#       <td id="T_30dea_row4_col11" class="data row4 col11" >U</td>
#       <td id="T_30dea_row4_col12" class="data row4 col12" >U</td>
#       <td id="T_30dea_row4_col13" class="data row4 col13" ><a href="https://lichenportal.org/portal/taxa/index.php?taxon=56389" target="_blank">https://lichenportal.org/portal/taxa/index.php?taxon=56389</a></td>
#       <td id="T_30dea_row4_col14" class="data row4 col14" >56389</td>
#     </tr>
#     <tr>
#       <th id="T_30dea_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_30dea_row5_col0" class="data row5 col0" >Lichen Portal</td>
#       <td id="T_30dea_row5_col1" class="data row5 col1" >U</td>
#       <td id="T_30dea_row5_col2" class="data row5 col2" >U</td>
#       <td id="T_30dea_row5_col3" class="data row
# ============================================================
#   symbiota / Lichen Portal
#   URL:       https://lichenportal.org/portal
#   Species:   Not species
#   Name type: synonym  (synonym of: Xanthoria parietina)
# ============================================================
# [Lichen Portal] 'api/v2/taxonomy/search' returned no results for 'Not species'.
# [Lichen Portal] 'api/v2/taxonomy' returned no results for 'Not species'.
# [Lichen Portal] All search endpoints returned no results for 'Not species'. Attempting autocomplete search.
# [Lichen Portal] All searches failed or returned no results for 'Not species'.
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / Bryophyte Portal
#   URL:       https://bryophyteportal.org/portal
#   Species:   Pohlia nutans
#   Name type: accepted
# ============================================================
# [Bryophyte Portal] 'api/v2/taxonomy/search' returned no results for 'Pohlia nutans'.
# [Bryophyte Portal] 'api/v2/taxonomy' returned results for 'Pohlia nutans'.
# {'tid': 160406, 'kingdomName': 'Plantae', 'rankID': 220, 'rankName': None, 'unitInd1': None, 'unitName1': 'Pohlia', 'unitInd2': None, 'unitName2': 'nutans', 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': '(Hedw.) Lindb.', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': 'tropicos;usda', 'sourceIdentifier': None, 'notes': None, 'securityStatus': 0, 'modifiedTimestamp': None, 'initialTimestamp': '2010-09-21 05:27:39', 'scientificName': 'Pohlia nutans'}
# Synonyms returned: 74
# <style type="text/css">
# </style>
# <table id="T_dd3f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd3f2_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_dd3f2_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_dd3f2_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_dd3f2_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_dd3f2_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_dd3f2_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_dd3f2_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_dd3f2_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_dd3f2_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_dd3f2_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_dd3f2_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_dd3f2_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_dd3f2_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_dd3f2_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_dd3f2_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd3f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd3f2_row0_col0" class="data row0 col0" >Bryophyte Portal</td>
#       <td id="T_dd3f2_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_dd3f2_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_dd3f2_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_dd3f2_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_dd3f2_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_dd3f2_row0_col6" class="data row0 col6" >Pohlia</td>
#       <td id="T_dd3f2_row0_col7" class="data row0 col7" >nutans</td>
#       <td id="T_dd3f2_row0_col8" class="data row0 col8" >(Hedw.) Lindb.</td>
#       <td id="T_dd3f2_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_dd3f2_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_dd3f2_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_dd3f2_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_dd3f2_row0_col13" class="data row0 col13" ><a href="https://bryophyteportal.org/portal/taxa/index.php?tid=160406" target="_blank">https://bryophyteportal.org/portal/taxa/index.php?tid=160406</a></td>
#       <td id="T_dd3f2_row0_col14" class="data row0 col14" >160406</td>
#     </tr>
#     <tr>
#       <th id="T_dd3f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd3f2_row1_col0" class="data row1 col0" >Bryophyte Portal</td>
#       <td id="T_dd3f2_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_dd3f2_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_dd3f2_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_dd3f2_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_dd3f2_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_dd3f2_row1_col6" class="data row1 col6" >Bryum</td>
#       <td id="T_dd3f2_row1_col7" class="data row1 col7" >afronutans</td>
#       <td id="T_dd3f2_row1_col8" class="data row1 col8" >Müll. Hal.</td>
#       <td id="T_dd3f2_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_dd3f2_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_dd3f2_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_dd3f2_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_dd3f2_row1_col13" class="data row1 col13" ><a href="https://bryophyteportal.org/portal/taxa/index.php?taxon=160406" target="_blank">https://bryophyteportal.org/portal/taxa/index.php?taxon=160406</a></td>
#       <td id="T_dd3f2_row1_col14" class="data row1 col14" >160406</td>
#     </tr>
#     <tr>
#       <th id="T_dd3f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd3f2_row2_col0" class="data row2 col0" >Bryophyte Portal</td>
#       <td id="T_dd3f2_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_dd3f2_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_dd3f2_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_dd3f2_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_dd3f2_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_dd3f2_row2_col6" class="data row2 col6" >Bryum</td>
#       <td id="T_dd3f2_row2_col7" class="data row2 col7" >austronutans</td>
#       <td id="T_dd3f2_row2_col8" class="data row2 col8" >Müll. Hal.</td>
#       <td id="T_dd3f2_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_dd3f2_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_dd3f2_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_dd3f2_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_dd3f2_row2_col13" class="data row2 col13" ><a href="https://bryophyteportal.org/portal/taxa/index.php?taxon=160406" target="_blank">https://bryophyteportal.org/portal/taxa/index.php?taxon=160406</a></td>
#       <td id="T_dd3f2_row2_col14" class="data row2 col14" >160406</td>
#     </tr>
#     <tr>
#       <th id="T_dd3f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd3f2_row3_col0" class="data row3 col0" >Bryophyte Portal</td>
#       <td id="T_dd3f2_row3_col1" class="data row3 col1" >U</td>
#       <td id="T_dd3f2_row3_col2" class="data row3 col2" >U</td>
#       <td id="T_dd3f2_row3_col3" class="data row3 col3" >U</td>
#       <td id="T_dd3f2_row3_col4" class="data row3 col4" >U</td>
#       <td id="T_dd3f2_row3_col5" class="data row3 col5" >U</td>
#       <td id="T_dd3f2_row3_col6" class="data row3 col6" >Bryum</td>
#       <td id="T_dd3f2_row3_col7" class="data row3 col7" >basalticum</td>
#       <td id="T_dd3f2_row3_col8" class="data row3 col8" >Warnst. & Geh.</td>
#       <td id="T_dd3f2_row3_col9" class="data row3 col9" >U</td>
#       <td id="T_dd3f2_row3_col10" class="data row3 col10" >U</td>
#       <td id="T_dd3f2_row3_col11" class="data row3 col11" >U</td>
#       <td id="T_dd3f2_row3_col12" class="data row3 col12" >U</td>
#       <td id="T_dd3f2_row3_col13" class="data row3 col13" ><a href="https://bryophyteportal.org/portal/taxa/index.php?taxon=160406" target="_blank">https://bryophyteportal.org/portal/taxa/index.php?taxon=160406</a></td>
#       <td id="T_dd3f2_row3_col14" class="data row3 col14" >160406</td>
#     </tr>
#     <tr>
#       <th id="T_dd3f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd3f2_row4_col0" class="data row4 col0" >Bryophyte Portal</td>
#       <td id="T_dd3f2_row4_col1" class="data row4 col1" >U</td>
#       <td id="T_dd3f2_row4_col2" class="data row4 col2" >U</td>
#       <td id="T_dd3f2_row4_col3" class="data row4 col3" >U</td>
#       <td id="T_dd3f2_row4_col4" class="data row4 col4" >U</td>
#       <td id="T_dd3f2_row4_col5" class="data row4 col5" >U</td>
#       <td id="T_dd3f2_row4_col6" class="data row4 col6" >Bryum</td>
#       <td id="T_dd3f2_row4_col7" class="data row4 col7" >bealeyense</td>
#       <td id="T_dd3f2_row4_col8" class="data row4 col8" >(Huebener) Delogne</td>
#       <td id="T_dd3f2_row4_col9" class="data row4 col9" >U</td>
#       <td id="T_dd3f2_row4_col10" class="data row4 col10" >U</td>
#       <td id="T_dd3f2_row4_col11" class="data row4 col11" >U</td>
#       <td id="T_dd3f2_row4_col12" class="data row4 col12" >U</td>
#       <td id="T_dd3f2_row4_col13" class="data row4 col13" ><a href="https://bryophyteportal.org/portal/taxa/index.php?taxon=160406" target="_blank">https://bryophyteportal.org/portal/taxa/index.php?taxon=160406</a></td>
#       <td id="T_dd3f2_row4_col14" class="data row4 col14" >160406</td>
#     </tr>
#     <tr>
#       <th id="T_dd3f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd3f2_row5_col0" class="data row5 col0" >Bryophyte Portal</td>
#       <td id="T_dd3f2_row5_col1" class="data row5 col1" >U</td>
#       <td id="T_dd3f2_row5_col2" class="data row5 col2" >U</td>
# ============================================================
#   symbiota / Bryophyte Portal
#   URL:       https://bryophyteportal.org/portal
#   Species:   Not species
#   Name type: synonym  (synonym of: Pohlia nutans)
# ============================================================
# [Bryophyte Portal] 'api/v2/taxonomy/search' returned no results for 'Not species'.
# [Bryophyte Portal] 'api/v2/taxonomy' returned no results for 'Not species'.
# [Bryophyte Portal] All search endpoints returned no results for 'Not species'. Attempting autocomplete search.
# [Bryophyte Portal] All searches failed or returned no results for 'Not species'.
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / CCH2
#   URL:       https://cch2.org/portal
#   Species:   Heteromeles arbutifolia
#   Name type: accepted
# ============================================================
# [CCH2] 'api/v2/taxonomy/search' returned no results for 'Heteromeles arbutifolia'.
# [CCH2] 'api/v2/taxonomy' returned results for 'Heteromeles arbutifolia'.
# {'tid': 22929, 'kingdomName': 'Plantae', 'rankID': 220, 'unitInd1': None, 'unitName1': 'Heteromeles', 'unitInd2': None, 'unitName2': 'arbutifolia', 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': '(Lindl.) M. Roem.', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': None, 'sourceIdentifier': None, 'notes': None, 'securityStatus': 0, 'scientificName': 'Heteromeles arbutifolia'}
# Synonyms returned: 5
# <style type="text/css">
# </style>
# <table id="T_55950">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55950_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_55950_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_55950_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_55950_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_55950_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_55950_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_55950_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_55950_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_55950_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_55950_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_55950_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_55950_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_55950_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_55950_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_55950_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55950_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55950_row0_col0" class="data row0 col0" >CCH2</td>
#       <td id="T_55950_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_55950_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_55950_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_55950_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_55950_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_55950_row0_col6" class="data row0 col6" >Heteromeles</td>
#       <td id="T_55950_row0_col7" class="data row0 col7" >arbutifolia</td>
#       <td id="T_55950_row0_col8" class="data row0 col8" >(Lindl.) M. Roem.</td>
#       <td id="T_55950_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_55950_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_55950_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_55950_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_55950_row0_col13" class="data row0 col13" ><a href="https://cch2.org/portal/taxa/index.php?tid=22929" target="_blank">https://cch2.org/portal/taxa/index.php?tid=22929</a></td>
#       <td id="T_55950_row0_col14" class="data row0 col14" >22929</td>
#     </tr>
#     <tr>
#       <th id="T_55950_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55950_row1_col0" class="data row1 col0" >CCH2</td>
#       <td id="T_55950_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_55950_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_55950_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_55950_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_55950_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_55950_row1_col6" class="data row1 col6" >Heteromeles</td>
#       <td id="T_55950_row1_col7" class="data row1 col7" >fremontiana</td>
#       <td id="T_55950_row1_col8" class="data row1 col8" >Decne.</td>
#       <td id="T_55950_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_55950_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_55950_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_55950_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_55950_row1_col13" class="data row1 col13" ><a href="https://cch2.org/portal/taxa/index.php?taxon=22929" target="_blank">https://cch2.org/portal/taxa/index.php?taxon=22929</a></td>
#       <td id="T_55950_row1_col14" class="data row1 col14" >22929</td>
#     </tr>
#     <tr>
#       <th id="T_55950_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55950_row2_col0" class="data row2 col0" >CCH2</td>
#       <td id="T_55950_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_55950_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_55950_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_55950_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_55950_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_55950_row2_col6" class="data row2 col6" >Heteromeles</td>
#       <td id="T_55950_row2_col7" class="data row2 col7" >salicifolia</td>
#       <td id="T_55950_row2_col8" class="data row2 col8" >(C. Presl) Abrams</td>
#       <td id="T_55950_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_55950_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_55950_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_55950_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_55950_row2_col13" class="data row2 col13" ><a href="https://cch2.org/portal/taxa/index.php?taxon=22929" target="_blank">https://cch2.org/portal/taxa/index.php?taxon=22929</a></td>
#       <td id="T_55950_row2_col14" class="data row2 col14" >22929</td>
#     </tr>
#     <tr>
#       <th id="T_55950_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55950_row3_col0" class="data row3 col0" >CCH2</td>
#       <td id="T_55950_row3_col1" class="data row3 col1" >U</td>
#       <td id="T_55950_row3_col2" class="data row3 col2" >U</td>
#       <td id="T_55950_row3_col3" class="data row3 col3" >U</td>
#       <td id="T_55950_row3_col4" class="data row3 col4" >U</td>
#       <td id="T_55950_row3_col5" class="data row3 col5" >U</td>
#       <td id="T_55950_row3_col6" class="data row3 col6" >Photinia</td>
#       <td id="T_55950_row3_col7" class="data row3 col7" >arbutifolia</td>
#       <td id="T_55950_row3_col8" class="data row3 col8" >Lindl.</td>
#       <td id="T_55950_row3_col9" class="data row3 col9" >U</td>
#       <td id="T_55950_row3_col10" class="data row3 col10" >U</td>
#       <td id="T_55950_row3_col11" class="data row3 col11" >U</td>
#       <td id="T_55950_row3_col12" class="data row3 col12" >U</td>
#       <td id="T_55950_row3_col13" class="data row3 col13" ><a href="https://cch2.org/portal/taxa/index.php?taxon=22929" target="_blank">https://cch2.org/portal/taxa/index.php?taxon=22929</a></td>
#       <td id="T_55950_row3_col14" class="data row3 col14" >22929</td>
#     </tr>
#     <tr>
#       <th id="T_55950_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55950_row4_col0" class="data row4 col0" >CCH2</td>
#       <td id="T_55950_row4_col1" class="data row4 col1" >U</td>
#       <td id="T_55950_row4_col2" class="data row4 col2" >U</td>
#       <td id="T_55950_row4_col3" class="data row4 col3" >U</td>
#       <td id="T_55950_row4_col4" class="data row4 col4" >U</td>
#       <td id="T_55950_row4_col5" class="data row4 col5" >U</td>
#       <td id="T_55950_row4_col6" class="data row4 col6" >Photinia</td>
#       <td id="T_55950_row4_col7" class="data row4 col7" >salicifolia</td>
#       <td id="T_55950_row4_col8" class="data row4 col8" >C. Presl</td>
#       <td id="T_55950_row4_col9" class="data row4 col9" >U</td>
#       <td id="T_55950_row4_col10" class="data row4 col10" >U</td>
#       <td id="T_55950_row4_col11" class="data row4 col11" >U</td>
#       <td id="T_55950_row4_col12" class="data row4 col12" >U</td>
#       <td id="T_55950_row4_col13" class="data row4 col13" ><a href="https://cch2.org/portal/taxa/index.php?taxon=22929" target="_blank">https://cch2.org/portal/taxa/index.php?taxon=22929</a></td>
#       <td id="T_55950_row4_col14" class="data row4 col14" >22929</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   symbiota / CCH2
#   URL:       https://cch2.org/portal
#   Species:   Not species
#   Name type: synonym  (synonym of: Heteromeles arbutifolia)
# ============================================================
# [CCH2] 'api/v2/taxonomy/search' returned no results for 'Not species'.
# [CCH2] 'api/v2/taxonomy' returned no results for 'Not species'.
# [CCH2] All search endpoints returned no results for 'Not species'. Attempting autocomplete search.
# [CCH2] All searches failed or returned no results for 'Not species'.
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / SERNEC
#   URL:       https://sernecportal.org/portal
#   Species:   Magnolia grandiflora
#   Name type: accepted
# ============================================================
# [SERNEC] 'api/v2/taxonomy/search' returned no results for 'Magnolia grandiflora'.
# [SERNEC] 'api/v2/taxonomy' returned results for 'Magnolia grandiflora'.
# {'tid': 17263, 'kingdomName': 'Plantae', 'rankID': 220, 'rankName': None, 'unitInd1': None, 'unitName1': 'Magnolia', 'unitInd2': None, 'unitName2': 'grandiflora', 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': 'L.', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': 'Martin_092306', 'sourceIdentifier': None, 'notes': None, 'securityStatus': 0, 'modifiedTimestamp': None, 'initialTimestamp': '2006-12-25 06:25:43', 'scientificName': 'Magnolia grandiflora'}
# Synonyms returned: 3
# <style type="text/css">
# </style>
# <table id="T_d9c63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9c63_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_d9c63_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_d9c63_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_d9c63_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_d9c63_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_d9c63_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_d9c63_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_d9c63_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_d9c63_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_d9c63_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_d9c63_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_d9c63_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_d9c63_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_d9c63_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_d9c63_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9c63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9c63_row0_col0" class="data row0 col0" >SERNEC</td>
#       <td id="T_d9c63_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_d9c63_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_d9c63_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_d9c63_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_d9c63_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_d9c63_row0_col6" class="data row0 col6" >Magnolia</td>
#       <td id="T_d9c63_row0_col7" class="data row0 col7" >grandiflora</td>
#       <td id="T_d9c63_row0_col8" class="data row0 col8" >L.</td>
#       <td id="T_d9c63_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_d9c63_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_d9c63_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_d9c63_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_d9c63_row0_col13" class="data row0 col13" ><a href="https://sernecportal.org/portal/taxa/index.php?tid=17263" target="_blank">https://sernecportal.org/portal/taxa/index.php?tid=17263</a></td>
#       <td id="T_d9c63_row0_col14" class="data row0 col14" >17263</td>
#     </tr>
#     <tr>
#       <th id="T_d9c63_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9c63_row1_col0" class="data row1 col0" >SERNEC</td>
#       <td id="T_d9c63_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_d9c63_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_d9c63_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_d9c63_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_d9c63_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_d9c63_row1_col6" class="data row1 col6" >Magnolia</td>
#       <td id="T_d9c63_row1_col7" class="data row1 col7" >foetida</td>
#       <td id="T_d9c63_row1_col8" class="data row1 col8" ></td>
#       <td id="T_d9c63_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_d9c63_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_d9c63_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_d9c63_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_d9c63_row1_col13" class="data row1 col13" ><a href="https://sernecportal.org/portal/taxa/index.php?taxon=17263" target="_blank">https://sernecportal.org/portal/taxa/index.php?taxon=17263</a></td>
#       <td id="T_d9c63_row1_col14" class="data row1 col14" >17263</td>
#     </tr>
#     <tr>
#       <th id="T_d9c63_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9c63_row2_col0" class="data row2 col0" >SERNEC</td>
#       <td id="T_d9c63_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_d9c63_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_d9c63_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_d9c63_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_d9c63_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_d9c63_row2_col6" class="data row2 col6" >Magnolia</td>
#       <td id="T_d9c63_row2_col7" class="data row2 col7" >tomentosa</td>
#       <td id="T_d9c63_row2_col8" class="data row2 col8" >Ser.</td>
#       <td id="T_d9c63_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_d9c63_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_d9c63_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_d9c63_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_d9c63_row2_col13" class="data row2 col13" ><a href="https://sernecportal.org/portal/taxa/index.php?taxon=17263" target="_blank">https://sernecportal.org/portal/taxa/index.php?taxon=17263</a></td>
#       <td id="T_d9c63_row2_col14" class="data row2 col14" >17263</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   symbiota / SERNEC
#   URL:       https://sernecportal.org/portal
#   Species:   Not species
#   Name type: synonym  (synonym of: Magnolia grandiflora)
# ============================================================
# [SERNEC] 'api/v2/taxonomy/search' returned no results for 'Not species'.
# [SERNEC] 'api/v2/taxonomy' returned no results for 'Not species'.
# [SERNEC] All search endpoints returned no results for 'Not species'. Attempting autocomplete search.
# [SERNEC] All searches failed or returned no results for 'Not species'.
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / NANSH
#   URL:       https://nansh.org/portal
#   Species:   Rudbeckia hirta
#   Name type: accepted
# ============================================================
# [NANSH] 'api/v2/taxonomy/search' returned no results for 'Rudbeckia hirta'.
# [NANSH] 'api/v2/taxonomy' returned results for 'Rudbeckia hirta'.
# {'tid': 17308, 'kingdomName': 'Plantae', 'rankID': 220, 'rankName': None, 'unitInd1': None, 'unitName1': 'Rudbeckia', 'unitInd2': None, 'unitName2': 'hirta', 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': 'L.', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': 'Martin_092306', 'sourceIdentifier': None, 'notes': None, 'securityStatus': 0, 'modifiedTimestamp': None, 'initialTimestamp': '2006-12-25 06:25:43', 'scientificName': 'Rudbeckia hirta'}
# Synonyms returned: 2
# <style type="text/css">
# </style>
# <table id="T_ba14f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba14f_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_ba14f_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_ba14f_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_ba14f_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_ba14f_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_ba14f_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_ba14f_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_ba14f_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_ba14f_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_ba14f_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_ba14f_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_ba14f_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_ba14f_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_ba14f_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_ba14f_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba14f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba14f_row0_col0" class="data row0 col0" >NANSH</td>
#       <td id="T_ba14f_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_ba14f_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_ba14f_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_ba14f_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_ba14f_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_ba14f_row0_col6" class="data row0 col6" >Rudbeckia</td>
#       <td id="T_ba14f_row0_col7" class="data row0 col7" >hirta</td>
#       <td id="T_ba14f_row0_col8" class="data row0 col8" >L.</td>
#       <td id="T_ba14f_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_ba14f_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_ba14f_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_ba14f_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_ba14f_row0_col13" class="data row0 col13" ><a href="https://nansh.org/portal/taxa/index.php?tid=17308" target="_blank">https://nansh.org/portal/taxa/index.php?tid=17308</a></td>
#       <td id="T_ba14f_row0_col14" class="data row0 col14" >17308</td>
#     </tr>
#     <tr>
#       <th id="T_ba14f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba14f_row1_col0" class="data row1 col0" >NANSH</td>
#       <td id="T_ba14f_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_ba14f_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_ba14f_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_ba14f_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_ba14f_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_ba14f_row1_col6" class="data row1 col6" >Coreopsis</td>
#       <td id="T_ba14f_row1_col7" class="data row1 col7" >hirta</td>
#       <td id="T_ba14f_row1_col8" class="data row1 col8" >]</td>
#       <td id="T_ba14f_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_ba14f_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_ba14f_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_ba14f_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_ba14f_row1_col13" class="data row1 col13" ><a href="https://nansh.org/portal/taxa/index.php?taxon=17308" target="_blank">https://nansh.org/portal/taxa/index.php?taxon=17308</a></td>
#       <td id="T_ba14f_row1_col14" class="data row1 col14" >17308</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   symbiota / NANSH
#   URL:       https://nansh.org/portal
#   Species:   Not species
#   Name type: synonym  (synonym of: Rudbeckia hirta)
# ============================================================
# [NANSH] 'api/v2/taxonomy/search' returned no results for 'Not species'.
# [NANSH] 'api/v2/taxonomy' returned no results for 'Not species'.
# [NANSH] All search endpoints returned no results for 'Not species'. Attempting autocomplete search.
# [NANSH] All searches failed or returned no results for 'Not species'.
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / Algae Herbarium Portal
#   URL:       https://macroalgae.org/portal
#   Species:   Ulva intestinalis
#   Name type: accepted
# ============================================================
# [Algae Herbarium Portal] 'api/v2/taxonomy/search' returned no results for 'Ulva intestinalis'.
# [Algae Herbarium Portal] 'api/v2/taxonomy' returned results for 'Ulva intestinalis'.
# {'tid': 76122, 'kingdomName': 'Plantae', 'rankID': 220, 'rankName': None, 'unitInd1': None, 'unitName1': 'Ulva', 'unitInd2': None, 'unitName2': 'intestinalis', 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': 'Linnaeus', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': None, 'sourceIdentifier': None, 'notes': 'Woolwich, London, England?', 'securityStatus': 0, 'modifiedTimestamp': None, 'initialTimestamp': '2014-04-25 18:37:07', 'scientificName': 'Ulva intestinalis'}
# Synonyms returned: 3
# <style type="text/css">
# </style>
# <table id="T_0f369">
#   <thead>
#     <tr>
# ...
#       <td id="T_0f0c1_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_0f0c1_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_0f0c1_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_0f0c1_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_0f0c1_row2_col6" class="data row2 col6" >Impatiens</td>
#       <td id="T_0f0c1_row2_col7" class="data row2 col7" >fulva</td>
#       <td id="T_0f0c1_row2_col8" class="data row2 col8" >Nutt.</td>
#       <td id="T_0f0c1_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_0f0c1_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_0f0c1_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_0f0c1_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_0f0c1_row2_col13" class="data row2 col13" ><a href="https://neherbaria.org/portal/taxa/index.php?taxon=824846" target="_blank">https://neherbaria.org/portal/taxa/index.php?taxon=824846</a></td>
#       <td id="T_0f0c1_row2_col14" class="data row2 col14" >824846</td>
#     </tr>
#     <tr>
#       <th id="T_0f0c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0f0c1_row3_col0" class="data row3 col0" >CNH</td>
#       <td id="T_0f0c1_row3_col1" class="data row3 col1" >U</td>
#       <td id="T_0f0c1_row3_col2" class="data row3 col2" >U</td>
#       <td id="T_0f0c1_row3_col3" class="data row3 col3" >U</td>
#       <td id="T_0f0c1_row3_col4" class="data row3 col4" >U</td>
#       <td id="T_0f0c1_row3_col5" class="data row3 col5" >U</td>
#       <td id="T_0f0c1_row3_col6" class="data row3 col6" >Impatiens</td>
#       <td id="T_0f0c1_row3_col7" class="data row3 col7" >nortonii</td>
#       <td id="T_0f0c1_row3_col8" class="data row3 col8" >Rydb.</td>
#       <td id="T_0f0c1_row3_col9" class="data row3 col9" >U</td>
#       <td id="T_0f0c1_row3_col10" class="data row3 col10" >U</td>
#       <td id="T_0f0c1_row3_col11" class="data row3 col11" >U</td>
#       <td id="T_0f0c1_row3_col12" class="data row3 col12" >U</td>
#       <td id="T_0f0c1_row3_col13" class="data row3 col13" ><a href="https://neherbaria.org/portal/taxa/index.php?taxon=824846" target="_blank">https://neherbaria.org/portal/taxa/index.php?taxon=824846</a></td>
#       <td id="T_0f0c1_row3_col14" class="data row3 col14" >824846</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   symbiota / CNH
#   URL:       https://neherbaria.org/portal
#   Species:   Not species
#   Name type: synonym  (synonym of: Impatiens capensis)
# ============================================================
# [CNH] 'api/v2/taxonomy/search' returned no results for 'Not species'.
# [CNH] 'api/v2/taxonomy' returned no results for 'Not species'.
# [CNH] All search endpoints returned no results for 'Not species'. Attempting autocomplete search.
# [CNH] All searches failed or returned no results for 'Not species'.
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / Mid-Atlantic Herbaria Consortium
#   URL:       https://midatlanticherbaria.org/portal
#   Species:   Quercus rubra
#   Name type: accepted
# ============================================================
# [Mid-Atlantic Herbaria Consortium] 'api/v2/taxonomy/search' returned no results for 'Quercus rubra'.
# [Mid-Atlantic Herbaria Consortium] 'api/v2/taxonomy' returned results for 'Quercus rubra'.
# {'tid': 46960, 'kingdomName': 'Plantae', 'rankID': 220, 'rankName': None, 'unitInd1': None, 'unitName1': 'Quercus', 'unitInd2': None, 'unitName2': 'rubra', 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': 'L.', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': 'Tropicos', 'sourceIdentifier': None, 'notes': None, 'securityStatus': 0, 'modifiedTimestamp': None, 'initialTimestamp': '2008-09-28 20:57:25', 'scientificName': 'Quercus rubra'}
# Synonyms returned: 3
# <style type="text/css">
# </style>
# <table id="T_4e02d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e02d_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_4e02d_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_4e02d_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_4e02d_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_4e02d_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_4e02d_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_4e02d_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_4e02d_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_4e02d_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_4e02d_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_4e02d_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_4e02d_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_4e02d_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_4e02d_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_4e02d_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e02d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e02d_row0_col0" class="data row0 col0" >Mid-Atlantic Herbaria Consortium</td>
#       <td id="T_4e02d_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_4e02d_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_4e02d_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_4e02d_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_4e02d_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_4e02d_row0_col6" class="data row0 col6" >Quercus</td>
#       <td id="T_4e02d_row0_col7" class="data row0 col7" >rubra</td>
#       <td id="T_4e02d_row0_col8" class="data row0 col8" >L.</td>
#       <td id="T_4e02d_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_4e02d_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_4e02d_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_4e02d_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_4e02d_row0_col13" class="data row0 col13" ><a href="https://midatlanticherbaria.org/portal/taxa/index.php?tid=46960" target="_blank">https://midatlanticherbaria.org/portal/taxa/index.php?tid=46960</a></td>
#       <td id="T_4e02d_row0_col14" class="data row0 col14" >46960</td>
#     </tr>
#     <tr>
#       <th id="T_4e02d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e02d_row1_col0" class="data row1 col0" >Mid-Atlantic Herbaria Consortium</td>
#       <td id="T_4e02d_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_4e02d_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_4e02d_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_4e02d_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_4e02d_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_4e02d_row1_col6" class="data row1 col6" >Quercus</td>
#       <td id="T_4e02d_row1_col7" class="data row1 col7" >borealis</td>
#       <td id="T_4e02d_row1_col8" class="data row1 col8" >Michx. f.</td>
#       <td id="T_4e02d_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_4e02d_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_4e02d_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_4e02d_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_4e02d_row1_col13" class="data row1 col13" ><a href="https://midatlanticherbaria.org/portal/taxa/index.php?taxon=46960" target="_blank">https://midatlanticherbaria.org/portal/taxa/index.php?taxon=46960</a></td>
#       <td id="T_4e02d_row1_col14" class="data row1 col14" >46960</td>
#     </tr>
#     <tr>
#       <th id="T_4e02d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4e02d_row2_col0" class="data row2 col0" >Mid-Atlantic Herbaria Consortium</td>
#       <td id="T_4e02d_row2_col1" class="data row2 col1" >U</td>
#       <td id="T_4e02d_row2_col2" class="data row2 col2" >U</td>
#       <td id="T_4e02d_row2_col3" class="data row2 col3" >U</td>
#       <td id="T_4e02d_row2_col4" class="data row2 col4" >U</td>
#       <td id="T_4e02d_row2_col5" class="data row2 col5" >U</td>
#       <td id="T_4e02d_row2_col6" class="data row2 col6" >Quercus</td>
#       <td id="T_4e02d_row2_col7" class="data row2 col7" >maxima</td>
#       <td id="T_4e02d_row2_col8" class="data row2 col8" >(Marsh.) Ashe</td>
#       <td id="T_4e02d_row2_col9" class="data row2 col9" >U</td>
#       <td id="T_4e02d_row2_col10" class="data row2 col10" >U</td>
#       <td id="T_4e02d_row2_col11" class="data row2 col11" >U</td>
#       <td id="T_4e02d_row2_col12" class="data row2 col12" >U</td>
#       <td id="T_4e02d_row2_col13" class="data row2 col13" ><a href="https://midatlanticherbaria.org/portal/taxa/index.php?taxon=46960" target="_blank">https://midatlanticherbaria.org/portal/taxa/index.php?taxon=46960</a></td>
#       <td id="T_4e02d_row2_col14" class="data row2 col14" >46960</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   symbiota / Mid-Atlantic Herbaria Consortium
#   URL:       https://midatlanticherbaria.org/portal
#   Species:   Not species
#   Name type: synonym  (synonym of: Quercus rubra)
# ============================================================
# [Mid-Atlantic Herbaria Consortium] 'api/v2/taxonomy/search' returned no results for 'Not species'.
# [Mid-Atlantic Herbaria Consortium] 'api/v2/taxonomy' returned no results for 'Not species'.
# [Mid-Atlantic Herbaria Consortium] All search endpoints returned no results for 'Not species'. Attempting autocomplete search.
# [Mid-Atlantic Herbaria Consortium] All searches failed or returned no results for 'Not species'.
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / swbiodiversity
#   URL:       https://swbiodiversity.org/seinet
#   Species:   Larrea tridentata
#   Name type: accepted
# ============================================================
# [swbiodiversity] 'api/v2/taxonomy/search' returned no results for 'Larrea tridentata'.
# [swbiodiversity] 'api/v2/taxonomy' returned results for 'Larrea tridentata'.
# {'tid': 2671, 'kingdomName': 'Plantae', 'rankID': 220, 'rankName': None, 'unitInd1': None, 'unitName1': 'Larrea', 'unitInd2': None, 'unitName2': 'tridentata', 'unitInd3': None, 'unitName3': None, 'cultivarEpithet': None, 'tradeName': None, 'author': '(Sessé & Moc. ex DC.) Coville', 'reviewStatus': None, 'displayStatus': None, 'isLegitimate': None, 'source': None, 'sourceIdentifier': None, 'notes': None, 'securityStatus': 0, 'modifiedTimestamp': None, 'initialTimestamp': '1996-06-13 20:51:08', 'scientificName': 'Larrea tridentata'}
# Synonyms returned: 2
# <style type="text/css">
# </style>
# <table id="T_80efb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80efb_level0_col0" class="col_heading level0 col0" >api_name</th>
#       <th id="T_80efb_level0_col1" class="col_heading level0 col1" >kingdom</th>
#       <th id="T_80efb_level0_col2" class="col_heading level0 col2" >phylum</th>
#       <th id="T_80efb_level0_col3" class="col_heading level0 col3" >class</th>
#       <th id="T_80efb_level0_col4" class="col_heading level0 col4" >family</th>
#       <th id="T_80efb_level0_col5" class="col_heading level0 col5" >subfamily</th>
#       <th id="T_80efb_level0_col6" class="col_heading level0 col6" >genus</th>
#       <th id="T_80efb_level0_col7" class="col_heading level0 col7" >species</th>
#       <th id="T_80efb_level0_col8" class="col_heading level0 col8" >author</th>
#       <th id="T_80efb_level0_col9" class="col_heading level0 col9" >publication_name</th>
#       <th id="T_80efb_level0_col10" class="col_heading level0 col10" >publication_year</th>
#       <th id="T_80efb_level0_col11" class="col_heading level0 col11" >status</th>
#       <th id="T_80efb_level0_col12" class="col_heading level0 col12" >source_name</th>
#       <th id="T_80efb_level0_col13" class="col_heading level0 col13" >api_link</th>
#       <th id="T_80efb_level0_col14" class="col_heading level0 col14" >api_internal_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80efb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80efb_row0_col0" class="data row0 col0" >swbiodiversity</td>
#       <td id="T_80efb_row0_col1" class="data row0 col1" >U</td>
#       <td id="T_80efb_row0_col2" class="data row0 col2" >U</td>
#       <td id="T_80efb_row0_col3" class="data row0 col3" >U</td>
#       <td id="T_80efb_row0_col4" class="data row0 col4" >U</td>
#       <td id="T_80efb_row0_col5" class="data row0 col5" >U</td>
#       <td id="T_80efb_row0_col6" class="data row0 col6" >Larrea</td>
#       <td id="T_80efb_row0_col7" class="data row0 col7" >tridentata</td>
#       <td id="T_80efb_row0_col8" class="data row0 col8" >(Sessé & Moc. ex DC.) Coville</td>
#       <td id="T_80efb_row0_col9" class="data row0 col9" >U</td>
#       <td id="T_80efb_row0_col10" class="data row0 col10" >U</td>
#       <td id="T_80efb_row0_col11" class="data row0 col11" >U</td>
#       <td id="T_80efb_row0_col12" class="data row0 col12" >U</td>
#       <td id="T_80efb_row0_col13" class="data row0 col13" ><a href="https://swbiodiversity.org/seinet/taxa/index.php?tid=2671" target="_blank">https://swbiodiversity.org/seinet/taxa/index.php?tid=2671</a></td>
#       <td id="T_80efb_row0_col14" class="data row0 col14" >2671</td>
#     </tr>
#     <tr>
#       <th id="T_80efb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80efb_row1_col0" class="data row1 col0" >swbiodiversity</td>
#       <td id="T_80efb_row1_col1" class="data row1 col1" >U</td>
#       <td id="T_80efb_row1_col2" class="data row1 col2" >U</td>
#       <td id="T_80efb_row1_col3" class="data row1 col3" >U</td>
#       <td id="T_80efb_row1_col4" class="data row1 col4" >U</td>
#       <td id="T_80efb_row1_col5" class="data row1 col5" >U</td>
#       <td id="T_80efb_row1_col6" class="data row1 col6" >Larrea</td>
#       <td id="T_80efb_row1_col7" class="data row1 col7" >mexicana</td>
#       <td id="T_80efb_row1_col8" class="data row1 col8" >Moric.</td>
#       <td id="T_80efb_row1_col9" class="data row1 col9" >U</td>
#       <td id="T_80efb_row1_col10" class="data row1 col10" >U</td>
#       <td id="T_80efb_row1_col11" class="data row1 col11" >U</td>
#       <td id="T_80efb_row1_col12" class="data row1 col12" >U</td>
#       <td id="T_80efb_row1_col13" class="data row1 col13" ><a href="https://swbiodiversity.org/seinet/taxa/index.php?taxon=2671" target="_blank">https://swbiodiversity.org/seinet/taxa/index.php?taxon=2671</a></td>
#       <td id="T_80efb_row1_col14" class="data row1 col14" >2671</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
#   symbiota / swbiodiversity
#   URL:       https://swbiodiversity.org/seinet
#   Species:   Not species
#   Name type: synonym  (synonym of: Larrea tridentata)
# ============================================================
# [swbiodiversity] 'api/v2/taxonomy/search' returned no results for 'Not species'.
# [swbiodiversity] 'api/v2/taxonomy' returned no results for 'Not species'.
# [swbiodiversity] All search endpoints returned no results for 'Not species'. Attempting autocomplete search.
# [swbiodiversity] All searches failed or returned no results for 'Not species'.
# {}
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
