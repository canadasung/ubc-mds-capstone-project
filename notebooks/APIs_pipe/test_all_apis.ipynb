# %% [markdown]
# # Test: `get_synonyms()` for all APIs_pipe clients
#
# Run from the **project root** so that `scripts/` is on the Python path.
#
# Covers:
# - COL, GBIF, GenBank, Index Fungorum, MushroomObserver, Tropicos
# - Symbiota portals: MyCoPortal, Lichen, Bryophyte, CCH2, SERNEC, NANSH, Macroalgae, Pterido, NE Herbaria, Mid-Atlantic, SW Biodiversity

# %%
import sys, os
# Ensure the project root is on sys.path when running from notebooks/APIs_pipe/
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from IPython.display import display

from scripts.APIs_pipe.col import COLAPI
from scripts.APIs_pipe.gbif import GBIFAPI
from scripts.APIs_pipe.genbank import GenBankAPI
from scripts.APIs_pipe.index_fungorum import IndexFungorumAPI
from scripts.APIs_pipe.mushroomobs import MushroomObserverAPI
from scripts.APIs_pipe.symbiota import SymbiotaAPI
from scripts.APIs_pipe.tropicos import TropicosAPI

# %% [markdown]
# ---
# ## Standard APIs

# %%
STANDARD_QUERIES = [
    ("col",            COLAPI(),               "Quercus robur"),
    ("gbif",           GBIFAPI(),              "Amanita muscaria"),
    ("genbank",        GenBankAPI(),           "Amanita muscaria"),
    ("index_fungorum", IndexFungorumAPI(),     "Amanita muscaria"),
    ("mushroomobs",    MushroomObserverAPI(),  "Amanita muscaria"),
    ("tropicos",       TropicosAPI(),          "Quercus robur"),
]

# %%
for key, client, species in STANDARD_QUERIES:
    print(f"\n{'='*60}")
    print(f"  {key}  ({client.__class__.__name__})")
    print(f"  Species: {species}")
    print(f"{'='*60}")
    try:
        result = client.get_synonyms(species)
        print(f"Synonyms returned: {len(result)}")
        display(result)
    except Exception as e:
        print(f"ERROR: {e}")
# Out:
# ============================================================
#   col  (COLAPI)
#   Species: Quercus robur
# ============================================================
# Synonyms returned: 16
# [{'name': 'Quercus atrosanguinea',
#   'author': 'hort.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SF5RP'},
#  {'name': 'Quercus belgica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4Z4'},
#  {'name': 'Quercus cupressoides',
#   'author': 'hort.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFBKJ'},
#  {'name': 'Quercus feminea',
#   'author': 'Mill.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFDVF'},
#  {'name': 'Quercus filicifolia',
#   'author': 'hort. ex A.DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFDXP'},
#  {'name': 'Quercus foemida',
#   'author': 'Mill.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4Y4'},
#  {'name': 'Quercus hentzei',
#   'author': 'Petz.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFGZ6'},
#  {'name': 'Quercus hohenackeri',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X52M'},
#  {'name': 'Quercus louettii',
#   'author': 'Dippel',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFMTB'},
#  {'name': 'Quercus malacophylla var. asterotricha',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R46R'},
#  {'name': 'Quercus pedunculata',
#   'author': 'Ehrh.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFRGP'},
#  {'name': 'Quercus pseudopeduncula',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFSTJ'},
#  {'name': 'Quercus robur f. pendula',
#   'author': '(Loudon) O. Schwarz',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFV5H'},
#  {'name': 'Quercus robur var. cuneifolia',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4FK'},
#  {'name': 'Quercus robur var. pedunculata',
#   'author': '(Hoffm.) Hook.f.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4GP'},
#  {'name': 'Quercus transiens',
#   'author': 'A.Reyn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/CDY39'}]
# ============================================================
#   gbif  (GBIFAPI)
#   Species: Amanita muscaria
# ============================================================
# Synonyms returned: 14
# [{'name': 'Agaricus aureolus',
#   'author': 'Kalchbr.',
#   'publication_year': '1873',
#   'publication_name': 'Icon. Sel. Hymenomyc. Hung. (Budapest) 1: 9.',
#   'api_link': 'https://www.gbif.org/species/5455639'},
#  {'name': 'Agaricus imperialis',
#   'author': 'Batsch',
#   'publication_year': '1783',
#   'publication_name': 'Elench. Fung. (Halle): 59.',
#   'api_link': 'https://www.gbif.org/species/5955425'},
#  {'name': 'Agaricus muscarius',
#   'author': 'L.',
#   'publication_year': '1753',
#   'publication_name': 'Sp. Pl. 2: 1172.',
#   'api_link': 'https://www.gbif.org/species/5451774'},
#  {'name': 'Agaricus nobilis',
#   'author': 'Bolton',
#   'publication_year': '1788',
#   'publication_name': 'Hist. Fung. Halifax (Huddersfield) 2: 46, Tab. 46.',
#   'api_link': 'https://www.gbif.org/species/3329091'},
#  {'name': 'Agaricus pseudoaurantiacus',
#   'author': 'Bull.',
#   'publication_year': '1792',
#   'publication_name': 'Hist. Champ. Fr. (Paris) 2(2): 673, Pl. 122.',
#   'api_link': 'https://www.gbif.org/species/3329092'},
#  {'name': 'Agaricus puellus',
#   'author': 'Batsch',
#   'publication_year': '1786',
#   'publication_name': 'Elench. Fung. (Halle): 59.',
#   'api_link': 'https://www.gbif.org/species/5452606'},
#  {'name': 'Amanita aureola',
#   'author': '(Kalchbr.) Sacc.',
#   'publication_year': '1887',
#   'publication_name': 'Syll. Fung. (Abellini) 5: 12.',
#   'api_link': 'https://www.gbif.org/species/5452441'},
#  {'name': 'Amanita circinnata',
#   'author': 'Gray',
#   'publication_year': '1821',
#   'publication_name': 'Nat. Arr. Brit. Pl. (London) 1: 600.',
#   'api_link': 'https://www.gbif.org/species/5452605'},
#  {'name': 'Amanita formosa',
#   'author': 'Gonn. & Rabenh.',
#   'publication_year': '1869',
#   'publication_name': 'Myc. Europ. (Dresden) 1-2: Tab. 10, Fig. 2.',
#   'api_link': 'https://www.gbif.org/species/5452657'},
#  {'name': 'Amanita muscaria',
#   'author': '(L.) Hook.',
#   'publication_year': '',
#   'publication_name': '',
#   'api_link': 'https://www.gbif.org/species/3329049'},
#  {'name': 'Amanita puella',
#   'author': '(Batsch) Gonnerm. & Rabenh.',
#   'publication_year': '',
#   'publication_name': '',
#   'api_link': 'https://www.gbif.org/species/5452294'},
#  {'name': 'Amanitaria muscaria',
#   'author': '(L.) E.-J.Gilbert',
#   'publication_year': '1940',
#   'publication_name': 'In Bresadola, Iconogr. mycol., Suppl. I (Milan) 27: 76.',
#   'api_link': 'https://www.gbif.org/species/3301084'},
#  {'name': 'Hypophyllum muscarium',
#   'author': '(L.) Paulet',
#   'publication_year': '1808',
#   'publication_name': 'Traité Champ. (Paris) 2: 346, Tab. 157, Figs 1-3 (’1793-1829′).',
#   'api_link': 'https://www.gbif.org/species/12357845'},
#  {'name': 'Venenarius muscarius',
#   'author': '(L.) Millsp.',
#   'publication_year': '1913',
#   'publication_name': 'West Virginia Geol. Surv., Ser. A 5(1): 131.',
#   'api_link': 'https://www.gbif.org/species/12282853'}]
# ============================================================
#   genbank  (GenBankAPI)
#   Species: Amanita muscaria
# ============================================================
# Synonyms returned: 1
# [{'name': 'Agaricus muscarius',
#   'author': 'U',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.ncbi.nlm.nih.gov/taxonomy/41956'}]
# ============================================================
#   index_fungorum  (IndexFungorumAPI)
#   Species: Amanita muscaria
# ============================================================
# IndexFungorumAPI fetch error [https://www.indexfungorum.org/ixfwebservice/fungus.asmx/NameSearch]: 401 Client Error: Unauthorized for url: https://www.indexfungorum.org/ixfwebservice/fungus.asmx/NameSearch?SearchText=Amanita+muscaria&AnywhereInText=false&MaxNumber=50
# Synonyms returned: 0
# []
# ============================================================
#   mushroomobs  (MushroomObserverAPI)
#   Species: Amanita muscaria
# ============================================================
# Synonyms returned: 2
# [{'name': 'Amanita amerimuscaria',
#   'author': 'Tulloss & Geml nom. prov.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://mushroomobserver.org/name/show_name/16015'},
#  {'name': 'Amanita muscaria',
#   'author': 'sensu auct. amer.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://mushroomobserver.org/name/show_name/28495'}]
# ============================================================
#   tropicos  (TropicosAPI)
#   Species: Quercus robur
# ============================================================
# Synonyms returned: 2
# [{'name': 'Quercus pedunculata',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.tropicos.org/name/13100434'},
#  {'name': 'Quercus robur subsp. eurobur',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.tropicos.org/name/13101404'}]

# %% [markdown]
# ---
# ## Symbiota Portals

# %%
_SYMBIOTA_PORTALS = [
    # (portal_key, base_url, species)
    ("mycoportal",     "https://mycoportal.org/portal",              "Amanita muscaria"),      # iconic, widely collected fungus
    ("lichen",         "https://lichenportal.org/portal",            "Cladonia cristatella"),  # British soldiers, very common N. American lichen
    ("bryophyte",      "https://bryophyteportal.org/portal",         "Polytrichum commune"),   # common haircap moss, global distribution
    ("cch2",           "https://cch2.org/portal",                    "Quercus agrifolia"),     # coast live oak, quintessential California plant
    ("sernec",         "https://sernecportal.org/portal",            "Magnolia grandiflora"),  # southern magnolia, iconic SE US tree
    ("nansh",          "https://nansh.org/portal",                   "Rudbeckia hirta"),       # black-eyed Susan, widespread N. American forb
    ("macroalgae",     "https://macroalgae.org/portal",              "Fucus vesiculosus"),     # bladderwrack, abundant N. Atlantic seaweed
    ("pterido",        "https://pteridoportal.org/portal",           "Pteridium aquilinum"),   # bracken fern, most widespread fern on Earth
    ("neherbaria",     "https://neherbaria.org/portal",              "Acer rubrum"),           # red maple, ubiquitous New England tree
    ("midatlantic",    "https://midatlanticherbaria.org/portal",     "Quercus rubra"),         # northern red oak, dominant mid-Atlantic hardwood
    ("swbiodiversity", "https://swbiodiversity.org/seinet",          "Larrea tridentata"),     # creosote bush, defining SW desert shrub
]

# %%
for portal_key, base_url, species in _SYMBIOTA_PORTALS:
    print(f"\n{'='*60}")
    print(f"  symbiota / {portal_key}")
    print(f"  URL:     {base_url}")
    print(f"  Species: {species}")
    print(f"{'='*60}")
    try:
        client = SymbiotaAPI(base_url=base_url, portal_name=portal_key)
        result = client.get_synonyms(species)
        print(f"Rows returned: {len(result)}")
        display(result)
    except Exception as e:
        print(f"ERROR: {e}")
# Out:
# ============================================================
#   symbiota / mycoportal
#   URL:     https://mycoportal.org/portal
#   Species: Amanita muscaria
# ============================================================
# [mycoportal] 'api/v2/taxonomy/search' succeeded: 1 result(s).
# [mycoportal] Found tid=95084 for 'Amanita muscaria' via search.
# [mycoportal] 'Amanita muscaria' is Accepted (tid=95084).
# [mycoportal] Scraped 0 synonym(s) from taxa page for tid=95084.
# [mycoportal] Synonym lookup complete: 1 record(s) built for 'Amanita muscaria'.
# Rows returned: 1
#   Source Name Kingdom         Phylum           Class       Family Subfamily  \
# 0  mycoportal   Fungi  Basidiomycota  Agaricomycetes  Amanitaceae
#
#      Genus   Species Source Species ID     Author Publication Name  \
# 0  Amanita  muscaria             95084  (L.) Lam.
#
#   Publication Year                                        Source Link  \
# 0                   https://mycoportal.org/portal/taxa/index.php?t...
#
#   GBIF Accepted Status
# 0             Accepted
# ============================================================
#   symbiota / lichen
#   URL:     https://lichenportal.org/portal
#   Species: Cladonia cristatella
# ============================================================
# [lichen] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Cladonia cristatella'.
# [lichen] 'api/v2/taxonomy' succeeded: 1 result(s).
# [lichen] Found tid=53394 for 'Cladonia cristatella' via search.
# [lichen] 'Cladonia cristatella' is Accepted (tid=53394).
# [lichen] Synonym lookup complete: 1 record(s) built for 'Cladonia cristatella'.
# Rows returned: 1
#   Source Name Kingdom      Phylum            Class        Family Subfamily  \
# 0      lichen   Fungi  Ascomycota  Lecanoromycetes  Cladoniaceae
#
#       Genus      Species Source Species ID Author Publication Name  \
# 0  Cladonia  cristatella             53394  Tuck.
#
#   Publication Year                                        Source Link  \
# 0                   https://lichenportal.org/portal/taxa/index.php...
#
#   GBIF Accepted Status
# 0             Accepted
# ============================================================
#   symbiota / bryophyte
#   URL:     https://bryophyteportal.org/portal
#   Species: Polytrichum commune
# ============================================================
# [bryophyte] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Polytrichum commune'.
# [bryophyte] 'api/v2/taxonomy' succeeded: 1 result(s).
# [bryophyte] Found tid=160442 for 'Polytrichum commune' via search.
# [bryophyte] 'Polytrichum commune' is Accepted (tid=160442).
# [bryophyte] Scraped 21 synonym(s) from taxa page for tid=160442.
# [bryophyte] Synonym lookup complete: 22 record(s) built for 'Polytrichum commune'.
# Rows returned: 22
#    Source Name  Kingdom     Phylum            Class          Family Subfamily  \
# 0    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 1    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 2    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 3    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 4    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 5    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 6    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 7    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 8    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 9    bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 10   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 11   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 12   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 13   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 14   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 15   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 16   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 17   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 18   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 19   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 20   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
# 21   bryophyte  Plantae  Bryophyta  Polytrichopsida  Polytrichaceae
#
#           Genus          Species Source Species ID  \
# 0   Polytrichum          commune            160442
# 1     Pogonatum       madagassum
# 2   Polytrichum         assimile
# 3   Polytrichum      brachypelma
# 4   Polytrichum       buchananii
# 5   Polytrichum     cataractarum
# 6   Polytrichum    deflexifolium
# 7   Polytrichum           elatum
# 8   Polytrichum      juccifolium
# 9   Polytrichum           leonii
# 10  Polytrichum       madagassum
# 11  Polytrichum      mildbraedii
# 12  Polytrichum       paludicola
# 13  Polytrichum      perigoniale
# 14  Polytrichum       propinquum
# 15  Polytrichum     purpurascens
# 16  Polytrichum    quadrangulare
# 17  Polytrichum     radulifolium
# 18  Polytrichum     remotifolium
# 19  Polytrichum  subremotifolium
# 20  Polytrichum       uliginosum
# 21  Polytrichum      yuccifolium
#
#                          Author Publication Name Publication Year  \
# 0                         Hedw.
# 1             (Hampe) A. Jaeger
# 2                         Hampe
# 3                         Hedw.
# 4                        Broth.
# 5                         Hedw.
# 6                       Warnst.
# 7                     P. Beauv.
# 8   Ehrh. ex F. Weber & D. Mohr
# 9                          Papp
# 10                        Hampe
# 11                       Broth.
# 12                       Cardot
# 13                       Michx.
# 14                       R. Br.
# 15                        Brid.
# 16                       Gilib.
# 17                   Müll. Hal.
# 18                    P. Beauv.
# 19                 Geh. & Hampe
# 20            (Wallr.) Schriebl
# 21               Ehrh. ex Funck
#
#                                           Source Link GBIF Accepted Status
# 0   https://bryophyteportal.org/portal/taxa/index....             Accepted
# 1                                                                  Synonym
# 2                                                                  Synonym
# 3                                                                  Synonym
# 4                                                                  Synonym
# 5                                                                  Synonym
# 6                                                                  Synonym
# 7                                                                  Synonym
# 8                                                                  Synonym
# 9                                                                  Synonym
# 10                                                                 Synonym
# 11                                                                 Synonym
# 12                                                                 Synonym
# 13                                                                 Synonym
# 14                                                                 Synonym
# 15                                                                 Synonym
# 16                                                                 Synonym
# 17                                                                 Synonym
# 18                                                                 Synonym
# 19                                                                 Synonym
# 20                                                                 Synonym
# 21                                                                 Synonym
# ============================================================
#   symbiota / cch2
#   URL:     https://cch2.org/portal
#   Species: Quercus agrifolia
# ============================================================
# [cch2] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Quercus agrifolia'.
# [cch2] 'api/v2/taxonomy' succeeded: 1 result(s).
# [cch2] Found tid=29223 for 'Quercus agrifolia' via search.
# [cch2] 'Quercus agrifolia' is Accepted (tid=29223).
# [cch2] Scraped 2 synonym(s) from taxa page for tid=29223.
# [cch2] Synonym lookup complete: 3 record(s) built for 'Quercus agrifolia'.
# Rows returned: 3
#   Source Name  Kingdom        Phylum          Class    Family Subfamily  \
# 0        cch2  Plantae  Streptophyta  Magnoliopsida  Fagaceae
# 1        cch2  Plantae  Streptophyta  Magnoliopsida  Fagaceae
# 2        cch2  Plantae  Streptophyta  Magnoliopsida  Fagaceae
#
#      Genus    Species Source Species ID Author Publication Name  \
# 0  Quercus  agrifolia             29223    Née
# 1  Quercus  oxyadenia                    Torr.
# 2  Quercus     pricei                    Sudw.
#
#   Publication Year                                        Source Link  \
# 0                   https://cch2.org/portal/taxa/index.php?taxon=2...
# 1
# 2
#
#   GBIF Accepted Status
# 0             Accepted
# 1              Synonym
# 2              Synonym
# ============================================================
#   symbiota / sernec
#   URL:     https://sernecportal.org/portal
#   Species: Magnolia grandiflora
# ============================================================
# [sernec] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Magnolia grandiflora'.
# [sernec] 'api/v2/taxonomy' succeeded: 1 result(s).
# [sernec] Found tid=17263 for 'Magnolia grandiflora' via search.
# [sernec] 'Magnolia grandiflora' is Accepted (tid=17263).
# [sernec] Scraped 2 synonym(s) from taxa page for tid=17263.
# [sernec] Synonym lookup complete: 3 record(s) built for 'Magnolia grandiflora'.
# Rows returned: 3
#   Source Name  Kingdom         Phylum       Class        Family Subfamily  \
# 0      sernec  Plantae  Magnoliophyta  Magnoliids  Magnoliaceae
# 1      sernec  Plantae  Magnoliophyta  Magnoliids  Magnoliaceae
# 2      sernec  Plantae  Magnoliophyta  Magnoliids  Magnoliaceae
#
#       Genus      Species Source Species ID Author Publication Name  \
# 0  Magnolia  grandiflora             17263     L.
# 1  Magnolia      foetida
# 2  Magnolia    tomentosa                     Ser.
#
#   Publication Year                                        Source Link  \
# 0                   https://sernecportal.org/portal/taxa/index.php...
# 1
# 2
#
#   GBIF Accepted Status
# 0             Accepted
# 1              Synonym
# 2              Synonym
# ============================================================
#   symbiota / nansh
#   URL:     https://nansh.org/portal
#   Species: Rudbeckia hirta
# ============================================================
# [nansh] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Rudbeckia hirta'.
# [nansh] 'api/v2/taxonomy' succeeded: 1 result(s).
# [nansh] Found tid=17308 for 'Rudbeckia hirta' via search.
# [nansh] 'Rudbeckia hirta' is Accepted (tid=17308).
# [nansh] Scraped 1 synonym(s) from taxa page for tid=17308.
# [nansh] Synonym lookup complete: 2 record(s) built for 'Rudbeckia hirta'.
# Rows returned: 2
#   Source Name  Kingdom         Phylum          Class      Family Subfamily  \
# 0       nansh  Plantae  Magnoliophyta  Core Eudicots  Asteraceae
# 1       nansh  Plantae  Magnoliophyta  Core Eudicots  Asteraceae
#
#        Genus Species Source Species ID Author Publication Name  \
# 0  Rudbeckia   hirta             17308     L.
# 1  Coreopsis   hirta                        ]
#
#   Publication Year                                        Source Link  \
# 0                   https://nansh.org/portal/taxa/index.php?taxon=...
# 1
#
#   GBIF Accepted Status
# 0             Accepted
# 1              Synonym
# ============================================================
#   symbiota / macroalgae
#   URL:     https://macroalgae.org/portal
#   Species: Fucus vesiculosus
# ============================================================
# [macroalgae] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Fucus vesiculosus'.
# [macroalgae] 'api/v2/taxonomy' succeeded: 1 result(s).
# [macroalgae] Found tid=39250 for 'Fucus vesiculosus' via search.
# [macroalgae] 'Fucus vesiculosus' is Accepted (tid=39250).
# [macroalgae] Scraped 5 synonym(s) from taxa page for tid=39250.
# [macroalgae] Synonym lookup complete: 6 record(s) built for 'Fucus vesiculosus'.
# Rows returned: 6
#   Source Name    Kingdom            Phylum         Class    Family Subfamily  \
# 0  macroalgae  Chromista  Heterokontophyta  Phaeophyceae  Fucaceae
# 1  macroalgae  Chromista  Heterokontophyta  Phaeophyceae  Fucaceae
# 2  macroalgae  Chromista  Heterokontophyta  Phaeophyceae  Fucaceae
# 3  macroalgae  Chromista  Heterokontophyta  Phaeophyceae  Fucaceae
# 4  macroalgae  Chromista  Heterokontophyta  Phaeophyceae  Fucaceae
# 5  macroalgae  Chromista  Heterokontophyta  Phaeophyceae  Fucaceae
#
#       Genus      Species Source Species ID                 Author  \
# 0     Fucus  vesiculosus             39250               Linnaeus
# 1     Fucus     balticus                                 C.Agardh
# 2     Fucus      excisus                                 Forsskål
# 3     Fucus     inflatus                                 Linnaeus
# 4     Fucus       mytili                                 Nienburg
# 5  Halidrys  vesiculosus                    (Linnaeus) Stackhouse
#
#   Publication Name Publication Year  \
# 0
# 1
# 2
# 3
# 4
# 5
#
#                                          Source Link GBIF Accepted Status
# 0  https://macroalgae.org/portal/taxa/index.php?t...             Accepted
# 1                                                                 Synonym
# 2                                                                 Synonym
# 3                                                                 Synonym
# 4                                                                 Synonym
# 5                                                                 Synonym
# ============================================================
#   symbiota / pterido
#   URL:     https://pteridoportal.org/portal
#   Species: Pteridium aquilinum
# ============================================================
# [pterido] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Pteridium aquilinum'.
# [pterido] 'api/v2/taxonomy' succeeded: 1 result(s).
# [pterido] Found tid=4505 for 'Pteridium aquilinum' via search.
# [pterido] 'Pteridium aquilinum' is Accepted (tid=4505).
# [pterido] Synonym lookup complete: 1 record(s) built for 'Pteridium aquilinum'.
# Rows returned: 1
#   Source Name  Kingdom        Phylum           Class            Family  \
# 0     pterido  Plantae  Tracheophyta  Polypodiopsida  Dennstaedtiaceae
#
#   Subfamily      Genus    Species Source Species ID Author Publication Name  \
# 0            Pteridium  aquilinum              4505
#
#   Publication Year                                        Source Link  \
# 0                   https://pteridoportal.org/portal/taxa/index.ph...
#
#   GBIF Accepted Status
# 0             Accepted
# ============================================================
#   symbiota / neherbaria
#   URL:     https://neherbaria.org/portal
#   Species: Acer rubrum
# ============================================================
# [neherbaria] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Acer rubrum'.
# [neherbaria] 'api/v2/taxonomy' succeeded: 1 result(s).
# [neherbaria] Found tid=815697 for 'Acer rubrum' via search.
# [neherbaria] 'Acer rubrum' is Accepted (tid=815697).
# [neherbaria] Scraped 1 synonym(s) from taxa page for tid=815697.
# [neherbaria] Synonym lookup complete: 2 record(s) built for 'Acer rubrum'.
# Rows returned: 2
#   Source Name  Kingdom      Phylum          Class       Family Subfamily  \
# 0  neherbaria  Plantae  Charophyta  Equisetopsida  Sapindaceae
# 1  neherbaria  Plantae  Charophyta  Equisetopsida  Sapindaceae
#
#   Genus  Species Source Species ID     Author Publication Name  \
# 0  Acer   rubrum            815697         L.
# 1  Acer  glaucum                    Marshall]
#
#   Publication Year                                        Source Link  \
# 0                   https://neherbaria.org/portal/taxa/index.php?t...
# 1
#
#   GBIF Accepted Status
# 0             Accepted
# 1              Synonym
# ============================================================
#   symbiota / midatlantic
#   URL:     https://midatlanticherbaria.org/portal
#   Species: Quercus rubra
# ============================================================
# [midatlantic] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Quercus rubra'.
# [midatlantic] 'api/v2/taxonomy' succeeded: 1 result(s).
# [midatlantic] Found tid=46960 for 'Quercus rubra' via search.
# [midatlantic] 'Quercus rubra' is Accepted (tid=46960).
# [midatlantic] Scraped 2 synonym(s) from taxa page for tid=46960.
# [midatlantic] Synonym lookup complete: 3 record(s) built for 'Quercus rubra'.
# Rows returned: 3
#    Source Name  Kingdom         Phylum          Class    Family Subfamily  \
# 0  midatlantic  Plantae  Magnoliophyta  Core Eudicots  Fagaceae
# 1  midatlantic  Plantae  Magnoliophyta  Core Eudicots  Fagaceae
# 2  midatlantic  Plantae  Magnoliophyta  Core Eudicots  Fagaceae
#
#      Genus   Species Source Species ID         Author Publication Name  \
# 0  Quercus     rubra             46960             L.
# 1  Quercus  borealis                        Michx. f.
# 2  Quercus    maxima                    (Marsh.) Ashe
#
#   Publication Year                                        Source Link  \
# 0                   https://midatlanticherbaria.org/portal/taxa/in...
# 1
# 2
#
#   GBIF Accepted Status
# 0             Accepted
# 1              Synonym
# 2              Synonym
# ============================================================
#   symbiota / swbiodiversity
#   URL:     https://swbiodiversity.org/seinet
#   Species: Larrea tridentata
# ============================================================
# [swbiodiversity] 'api/v2/taxonomy/search' returned HTTP 200 but no results for 'Larrea tridentata'.
# [swbiodiversity] 'api/v2/taxonomy' succeeded: 1 result(s).
# [swbiodiversity] Found tid=2671 for 'Larrea tridentata' via search.
# [swbiodiversity] 'Larrea tridentata' is Accepted (tid=2671).
# [swbiodiversity] Scraped 1 synonym(s) from taxa page for tid=2671.
# [swbiodiversity] Synonym lookup complete: 2 record(s) built for 'Larrea tridentata'.
# Rows returned: 2
#       Source Name  Kingdom         Phylum          Class          Family  \
# 0  swbiodiversity  Plantae  Magnoliophyta  Core Eudicots  Zygophyllaceae
# 1  swbiodiversity  Plantae  Magnoliophyta  Core Eudicots  Zygophyllaceae
#
#   Subfamily   Genus     Species Source Species ID  \
# 0            Larrea  tridentata              2671
# 1            Larrea    mexicana
#
#                           Author Publication Name Publication Year  \
# 0  (Sessé & Moc. ex DC.) Coville
# 1                         Moric.
#
#                                          Source Link GBIF Accepted Status
# 0  https://swbiodiversity.org/seinet/taxa/index.p...             Accepted
# 1                                                                 Synonym
