# %% [markdown]
# # Test: `get_synonyms()` for all APIs_pipe clients
#
# Run from the **project root** so that `scripts/` is on the Python path.
#
# Covers:
# - COL, GBIF, GenBank, Index Fungorum, MushroomObserver, Tropicos
# - Symbiota portals: MyCoPortal, Lichen, Bryophyte, CCH2, SERNEC, NANSH, Macroalgae, Pterido, NE Herbaria, Mid-Atlantic, SW Biodiversity

# %%
import time
import sys, os
# Ensure the project root is on sys.path when running from notebooks.apis_pipe/
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from IPython.display import display

from scripts.apis_pipe.col import COLAPI
from scripts.apis_pipe.gbif import GBIFAPI
from scripts.apis_pipe.genbank import GenBankAPI
from scripts.apis_pipe.index_fungorum import IndexFungorumAPI
from scripts.apis_pipe.mushroomobs import MushroomObserverAPI
from scripts.apis_pipe.symbiota import SymbiotaAPI
from scripts.apis_pipe.tropicos import TropicosAPI
from scripts.apis_pipe.fishbase import FishBaseAPI

# %% [markdown]
# ---
# ## Standard APIs

# %%
from scripts.apis_pipe.config import (
    COL_PORTAL,
    GBIF_PORTAL,
    INDEX_FUNGORUM_PORTAL,
    MUSHROOM_OBSERVER_PORTAL,
    TROPICOS_PORTAL,
    FISHBASE_PORTAL
)

STANDARD_QUERIES = [
    # (portal, client, accepted_species, synonym_of_accepted)
    # (COL_PORTAL,               COLAPI(),              "Quercus robur",    "Quercus atrosanguinea"),
    # (GBIF_PORTAL,              GBIFAPI(),             "Amanita muscaria", "Agaricus muscarius"),
    # (INDEX_FUNGORUM_PORTAL,    IndexFungorumAPI(),    "Amanita muscaria", "Agaricus muscarius"),
    # (MUSHROOM_OBSERVER_PORTAL, MushroomObserverAPI(), "Amanita muscaria", "Amanita amerimuscaria"),
    # (TROPICOS_PORTAL,          TropicosAPI(),         "Quercus robur",    "Quercus pedunculata"),
    (FISHBASE_PORTAL,          FishBaseAPI(),         "Gadus morhua",     "Gadus callarias"),
]

# %%
# display(GBIFAPI().get_synonyms("Agaricus muscarius"))
# Out:
#    api_name kingdom phylum class family subfamily        genus  \
# 0      GBIF       U      U     U      U         U      Amanita
# 1      GBIF       U      U     U      U         U     Agaricus
# 2      GBIF       U      U     U      U         U     Agaricus
# 3      GBIF       U      U     U      U         U     Agaricus
# 4      GBIF       U      U     U      U         U     Agaricus
# 5      GBIF       U      U     U      U         U     Agaricus
# 6      GBIF       U      U     U      U         U     Agaricus
# 7      GBIF       U      U     U      U         U      Amanita
# 8      GBIF       U      U     U      U         U      Amanita
# 9      GBIF       U      U     U      U         U      Amanita
# 10     GBIF       U      U     U      U         U      Amanita
# 11     GBIF       U      U     U      U         U      Amanita
# 12     GBIF       U      U     U      U         U   Amanitaria
# 13     GBIF       U      U     U      U         U  Hypophyllum
# 14     GBIF       U      U     U      U         U   Venenarius
#
#               species                       author  \
# 0            muscaria                    (L.) Lam.
# 1            aureolus                     Kalchbr.
# 2          imperialis                       Batsch
# 3           muscarius                           L.
# 4             nobilis                       Bolton
# 5   pseudoaurantiacus                        Bull.
# 6             puellus                       Batsch
# 7             aureola             (Kalchbr.) Sacc.
# 8          circinnata                         Gray
# 9             formosa              Gonn. & Rabenh.
# 10           muscaria                   (L.) Hook.
# 11             puella  (Batsch) Gonnerm. & Rabenh.
# 12           muscaria            (L.) E.-J.Gilbert
# 13          muscarium                  (L.) Paulet
# 14          muscarius                 (L.) Millsp.
#
#                                      publication_name publication_year status  \
# 0               Encycl. Méth. Bot. (Paris) 1(1): 111.             1783      U
# 1        Icon. Sel. Hymenomyc. Hung. (Budapest) 1: 9.             1873      U
# 2                          Elench. Fung. (Halle): 59.             1783      U
# 3                                    Sp. Pl. 2: 1172.             1753      U
# 4   Hist. Fung. Halifax (Huddersfield) 2: 46, Tab....             1788      U
# 5        Hist. Champ. Fr. (Paris) 2(2): 673, Pl. 122.             1792      U
# 6                          Elench. Fung. (Halle): 59.             1786      U
# 7                       Syll. Fung. (Abellini) 5: 12.             1887      U
# 8                Nat. Arr. Brit. Pl. (London) 1: 600.             1821      U
# 9         Myc. Europ. (Dresden) 1-2: Tab. 10, Fig. 2.             1869      U
# 10                                                                          U
# 11                                                                          U
# 12  In Bresadola, Iconogr. mycol., Suppl. I (Milan...             1940      U
# 13  Traité Champ. (Paris) 2: 346, Tab. 157, Figs 1...             1808      U
# 14       West Virginia Geol. Surv., Ser. A 5(1): 131.             1913      U
#
#    source_name                               api_link api_internal_id
# 0            U   https://www.gbif.org/species/8168319         8168319
# 1            U   https://www.gbif.org/species/5455639         5455639
# 2            U   https://www.gbif.org/species/5955425         5955425
# 3            U   https://www.gbif.org/species/5451774         5451774
# 4            U   https://www.gbif.org/species/3329091         3329091
# 5            U   https://www.gbif.org/species/3329092         3329092
# 6            U   https://www.gbif.org/species/5452606         5452606
# 7            U   https://www.gbif.org/species/5452441         5452441
# 8            U   https://www.gbif.org/species/5452605         5452605
# 9            U   https://www.gbif.org/species/5452657         5452657
# 10           U   https://www.gbif.org/species/3329049         3329049
# 11           U   https://www.gbif.org/species/5452294         5452294
# 12           U   https://www.gbif.org/species/3301084         3301084
# 13           U  https://www.gbif.org/species/12357845        12357845
# 14           U  https://www.gbif.org/species/12282853        12282853

# %%
for portal, client, accepted, synonym in STANDARD_QUERIES:
    for species, name_type in [(accepted, "accepted"), (synonym, "synonym")]:
        print(f"\n{'='*60}")
        print(f"  {portal.display_name}  ({client.__class__.__name__})")
        print(f"  Species:   {species}")
        print(f"  Name type: {name_type}  (synonym of: {accepted})" if name_type == "synonym" else f"  Name type: {name_type}")
        print(f"{'='*60}")
        try:
            result = client.get_synonyms(species)
            print(f"Synonyms returned: {len(result)}")
            display(result)
        except Exception as e:
            print(f"ERROR: {e}")
# Out:
# ============================================================
#   COL  (COLAPI)
#   Species:   Quercus robur
#   Name type: accepted
# ============================================================
# Synonyms returned: 17
#    api_name kingdom phylum class family subfamily    genus          species  \
# 0       COL       U      U     U      U         U  Quercus            robur
# 1       COL       U      U     U      U         U  Quercus    atrosanguinea
# 2       COL       U      U     U      U         U  Quercus          belgica
# 3       COL       U      U     U      U         U  Quercus     cupressoides
# 4       COL       U      U     U      U         U  Quercus          feminea
# 5       COL       U      U     U      U         U  Quercus      filicifolia
# 6       COL       U      U     U      U         U  Quercus          foemida
# 7       COL       U      U     U      U         U  Quercus          hentzei
# 8       COL       U      U     U      U         U  Quercus      hohenackeri
# 9       COL       U      U     U      U         U  Quercus         louettii
# 10      COL       U      U     U      U         U  Quercus     malacophylla
# 11      COL       U      U     U      U         U  Quercus      pedunculata
# 12      COL       U      U     U      U         U  Quercus  pseudopeduncula
# 13      COL       U      U     U      U         U  Quercus            robur
# 14      COL       U      U     U      U         U  Quercus            robur
# 15      COL       U      U     U      U         U  Quercus            robur
# 16      COL       U      U     U      U         U  Quercus        transiens
#
#                  author publication_name publication_year status source_name  \
# 0                    L.                U                U      U           U
# 1                 hort.                U                U      U           U
# 2                 Gand.                U                U      U           U
# 3                 hort.                U                U      U           U
# 4                 Mill.                U                U      U           U
# 5        hort. ex A.DC.                U                U      U           U
# 6                 Mill.                U                U      U           U
# 7                 Petz.                U                U      U           U
# 8                 Gand.                U                U      U           U
# 9                Dippel                U                U      U           U
# 10               Borbás                U                U      U           U
# 11                Ehrh.                U                U      U           U
# 12                 Vuk.                U                U      U           U
# 13  (Loudon) O. Schwarz                U                U      U           U
# 14                 Vuk.                U                U      U           U
# 15     (Hoffm.) Hook.f.                U                U      U           U
# 16              A.Reyn.                U                U      U           U
#
#                                             api_link api_internal_id
# 0   https://www.catalogueoflife.org/data/taxon/4R5YN           4R5YN
# 1   https://www.catalogueoflife.org/data/taxon/SF5RP           SF5RP
# 2   https://www.catalogueoflife.org/data/taxon/8X4Z4           8X4Z4
# 3   https://www.catalogueoflife.org/data/taxon/SFBKJ           SFBKJ
# 4   https://www.catalogueoflife.org/data/taxon/SFDVF           SFDVF
# 5   https://www.catalogueoflife.org/data/taxon/SFDXP           SFDXP
# 6   https://www.catalogueoflife.org/data/taxon/4R4Y4           4R4Y4
# 7   https://www.catalogueoflife.org/data/taxon/SFGZ6           SFGZ6
# 8   https://www.catalogueoflife.org/data/taxon/8X52M           8X52M
# 9   https://www.catalogueoflife.org/data/taxon/SFMTB           SFMTB
# 10  https://www.catalogueoflife.org/data/taxon/5R46R           5R46R
# 11  https://www.catalogueoflife.org/data/taxon/SFRGP           SFRGP
# 12  https://www.catalogueoflife.org/data/taxon/SFSTJ           SFSTJ
# 13  https://www.catalogueoflife.org/data/taxon/SFV5H           SFV5H
# 14  https://www.catalogueoflife.org/data/taxon/5R4FK           5R4FK
# 15  https://www.catalogueoflife.org/data/taxon/5R4GP           5R4GP
# 16  https://www.catalogueoflife.org/data/taxon/CDY39           CDY39
# ============================================================
#   COL  (COLAPI)
#   Species:   Quercus atrosanguinea
#   Name type: synonym  (synonym of: Quercus robur)
# ============================================================
# Synonyms returned: 356
#     api_name kingdom phylum class family subfamily    genus       species  \
# 0        COL       U      U     U      U         U  Quercus         robur
# 1        COL       U      U     U      U         U  Quercus    abbreviata
# 2        COL       U      U     U      U         U  Quercus     accessiva
# 3        COL       U      U     U      U         U  Quercus    accomodata
# 4        COL       U      U     U      U         U  Quercus     acutiloba
# ..       ...     ...    ...   ...    ...       ...      ...           ...
# 351      COL       U      U     U      U         U  Quercus  sessiliflora
# 352      COL       U      U     U      U         U  Quercus     tomentosa
# 353      COL       U      U     U      U         U  Quercus       tristis
# 354      COL       U      U     U      U         U  Quercus     turbinata
# 355      COL       U      U     U      U         U  Quercus     vallicola
#
#               author publication_name publication_year status source_name  \
# 0                                   U                U      U           U
# 1               Vuk.                U                U      U           U
# 2              Gand.                U                U      U           U
# 3              Gand.                U                U      U           U
# 4             Borbás                U                U      U           U
# ..               ...              ...              ...    ...         ...
# 351  (Lapeyr.) Nyman                U                U      U           U
# 352   Ehrh. ex A.DC.                U                U      U           U
# 353            Gand.                U                U      U           U
# 354             Kit.                U                U      U           U
# 355            Gand.                U                U      U           U
#
#                                              api_link api_internal_id
# 0    https://www.catalogueoflife.org/data/taxon/5KTTT           5KTTT
# 1    https://www.catalogueoflife.org/data/taxon/4R45Z           4R45Z
# 2    https://www.catalogueoflife.org/data/taxon/8X4Y9           8X4Y9
# 3    https://www.catalogueoflife.org/data/taxon/8X4YB           8X4YB
# 4    https://www.catalogueoflife.org/data/taxon/4R46X           4R46X
# ..                                                ...             ...
# 351  https://www.catalogueoflife.org/data/taxon/5R4L3           5R4L3
# 352  https://www.catalogueoflife.org/data/taxon/8X4FJ           8X4FJ
# 353  https://www.catalogueoflife.org/data/taxon/8X4FN           8X4FN
# 354  https://www.catalogueoflife.org/data/taxon/4R6CC           4R6CC
# 355  https://www.catalogueoflife.org/data/taxon/8X4FT           8X4FT
#
# [356 rows x 15 columns]
# ============================================================
#   GBIF  (GBIFAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# Synonyms returned: 15
#    api_name kingdom phylum class family subfamily        genus  \
# 0      GBIF       U      U     U      U         U      Amanita
# 1      GBIF       U      U     U      U         U     Agaricus
# 2      GBIF       U      U     U      U         U     Agaricus
# 3      GBIF       U      U     U      U         U     Agaricus
# 4      GBIF       U      U     U      U         U     Agaricus
# 5      GBIF       U      U     U      U         U     Agaricus
# 6      GBIF       U      U     U      U         U     Agaricus
# 7      GBIF       U      U     U      U         U      Amanita
# 8      GBIF       U      U     U      U         U      Amanita
# 9      GBIF       U      U     U      U         U      Amanita
# 10     GBIF       U      U     U      U         U      Amanita
# 11     GBIF       U      U     U      U         U      Amanita
# 12     GBIF       U      U     U      U         U   Amanitaria
# 13     GBIF       U      U     U      U         U  Hypophyllum
# 14     GBIF       U      U     U      U         U   Venenarius
#
#               species                       author  \
# 0            muscaria
# 1            aureolus                     Kalchbr.
# 2          imperialis                       Batsch
# 3           muscarius                           L.
# 4             nobilis                       Bolton
# 5   pseudoaurantiacus                        Bull.
# 6             puellus                       Batsch
# 7             aureola             (Kalchbr.) Sacc.
# 8          circinnata                         Gray
# 9             formosa              Gonn. & Rabenh.
# 10           muscaria                   (L.) Hook.
# 11             puella  (Batsch) Gonnerm. & Rabenh.
# 12           muscaria            (L.) E.-J.Gilbert
# 13          muscarium                  (L.) Paulet
# 14          muscarius                 (L.) Millsp.
#
#                                      publication_name publication_year status  \
# 0                                                                           U
# 1        Icon. Sel. Hymenomyc. Hung. (Budapest) 1: 9.             1873      U
# 2                          Elench. Fung. (Halle): 59.             1783      U
# 3                                    Sp. Pl. 2: 1172.             1753      U
# 4   Hist. Fung. Halifax (Huddersfield) 2: 46, Tab....             1788      U
# 5        Hist. Champ. Fr. (Paris) 2(2): 673, Pl. 122.             1792      U
# 6                          Elench. Fung. (Halle): 59.             1786      U
# 7                       Syll. Fung. (Abellini) 5: 12.             1887      U
# 8                Nat. Arr. Brit. Pl. (London) 1: 600.             1821      U
# 9         Myc. Europ. (Dresden) 1-2: Tab. 10, Fig. 2.             1869      U
# 10                                                                          U
# 11                                                                          U
# 12  In Bresadola, Iconogr. mycol., Suppl. I (Milan...             1940      U
# 13  Traité Champ. (Paris) 2: 346, Tab. 157, Figs 1...             1808      U
# 14       West Virginia Geol. Surv., Ser. A 5(1): 131.             1913      U
#
#    source_name                               api_link api_internal_id
# 0            U   https://www.gbif.org/species/8168319         8168319
# 1            U   https://www.gbif.org/species/5455639         5455639
# 2            U   https://www.gbif.org/species/5955425         5955425
# 3            U   https://www.gbif.org/species/5451774         5451774
# 4            U   https://www.gbif.org/species/3329091         3329091
# 5            U   https://www.gbif.org/species/3329092         3329092
# 6            U   https://www.gbif.org/species/5452606         5452606
# 7            U   https://www.gbif.org/species/5452441         5452441
# 8            U   https://www.gbif.org/species/5452605         5452605
# 9            U   https://www.gbif.org/species/5452657         5452657
# 10           U   https://www.gbif.org/species/3329049         3329049
# 11           U   https://www.gbif.org/species/5452294         5452294
# 12           U   https://www.gbif.org/species/3301084         3301084
# 13           U  https://www.gbif.org/species/12357845        12357845
# 14           U  https://www.gbif.org/species/12282853        12282853
# ============================================================
#   GBIF  (GBIFAPI)
#   Species:   Agaricus muscarius
#   Name type: synonym  (synonym of: Amanita muscaria)
# ============================================================
# Synonyms returned: 15
#    api_name kingdom phylum class family subfamily        genus  \
# 0      GBIF       U      U     U      U         U      Amanita
# 1      GBIF       U      U     U      U         U     Agaricus
# 2      GBIF       U      U     U      U         U     Agaricus
# 3      GBIF       U      U     U      U         U     Agaricus
# 4      GBIF       U      U     U      U         U     Agaricus
# 5      GBIF       U      U     U      U         U     Agaricus
# 6      GBIF       U      U     U      U         U     Agaricus
# 7      GBIF       U      U     U      U         U      Amanita
# 8      GBIF       U      U     U      U         U      Amanita
# 9      GBIF       U      U     U      U         U      Amanita
# 10     GBIF       U      U     U      U         U      Amanita
# 11     GBIF       U      U     U      U         U      Amanita
# 12     GBIF       U      U     U      U         U   Amanitaria
# 13     GBIF       U      U     U      U         U  Hypophyllum
# 14     GBIF       U      U     U      U         U   Venenarius
#
#               species                       author  \
# 0            muscaria                    (L.) Lam.
# 1            aureolus                     Kalchbr.
# 2          imperialis                       Batsch
# 3           muscarius                           L.
# 4             nobilis                       Bolton
# 5   pseudoaurantiacus                        Bull.
# 6             puellus                       Batsch
# 7             aureola             (Kalchbr.) Sacc.
# 8          circinnata                         Gray
# 9             formosa              Gonn. & Rabenh.
# 10           muscaria                   (L.) Hook.
# 11             puella  (Batsch) Gonnerm. & Rabenh.
# 12           muscaria            (L.) E.-J.Gilbert
# 13          muscarium                  (L.) Paulet
# 14          muscarius                 (L.) Millsp.
#
#                                      publication_name publication_year status  \
# 0               Encycl. Méth. Bot. (Paris) 1(1): 111.             1783      U
# 1        Icon. Sel. Hymenomyc. Hung. (Budapest) 1: 9.             1873      U
# 2                          Elench. Fung. (Halle): 59.             1783      U
# 3                                    Sp. Pl. 2: 1172.             1753      U
# 4   Hist. Fung. Halifax (Huddersfield) 2: 46, Tab....             1788      U
# 5        Hist. Champ. Fr. (Paris) 2(2): 673, Pl. 122.             1792      U
# 6                          Elench. Fung. (Halle): 59.             1786      U
# 7                       Syll. Fung. (Abellini) 5: 12.             1887      U
# 8                Nat. Arr. Brit. Pl. (London) 1: 600.             1821      U
# 9         Myc. Europ. (Dresden) 1-2: Tab. 10, Fig. 2.             1869      U
# 10                                                                          U
# 11                                                                          U
# 12  In Bresadola, Iconogr. mycol., Suppl. I (Milan...             1940      U
# 13  Traité Champ. (Paris) 2: 346, Tab. 157, Figs 1...             1808      U
# 14       West Virginia Geol. Surv., Ser. A 5(1): 131.             1913      U
#
#    source_name                               api_link api_internal_id
# 0            U   https://www.gbif.org/species/8168319         8168319
# 1            U   https://www.gbif.org/species/5455639         5455639
# 2            U   https://www.gbif.org/species/5955425         5955425
# 3            U   https://www.gbif.org/species/5451774         5451774
# 4            U   https://www.gbif.org/species/3329091         3329091
# 5            U   https://www.gbif.org/species/3329092         3329092
# 6            U   https://www.gbif.org/species/5452606         5452606
# 7            U   https://www.gbif.org/species/5452441         5452441
# 8            U   https://www.gbif.org/species/5452605         5452605
# 9            U   https://www.gbif.org/species/5452657         5452657
# 10           U   https://www.gbif.org/species/3329049         3329049
# 11           U   https://www.gbif.org/species/5452294         5452294
# 12           U   https://www.gbif.org/species/3301084         3301084
# 13           U  https://www.gbif.org/species/12357845        12357845
# 14           U  https://www.gbif.org/species/12282853        12282853
# ============================================================
#   Index Fungorum  (IndexFungorumAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# Synonyms returned: 13
#           api_name kingdom phylum class family subfamily        genus  \
# 0   Index Fungorum       U      U     U      U         U     Agaricus
# 1   Index Fungorum       U      U     U      U         U     Agaricus
# 2   Index Fungorum       U      U     U      U         U     Agaricus
# 3   Index Fungorum       U      U     U      U         U     Agaricus
# 4   Index Fungorum       U      U     U      U         U     Agaricus
# 5   Index Fungorum       U      U     U      U         U     Agaricus
# 6   Index Fungorum       U      U     U      U         U      Amanita
# 7   Index Fungorum       U      U     U      U         U      Amanita
# 8   Index Fungorum       U      U     U      U         U      Amanita
# 9   Index Fungorum       U      U     U      U         U      Amanita
# 10  Index Fungorum       U      U     U      U         U   Amanitaria
# 11  Index Fungorum       U      U     U      U         U  Hypophyllum
# 12  Index Fungorum       U      U     U      U         U   Venenarius
#
#               species              author publication_name publication_year  \
# 0            aureolus            Kalchbr.                U                U
# 1          imperialis              Batsch                U                U
# 2           muscarius                  L.                U                U
# 3             nobilis              Bolton                U                U
# 4   pseudoaurantiacus               Bull.                U                U
# 5             puellus              Batsch                U                U
# 6             aureola    (Kalchbr.) Sacc.                U                U
# 7          circinnata                Gray                U                U
# 8             formosa     Gonn. & Rabenh.                U                U
# 9            muscaria           (L.) Lam.                U                U
# 10           muscaria  (L.) E.-J. Gilbert                U                U
# 11          muscarium         (L.) Paulet                U                U
# 12          muscarius          (L.) Earle                U                U
#
#    status source_name                                           api_link  \
# 0       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 1       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 2       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 3       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 4       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 5       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 6       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 7       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 8       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 9       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 10      U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 11      U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 12      U           U  https://www.indexfungorum.org/Names/NamesRecor...
#
#    api_internal_id
# 0           298478
# 1           495382
# 2           375287
# 3           450473
# 4           494787
# 5           372222
# 6           209653
# 7           486444
# 8           212977
# 9           161267
# 10          284092
# 11          652473
# 12          100185
# ============================================================
#   Index Fungorum  (IndexFungorumAPI)
#   Species:   Agaricus muscarius
#   Name type: synonym  (synonym of: Amanita muscaria)
# ============================================================
# Synonyms returned: 13
#           api_name kingdom phylum class family subfamily        genus  \
# 0   Index Fungorum       U      U     U      U         U     Agaricus
# 1   Index Fungorum       U      U     U      U         U     Agaricus
# 2   Index Fungorum       U      U     U      U         U     Agaricus
# 3   Index Fungorum       U      U     U      U         U     Agaricus
# 4   Index Fungorum       U      U     U      U         U     Agaricus
# 5   Index Fungorum       U      U     U      U         U     Agaricus
# 6   Index Fungorum       U      U     U      U         U      Amanita
# 7   Index Fungorum       U      U     U      U         U      Amanita
# 8   Index Fungorum       U      U     U      U         U      Amanita
# 9   Index Fungorum       U      U     U      U         U      Amanita
# 10  Index Fungorum       U      U     U      U         U   Amanitaria
# 11  Index Fungorum       U      U     U      U         U  Hypophyllum
# 12  Index Fungorum       U      U     U      U         U   Venenarius
#
#               species              author publication_name publication_year  \
# 0            aureolus            Kalchbr.                U                U
# 1          imperialis              Batsch                U                U
# 2           muscarius                  L.                U                U
# 3             nobilis              Bolton                U                U
# 4   pseudoaurantiacus               Bull.                U                U
# 5             puellus              Batsch                U                U
# 6             aureola    (Kalchbr.) Sacc.                U                U
# 7          circinnata                Gray                U                U
# 8             formosa     Gonn. & Rabenh.                U                U
# 9            muscaria           (L.) Lam.                U                U
# 10           muscaria  (L.) E.-J. Gilbert                U                U
# 11          muscarium         (L.) Paulet                U                U
# 12          muscarius          (L.) Earle                U                U
#
#    status source_name                                           api_link  \
# 0       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 1       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 2       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 3       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 4       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 5       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 6       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 7       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 8       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 9       U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 10      U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 11      U           U  https://www.indexfungorum.org/Names/NamesRecor...
# 12      U           U  https://www.indexfungorum.org/Names/NamesRecor...
#
#    api_internal_id
# 0           298478
# 1           495382
# 2           375287
# 3           450473
# 4           494787
# 5           372222
# 6           209653
# 7           486444
# 8           212977
# 9           161267
# 10          284092
# 11          652473
# 12          100185
# ============================================================
#   Mushroom Observer  (MushroomObserverAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# Synonyms returned: 3
#             api_name kingdom phylum class family subfamily    genus  \
# 0  Mushroom Observer       U      U     U      U         U  Amanita
# 1  Mushroom Observer       U      U     U      U         U  Amanita
# 2  Mushroom Observer       U      U     U      U         U  Amanita
#
#          species                     author publication_name publication_year  \
# 0       muscaria                  (L.) Lam.                U                U
# 1  amerimuscaria  Tulloss & Geml nom. prov.                U                U
# 2       muscaria          sensu auct. amer.                U                U
#
#   status source_name api_link api_internal_id
# 0      U           U        U             373
# 1      U           U        U           16015
# 2      U           U        U           28495
# ============================================================
#   Mushroom Observer  (MushroomObserverAPI)
#   Species:   Amanita amerimuscaria
#   Name type: synonym  (synonym of: Amanita muscaria)
# ============================================================
# Synonyms returned: 3
#             api_name kingdom phylum class family subfamily    genus  \
# 0  Mushroom Observer       U      U     U      U         U  Amanita
# 1  Mushroom Observer       U      U     U      U         U  Amanita
# 2  Mushroom Observer       U      U     U      U         U  Amanita
#
#          species                     author publication_name publication_year  \
# 0  amerimuscaria  Tulloss & Geml nom. prov.                U                U
# 1  amerimuscaria  Tulloss & Geml nom. prov.                U                U
# 2       muscaria          sensu auct. amer.                U                U
#
#   status source_name api_link api_internal_id
# 0      U           U        U           16015
# 1      U           U        U           16015
# 2      U           U        U           28495
# ============================================================
#   Tropicos  (TropicosAPI)
#   Species:   Quercus robur
#   Name type: accepted
# ============================================================
# Synonyms returned: 2
#    api_name kingdom phylum class family subfamily    genus      species  \
# 0  Tropicos       U      U     U      U         U  Quercus        robur
# 1  Tropicos       U      U     U      U         U  Quercus  pedunculata
#
#   author publication_name publication_year status source_name  \
# 0     L.                U                U      U           U
# 1                       U                U      U           U
#
#                                  api_link api_internal_id
# 0  https://www.tropicos.org/name/13100004        13100004
# 1  https://www.tropicos.org/name/13100434        13100434
# ============================================================
#   Tropicos  (TropicosAPI)
#   Species:   Quercus pedunculata
#   Name type: synonym  (synonym of: Quercus robur)
# ============================================================
# Synonyms returned: 2
#    api_name kingdom phylum class family subfamily    genus      species  \
# 0  Tropicos       U      U     U      U         U  Quercus        robur
# 1  Tropicos       U      U     U      U         U  Quercus  pedunculata
#
#   author publication_name publication_year status source_name  \
# 0     L.                U                U      U           U
# 1                       U                U      U           U
#
#                                  api_link api_internal_id
# 0  https://www.tropicos.org/name/13100004        13100004
# 1  https://www.tropicos.org/name/13100434        13100434

# %%
from scripts.apis_pipe.config import GENBANK_PORTAL

# GenBank is run separately because NCBI rate-limits unauthenticated callers
# to 3 req/s. Each get_synonyms() makes 2 requests (esearch + efetch), so we
# sleep 1s between calls to stay well under the limit.
GENBANK_QUERIES = [
    ("Amanita muscaria",   "accepted"),
    ("Agaricus muscarius", "synonym"),
]
genbank_client = GenBankAPI()
for species, name_type in GENBANK_QUERIES:
    print(f"\n{'='*60}")
    print(f"  {GENBANK_PORTAL.display_name}  (GenBankAPI)")
    print(f"  Species:   {species}")
    print(f"  Name type: {name_type}")
    print(f"{'='*60}")
    try:
        result = genbank_client.get_synonyms(species)
        print(f"Synonyms returned: {len(result)}")
        display(result)
    except Exception as e:
        print(f"ERROR: {e}")
    time.sleep(1.0)  # NCBI rate limit: max 3 req/s; each call makes 2 requests
# Out:
# ============================================================
#   GenBank  (GenBankAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# Synonyms returned: 2
#   api_name kingdom phylum class family subfamily     genus    species author  \
# 0  GenBank       U      U     U      U         U   Amanita   muscaria      U
# 1  GenBank       U      U     U      U         U  Agaricus  muscarius      U
#
#   publication_name publication_year status source_name  \
# 0                U                U      U           U
# 1                U                U      U           U
#
#                                       api_link api_internal_id
# 0  https://www.ncbi.nlm.nih.gov/taxonomy/41956           41956
# 1  https://www.ncbi.nlm.nih.gov/taxonomy/41956           41956
# ============================================================
#   GenBank  (GenBankAPI)
#   Species:   Agaricus muscarius
#   Name type: synonym
# ============================================================
# Synonyms returned: 2
#   api_name kingdom phylum class family subfamily     genus    species author  \
# 0  GenBank       U      U     U      U         U   Amanita   muscaria      U
# 1  GenBank       U      U     U      U         U  Agaricus  muscarius      U
#
#   publication_name publication_year status source_name  \
# 0                U                U      U           U
# 1                U                U      U           U
#
#                                       api_link api_internal_id
# 0  https://www.ncbi.nlm.nih.gov/taxonomy/41956           41956
# 1  https://www.ncbi.nlm.nih.gov/taxonomy/41956           41956

# %% [markdown]
# ---
# ## Symbiota Portals

# %%
from scripts.apis_pipe.config import SYMBIOTA_PORTAL_BY_NAME

_SYMBIOTA_QUERIES = [
    # (portal, accepted_species, synonym_of_accepted)
    (SYMBIOTA_PORTAL_BY_NAME["MyCoPortal"],                    "Agaricus campestris",     "Psalliota villatica"),
    (SYMBIOTA_PORTAL_BY_NAME["Lichen Portal"],                 "Xanthoria parietina",     "Physcia parietina"),
    (SYMBIOTA_PORTAL_BY_NAME["Bryophyte Portal"],              "Pohlia nutans",           "Webera nutans"),
    # Photinia arbutifolia is a synonym OF Heteromeles arbutifolia (toyon)
    (SYMBIOTA_PORTAL_BY_NAME["CCH2"],                          "Heteromeles arbutifolia", "Photinia arbutifolia"),
    (SYMBIOTA_PORTAL_BY_NAME["SERNEC"],                        "Magnolia grandiflora",    "Magnolia foetida"),
    (SYMBIOTA_PORTAL_BY_NAME["NANSH"],                         "Rudbeckia hirta",         "Coreopsis hirta"),
    (SYMBIOTA_PORTAL_BY_NAME["Algae Herbarium Portal"],        "Ulva intestinalis",       "Ilea intestinalis"),
    (SYMBIOTA_PORTAL_BY_NAME["Pterido Portal"],                "Dryopteris filix-mas",    "Nephrodium filix-mas"),
    (SYMBIOTA_PORTAL_BY_NAME["CNH"],                           "Impatiens capensis",      "Impatiens biflora"),
    (SYMBIOTA_PORTAL_BY_NAME["Mid-Atlantic Herbaria Consortium"], "Quercus rubra",         "Quercus maxima"),
    (SYMBIOTA_PORTAL_BY_NAME["swbiodiversity"],                "Larrea tridentata",       "Larrea mexicana"),
]

# %%
for portal, accepted, synonym in _SYMBIOTA_QUERIES:
    for species, name_type in [(accepted, "accepted"), (synonym, "synonym")]:
        print(f"\n{'='*60}")
        print(f"  symbiota / {portal.display_name}")
        print(f"  URL:       {portal.base_url}")
        print(f"  Species:   {species}")
        print(f"  Name type: {name_type}  (synonym of: {accepted})" if name_type == "synonym" else f"  Name type: {name_type}")
        print(f"{'='*60}")
        try:
            client = SymbiotaAPI(portal.display_name)
            result = client.get_synonyms(species)
            print(f"Synonyms returned: {len(result)}")
            display(result)
        except Exception as e:
            print(f"ERROR: {e}")
# Out:
# ============================================================
#   symbiota / MyCoPortal
#   URL:       https://mycoportal.org/portal
#   Species:   Agaricus campestris
#   Name type: accepted
# ============================================================
# [MyCoPortal] 'api/v2/taxonomy/search' returned results for 'Agaricus campestris'.
# Synonyms returned: 2
#      api_name kingdom phylum class family subfamily      genus     species  \
# 0  MyCoPortal       U      U     U      U         U   Agaricus  campestris
# 1  MyCoPortal       U      U     U      U         U  Psalliota   villatica
#
#             author publication_name publication_year status source_name  \
# 0               L.                U                U      U           U
# 1  (Brond.) Bres.]                U                U      U           U
#
#                                             api_link api_internal_id
# 0  https://mycoportal.org/portal/taxa/index.php?t...          214862
# 1  https://mycoportal.org/portal/taxa/index.php?t...          214862
# ============================================================
#   symbiota / MyCoPortal
#   URL:       https://mycoportal.org/portal
#   Species:   Psalliota villatica
#   Name type: synonym  (synonym of: Agaricus campestris)
# ============================================================
# [MyCoPortal] 'api/v2/taxonomy/search' returned results for 'Psalliota villatica'.
# Synonyms returned: 2
#      api_name kingdom phylum class family subfamily      genus     species  \
# 0  MyCoPortal       U      U     U      U         U   Agaricus  campestris
# 1  MyCoPortal       U      U     U      U         U  Psalliota   villatica
#
#             author publication_name publication_year status source_name  \
# 0               L.                U                U      U           U
# 1  (Brond.) Bres.]                U                U      U           U
#
#                                             api_link api_internal_id
# 0  https://mycoportal.org/portal/taxa/index.php?t...          214862
# 1  https://mycoportal.org/portal/taxa/index.php?t...          214862
# ============================================================
#   symbiota / Lichen Portal
#   URL:       https://lichenportal.org/portal
#   Species:   Xanthoria parietina
#   Name type: accepted
# ============================================================
# [Lichen Portal] 'api/v2/taxonomy/search' returned no results for 'Xanthoria parietina'.
# [Lichen Portal] 'api/v2/taxonomy' returned results for 'Xanthoria parietina'.
# Synonyms returned: 15
#          api_name kingdom phylum class family subfamily           genus  \
# 0   Lichen Portal       U      U     U      U         U       Xanthoria
# 1   Lichen Portal       U      U     U      U         U  Blasteniospora
# 2   Lichen Portal       U      U     U      U         U       Geissodea
# 3   Lichen Portal       U      U     U      U         U      Imbricaria
# 4   Lichen Portal       U      U     U      U         U        Lecanora
# 5   Lichen Portal       U      U     U      U         U          Lichen
# 6   Lichen Portal       U      U     U      U         U         Lobaria
# 7   Lichen Portal       U      U     U      U         U        Parmelia
# 8   Lichen Portal       U      U     U      U         U         Physcia
# 9   Lichen Portal       U      U     U      U         U         Physcia
# 10  Lichen Portal       U      U     U      U         U        Platysma
# 11  Lichen Portal       U      U     U      U         U    Teloschistes
# 12  Lichen Portal       U      U     U      U         U       Xanthoria
# 13  Lichen Portal       U      U     U      U         U       Xanthoria
# 14  Lichen Portal       U      U     U      U         U       Xanthoria
#
#        species                         author publication_name  \
# 0    parietina                   (L.) Th. Fr.                U
# 1    parietina                   (L.) Trevis.                U
# 2    parietina              (L.) J. St.-Hill.                U
# 3    parietina                       (L.) DC.                U
# 4     rutilans                    (Ach.) Ach.                U
# 5     rutilans                           Ach.                U
# 6    parietina                    (L.) Hoffm.                U
# 7     rutilans                    (Ach.) Ach.                U
# 8      ectanea                  (Ach.) Linds.                U
# 9    parietina                   (L.) De Not.                U
# 10  parietinum                     (L.) Frege                U
# 11  parietinus               (Ach.) F. Wilson                U
# 12      coomae        S.Y. Kondr. & Kärnefelt                U
# 13     ectanea       (Ach.) Räsänen ex Filson                U
# 14   polessica  S. Y. Kondr. et A. P. Yatsyna                U
#
#    publication_year status source_name  \
# 0                 U      U           U
# 1                 U      U           U
# 2                 U      U           U
# 3                 U      U           U
# 4                 U      U           U
# 5                 U      U           U
# 6                 U      U           U
# 7                 U      U           U
# 8                 U      U           U
# 9                 U      U           U
# 10                U      U           U
# 11                U      U           U
# 12                U      U           U
# 13                U      U           U
# 14                U      U           U
#
#                                              api_link api_internal_id
# 0   https://lichenportal.org/portal/taxa/index.php...           56389
# 1   https://lichenportal.org/portal/taxa/index.php...           56389
# 2   https://lichenportal.org/portal/taxa/index.php...           56389
# 3   https://lichenportal.org/portal/taxa/index.php...           56389
# 4   https://lichenportal.org/portal/taxa/index.php...           56389
# 5   https://lichenportal.org/portal/taxa/index.php...           56389
# 6   https://lichenportal.org/portal/taxa/index.php...           56389
# 7   https://lichenportal.org/portal/taxa/index.php...           56389
# 8   https://lichenportal.org/portal/taxa/index.php...           56389
# 9   https://lichenportal.org/portal/taxa/index.php...           56389
# 10  https://lichenportal.org/portal/taxa/index.php...           56389
# 11  https://lichenportal.org/portal/taxa/index.php...           56389
# 12  https://lichenportal.org/portal/taxa/index.php...           56389
# 13  https://lichenportal.org/portal/taxa/index.php...           56389
# 14  https://lichenportal.org/portal/taxa/index.php...           56389
# ============================================================
#   symbiota / Lichen Portal
#   URL:       https://lichenportal.org/portal
#   Species:   Physcia parietina
#   Name type: synonym  (synonym of: Xanthoria parietina)
# ============================================================
# [Lichen Portal] 'api/v2/taxonomy/search' returned no results for 'Physcia parietina'.
# [Lichen Portal] 'api/v2/taxonomy' returned results for 'Physcia parietina'.
# Synonyms returned: 15
#          api_name kingdom phylum class family subfamily           genus  \
# 0   Lichen Portal       U      U     U      U         U       Xanthoria
# 1   Lichen Portal       U      U     U      U         U  Blasteniospora
# 2   Lichen Portal       U      U     U      U         U       Geissodea
# 3   Lichen Portal       U      U     U      U         U      Imbricaria
# 4   Lichen Portal       U      U     U      U         U        Lecanora
# 5   Lichen Portal       U      U     U      U         U          Lichen
# 6   Lichen Portal       U      U     U      U         U         Lobaria
# 7   Lichen Portal       U      U     U      U         U        Parmelia
# 8   Lichen Portal       U      U     U      U         U         Physcia
# 9   Lichen Portal       U      U     U      U         U         Physcia
# 10  Lichen Portal       U      U     U      U         U        Platysma
# 11  Lichen Portal       U      U     U      U         U    Teloschistes
# 12  Lichen Portal       U      U     U      U         U       Xanthoria
# 13  Lichen Portal       U      U     U      U         U       Xanthoria
# 14  Lichen Portal       U      U     U      U         U       Xanthoria
#
#        species                         author publication_name  \
# 0    parietina                   (L.) Th. Fr.                U
# 1    parietina                   (L.) Trevis.                U
# 2    parietina              (L.) J. St.-Hill.                U
# 3    parietina                       (L.) DC.                U
# 4     rutilans                    (Ach.) Ach.                U
# 5     rutilans                           Ach.                U
# 6    parietina                    (L.) Hoffm.                U
# 7     rutilans                    (Ach.) Ach.                U
# 8      ectanea                  (Ach.) Linds.                U
# 9    parietina                   (L.) De Not.                U
# 10  parietinum                     (L.) Frege                U
# 11  parietinus               (Ach.) F. Wilson                U
# 12      coomae        S.Y. Kondr. & Kärnefelt                U
# 13     ectanea       (Ach.) Räsänen ex Filson                U
# 14   polessica  S. Y. Kondr. et A. P. Yatsyna                U
#
#    publication_year status source_name  \
# 0                 U      U           U
# 1                 U      U           U
# 2                 U      U           U
# 3                 U      U           U
# 4                 U      U           U
# 5                 U      U           U
# 6                 U      U           U
# 7                 U      U           U
# 8                 U      U           U
# 9                 U      U           U
# 10                U      U           U
# 11                U      U           U
# 12                U      U           U
# 13                U      U           U
# 14                U      U           U
#
#                                              api_link api_internal_id
# 0   https://lichenportal.org/portal/taxa/index.php...           56389
# 1   https://lichenportal.org/portal/taxa/index.php...           56389
# 2   https://lichenportal.org/portal/taxa/index.php...           56389
# 3   https://lichenportal.org/portal/taxa/index.php...           56389
# 4   https://lichenportal.org/portal/taxa/index.php...           56389
# 5   https://lichenportal.org/portal/taxa/index.php...           56389
# 6   https://lichenportal.org/portal/taxa/index.php...           56389
# 7   https://lichenportal.org/portal/taxa/index.php...           56389
# 8   https://lichenportal.org/portal/taxa/index.php...           56389
# 9   https://lichenportal.org/portal/taxa/index.php...           56389
# 10  https://lichenportal.org/portal/taxa/index.php...           56389
# 11  https://lichenportal.org/portal/taxa/index.php...           56389
# 12  https://lichenportal.org/portal/taxa/index.php...           56389
# 13  https://lichenportal.org/portal/taxa/index.php...           56389
# 14  https://lichenportal.org/portal/taxa/index.php...           56389
# ============================================================
#   symbiota / Bryophyte Portal
#   URL:       https://bryophyteportal.org/portal
#   Species:   Pohlia nutans
#   Name type: accepted
# ============================================================
# [Bryophyte Portal] 'api/v2/taxonomy/search' returned no results for 'Pohlia nutans'.
# [Bryophyte Portal] 'api/v2/taxonomy' returned results for 'Pohlia nutans'.
# Synonyms returned: 74
#             api_name kingdom phylum class family subfamily   genus  \
# 0   Bryophyte Portal       U      U     U      U         U  Pohlia
# 1   Bryophyte Portal       U      U     U      U         U   Bryum
# 2   Bryophyte Portal       U      U     U      U         U   Bryum
# 3   Bryophyte Portal       U      U     U      U         U   Bryum
# 4   Bryophyte Portal       U      U     U      U         U   Bryum
# ..               ...     ...    ...   ...    ...       ...     ...
# 69  Bryophyte Portal       U      U     U      U         U  Webera
# 70  Bryophyte Portal       U      U     U      U         U  Webera
# 71  Bryophyte Portal       U      U     U      U         U  Webera
# 72  Bryophyte Portal       U      U     U      U         U  Webera
# 73  Bryophyte Portal       U      U     U      U         U  Webera
#
#            species                author publication_name publication_year  \
# 0           nutans        (Hedw.) Lindb.                U                U
# 1       afronutans            Müll. Hal.                U                U
# 2     austronutans            Müll. Hal.                U                U
# 3       basalticum        Warnst. & Geh.                U                U
# 4       bealeyense    (Huebener) Delogne                U                U
# ..             ...                   ...              ...              ...
# 69        rutilans               Schimp.                U                U
# 70       schimperi  (Müll. Hal.) Schimp.                U                U
# 71  sphagnadelphus   (Müll. Hal.) Besch.                U                U
# 72     strangulata                  Nees                U                U
# 73  subdenticulata         (Brid.) Brid.                U                U
#
#    status source_name                                           api_link  \
# 0       U           U  https://bryophyteportal.org/portal/taxa/index....
# 1       U           U  https://bryophyteportal.org/portal/taxa/index....
# 2       U           U  https://bryophyteportal.org/portal/taxa/index....
# 3       U           U  https://bryophyteportal.org/portal/taxa/index....
# 4       U           U  https://bryophyteportal.org/portal/taxa/index....
# ..    ...         ...                                                ...
# 69      U           U  https://bryophyteportal.org/portal/taxa/index....
# 70      U           U  https://bryophyteportal.org/portal/taxa/index....
# 71      U           U  https://bryophyteportal.org/portal/taxa/index....
# 72      U           U  https://bryophyteportal.org/portal/taxa/index....
# 73      U           U  https://bryophyteportal.org/portal/taxa/index....
#
#    api_internal_id
# 0           160406
# 1           160406
# 2           160406
# 3           160406
# 4           160406
# ..             ...
# 69          160406
# 70          160406
# 71          160406
# 72          160406
# 73          160406
#
# [74 rows x 15 columns]
# ============================================================
#   symbiota / Bryophyte Portal
#   URL:       https://bryophyteportal.org/portal
#   Species:   Webera nutans
#   Name type: synonym  (synonym of: Pohlia nutans)
# ============================================================
# [Bryophyte Portal] 'api/v2/taxonomy/search' returned no results for 'Webera nutans'.
# [Bryophyte Portal] 'api/v2/taxonomy' returned results for 'Webera nutans'.
# Synonyms returned: 74
#             api_name kingdom phylum class family subfamily   genus  \
# 0   Bryophyte Portal       U      U     U      U         U  Pohlia
# 1   Bryophyte Portal       U      U     U      U         U   Bryum
# 2   Bryophyte Portal       U      U     U      U         U   Bryum
# 3   Bryophyte Portal       U      U     U      U         U   Bryum
# 4   Bryophyte Portal       U      U     U      U         U   Bryum
# ..               ...     ...    ...   ...    ...       ...     ...
# 69  Bryophyte Portal       U      U     U      U         U  Webera
# 70  Bryophyte Portal       U      U     U      U         U  Webera
# 71  Bryophyte Portal       U      U     U      U         U  Webera
# 72  Bryophyte Portal       U      U     U      U         U  Webera
# 73  Bryophyte Portal       U      U     U      U         U  Webera
#
#            species                author publication_name publication_year  \
# 0           nutans        (Hedw.) Lindb.                U                U
# 1       afronutans            Müll. Hal.                U                U
# 2     austronutans            Müll. Hal.                U                U
# 3       basalticum        Warnst. & Geh.                U                U
# 4       bealeyense    (Huebener) Delogne                U                U
# ..             ...                   ...              ...              ...
# 69        rutilans               Schimp.                U                U
# 70       schimperi  (Müll. Hal.) Schimp.                U                U
# 71  sphagnadelphus   (Müll. Hal.) Besch.                U                U
# 72     strangulata                  Nees                U                U
# 73  subdenticulata         (Brid.) Brid.                U                U
#
#    status source_name                                           api_link  \
# 0       U           U  https://bryophyteportal.org/portal/taxa/index....
# 1       U           U  https://bryophyteportal.org/portal/taxa/index....
# 2       U           U  https://bryophyteportal.org/portal/taxa/index....
# 3       U           U  https://bryophyteportal.org/portal/taxa/index....
# 4       U           U  https://bryophyteportal.org/portal/taxa/index....
# ..    ...         ...                                                ...
# 69      U           U  https://bryophyteportal.org/portal/taxa/index....
# 70      U           U  https://bryophyteportal.org/portal/taxa/index....
# 71      U           U  https://bryophyteportal.org/portal/taxa/index....
# 72      U           U  https://bryophyteportal.org/portal/taxa/index....
# 73      U           U  https://bryophyteportal.org/portal/taxa/index....
#
#    api_internal_id
# 0           160406
# 1           160406
# 2           160406
# 3           160406
# 4           160406
# ..             ...
# 69          160406
# 70          160406
# 71          160406
# 72          160406
# 73          160406
#
# [74 rows x 15 columns]
# ============================================================
#   symbiota / CCH2
#   URL:       https://cch2.org/portal
#   Species:   Heteromeles arbutifolia
#   Name type: accepted
# ============================================================
# [CCH2] 'api/v2/taxonomy/search' returned no results for 'Heteromeles arbutifolia'.
# [CCH2] 'api/v2/taxonomy' returned results for 'Heteromeles arbutifolia'.
# Synonyms returned: 5
#   api_name kingdom phylum class family subfamily        genus      species  \
# 0     CCH2       U      U     U      U         U  Heteromeles  arbutifolia
# 1     CCH2       U      U     U      U         U  Heteromeles  fremontiana
# 2     CCH2       U      U     U      U         U  Heteromeles  salicifolia
# 3     CCH2       U      U     U      U         U     Photinia  arbutifolia
# 4     CCH2       U      U     U      U         U     Photinia  salicifolia
#
#               author publication_name publication_year status source_name  \
# 0  (Lindl.) M. Roem.                U                U      U           U
# 1             Decne.                U                U      U           U
# 2  (C. Presl) Abrams                U                U      U           U
# 3             Lindl.                U                U      U           U
# 4           C. Presl                U                U      U           U
#
#                                             api_link api_internal_id
# 0   https://cch2.org/portal/taxa/index.php?tid=22929           22929
# 1  https://cch2.org/portal/taxa/index.php?taxon=2...           22929
# 2  https://cch2.org/portal/taxa/index.php?taxon=2...           22929
# 3  https://cch2.org/portal/taxa/index.php?taxon=2...           22929
# 4  https://cch2.org/portal/taxa/index.php?taxon=2...           22929
# ============================================================
#   symbiota / CCH2
#   URL:       https://cch2.org/portal
#   Species:   Photinia arbutifolia
#   Name type: synonym  (synonym of: Heteromeles arbutifolia)
# ============================================================
# [CCH2] 'api/v2/taxonomy/search' returned no results for 'Photinia arbutifolia'.
# [CCH2] 'api/v2/taxonomy' returned results for 'Photinia arbutifolia'.
# Synonyms returned: 5
#   api_name kingdom phylum class family subfamily        genus      species  \
# 0     CCH2       U      U     U      U         U  Heteromeles  arbutifolia
# 1     CCH2       U      U     U      U         U  Heteromeles  fremontiana
# 2     CCH2       U      U     U      U         U  Heteromeles  salicifolia
# 3     CCH2       U      U     U      U         U     Photinia  arbutifolia
# 4     CCH2       U      U     U      U         U     Photinia  salicifolia
#
#               author publication_name publication_year status source_name  \
# 0  (Lindl.) M. Roem.                U                U      U           U
# 1             Decne.                U                U      U           U
# 2  (C. Presl) Abrams                U                U      U           U
# 3             Lindl.                U                U      U           U
# 4           C. Presl                U                U      U           U
#
#                                             api_link api_internal_id
# 0   https://cch2.org/portal/taxa/index.php?tid=22929           22929
# 1  https://cch2.org/portal/taxa/index.php?taxon=2...           22929
# 2  https://cch2.org/portal/taxa/index.php?taxon=2...           22929
# 3  https://cch2.org/portal/taxa/index.php?taxon=2...           22929
# 4  https://cch2.org/portal/taxa/index.php?taxon=2...           22929
# ============================================================
#   symbiota / SERNEC
#   URL:       https://sernecportal.org/portal
#   Species:   Magnolia grandiflora
#   Name type: accepted
# ============================================================
# [SERNEC] 'api/v2/taxonomy/search' returned no results for 'Magnolia grandiflora'.
# SymbiotaAPI fetch error [https://sernecportal.org/portal/api/v2/taxonomy]: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# [SERNEC] 'api/v2/taxonomy' returned an error; trying next endpoint.
# [SERNEC] All search endpoints returned no results for 'Magnolia grandiflora'. Attempting autocomplete search.
# SymbiotaAPI fetch error [https://sernecportal.org/portal/taxa/taxonomy/rpc/gettaxasuggest.php]: HTTPSConnectionPool(host='sernecportal.org', port=443): Read timed out. (read timeout=10)
# [SERNEC] All searches failed or returned no results for 'Magnolia grandiflora'.
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / SERNEC
#   URL:       https://sernecportal.org/portal
#   Species:   Magnolia foetida
#   Name type: synonym  (synonym of: Magnolia grandiflora)
# ============================================================
# [SERNEC] 'api/v2/taxonomy/search' returned no results for 'Magnolia foetida'.
# SymbiotaAPI fetch error [https://sernecportal.org/portal/api/v2/taxonomy]: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# [SERNEC] 'api/v2/taxonomy' returned an error; trying next endpoint.
# [SERNEC] All search endpoints returned no results for 'Magnolia foetida'. Attempting autocomplete search.
# SymbiotaAPI fetch error [https://sernecportal.org/portal/taxa/taxonomy/rpc/gettaxasuggest.php]: HTTPSConnectionPool(host='sernecportal.org', port=443): Read timed out. (read timeout=10)
# [SERNEC] All searches failed or returned no results for 'Magnolia foetida'.
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / NANSH
#   URL:       https://nansh.org/portal
#   Species:   Rudbeckia hirta
#   Name type: accepted
# ============================================================
# SymbiotaAPI fetch error [https://nansh.org/portal/api/v2/taxonomy/search]: HTTPSConnectionPool(host='nansh.org', port=443): Read timed out. (read timeout=10)
# [NANSH] 'api/v2/taxonomy/search' returned an error; trying next endpoint.
# SymbiotaAPI fetch error [https://nansh.org/portal/api/v2/taxonomy]: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# [NANSH] 'api/v2/taxonomy' returned an error; trying next endpoint.
# [NANSH] All search endpoints returned no results for 'Rudbeckia hirta'. Attempting autocomplete search.
# SymbiotaAPI fetch error [https://nansh.org/portal/taxa/taxonomy/rpc/gettaxasuggest.php]: HTTPSConnectionPool(host='nansh.org', port=443): Read timed out. (read timeout=10)
# [NANSH] All searches failed or returned no results for 'Rudbeckia hirta'.
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / NANSH
#   URL:       https://nansh.org/portal
#   Species:   Coreopsis hirta
#   Name type: synonym  (synonym of: Rudbeckia hirta)
# ============================================================
# SymbiotaAPI fetch error [https://nansh.org/portal/api/v2/taxonomy/search]: HTTPSConnectionPool(host='nansh.org', port=443): Max retries exceeded with url: /portal/api/v2/taxonomy/search?taxon=Coreopsis+hirta&type=EXACT&limit=100&offset=0 (Caused by ConnectTimeoutError(<HTTPSConnection(host='nansh.org', port=443) at 0x309c0e210>, 'Connection to nansh.org timed out. (connect timeout=10)'))
# [NANSH] 'api/v2/taxonomy/search' returned an error; trying next endpoint.
# SymbiotaAPI fetch error [https://nansh.org/portal/api/v2/taxonomy]: HTTPSConnectionPool(host='nansh.org', port=443): Max retries exceeded with url: /portal/api/v2/taxonomy?taxon=Coreopsis+hirta&type=EXACT&limit=100&offset=0 (Caused by ConnectTimeoutError(<HTTPSConnection(host='nansh.org', port=443) at 0x309c0e270>, 'Connection to nansh.org timed out. (connect timeout=10)'))
# [NANSH] 'api/v2/taxonomy' returned an error; trying next endpoint.
# [NANSH] All search endpoints returned no results for 'Coreopsis hirta'. Attempting autocomplete search.
# SymbiotaAPI fetch error [https://nansh.org/portal/taxa/taxonomy/rpc/gettaxasuggest.php]: HTTPSConnectionPool(host='nansh.org', port=443): Read timed out. (read timeout=10)
# [NANSH] All searches failed or returned no results for 'Coreopsis hirta'.
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / Algae Herbarium Portal
#   URL:       https://macroalgae.org/portal
#   Species:   Ulva intestinalis
#   Name type: accepted
# ============================================================
# [Algae Herbarium Portal] 'api/v2/taxonomy/search' returned no results for 'Ulva intestinalis'.
# [Algae Herbarium Portal] 'api/v2/taxonomy' returned results for 'Ulva intestinalis'.
# Synonyms returned: 3
#                  api_name kingdom phylum class family subfamily       genus  \
# 0  Algae Herbarium Portal       U      U     U      U         U        Ulva
# 1  Algae Herbarium Portal       U      U     U      U         U        Ilea
# 2  Algae Herbarium Portal       U      U     U      U         U  Tetraspora
#
#         species               author publication_name publication_year status  \
# 0  intestinalis             Linnaeus                U                U      U
# 1  intestinalis  (Linnaeus) Leiblein                U                U      U
# 2  intestinalis   (Linnaeus) Desvaux                U                U      U
#
#   source_name                                           api_link  \
# 0           U  https://macroalgae.org/portal/taxa/index.php?t...
# 1           U  https://macroalgae.org/portal/taxa/index.php?t...
# 2           U  https://macroalgae.org/portal/taxa/index.php?t...
#
#   api_internal_id
# 0           76122
# 1           76122
# 2           76122
# ============================================================
#   symbiota / Algae Herbarium Portal
#   URL:       https://macroalgae.org/portal
#   Species:   Ilea intestinalis
#   Name type: synonym  (synonym of: Ulva intestinalis)
# ============================================================
# [Algae Herbarium Portal] 'api/v2/taxonomy/search' returned no results for 'Ilea intestinalis'.
# [Algae Herbarium Portal] 'api/v2/taxonomy' returned results for 'Ilea intestinalis'.
# Synonyms returned: 3
#                  api_name kingdom phylum class family subfamily       genus  \
# 0  Algae Herbarium Portal       U      U     U      U         U        Ulva
# 1  Algae Herbarium Portal       U      U     U      U         U        Ilea
# 2  Algae Herbarium Portal       U      U     U      U         U  Tetraspora
#
#         species               author publication_name publication_year status  \
# 0  intestinalis             Linnaeus                U                U      U
# 1  intestinalis  (Linnaeus) Leiblein                U                U      U
# 2  intestinalis   (Linnaeus) Desvaux                U                U      U
#
#   source_name                                           api_link  \
# 0           U  https://macroalgae.org/portal/taxa/index.php?t...
# 1           U  https://macroalgae.org/portal/taxa/index.php?t...
# 2           U  https://macroalgae.org/portal/taxa/index.php?t...
#
#   api_internal_id
# 0           76122
# 1           76122
# 2           76122
# ============================================================
#   symbiota / Pterido Portal
#   URL:       https://pteridoportal.org/portal
#   Species:   Dryopteris filix-mas
#   Name type: accepted
# ============================================================
# [Pterido Portal] 'api/v2/taxonomy/search' returned no results for 'Dryopteris filix-mas'.
# [Pterido Portal] 'api/v2/taxonomy' returned results for 'Dryopteris filix-mas'.
# Synonyms returned: 8
#          api_name kingdom phylum class family subfamily        genus  \
# 0  Pterido Portal       U      U     U      U         U   Dryopteris
# 1  Pterido Portal       U      U     U      U         U        Filix
# 2  Pterido Portal       U      U     U      U         U    Filix-mas
# 3  Pterido Portal       U      U     U      U         U    Filix-mas
# 4  Pterido Portal       U      U     U      U         U   Nephrodium
# 5  Pterido Portal       U      U     U      U         U   Polypodium
# 6  Pterido Portal       U      U     U      U         U  Polystichum
# 7  Pterido Portal       U      U     U      U         U  Polystichum
#
#        species         author publication_name publication_year status  \
# 0    filix-mas                               U                U      U
# 1    filix-mas                               U                U      U
# 2    filix-mas          Farw.                U                U      U
# 3     vulgaris  Hill ex Farw.                U                U      U
# 4    filix-mas     (L.) Rich.                U                U      U
# 5  umbilicatum          Poir.                U                U      U
# 6    filix-mas           Roth                U                U      U
# 7    polysorum           Tod.                U                U      U
#
#   source_name                                           api_link  \
# 0           U  https://pteridoportal.org/portal/taxa/index.ph...
# 1           U  https://pteridoportal.org/portal/taxa/index.ph...
# 2           U  https://pteridoportal.org/portal/taxa/index.ph...
# 3           U  https://pteridoportal.org/portal/taxa/index.ph...
# 4           U  https://pteridoportal.org/portal/taxa/index.ph...
# 5           U  https://pteridoportal.org/portal/taxa/index.ph...
# 6           U  https://pteridoportal.org/portal/taxa/index.ph...
# 7           U  https://pteridoportal.org/portal/taxa/index.ph...
#
#   api_internal_id
# 0             386
# 1             386
# 2             386
# 3             386
# 4             386
# 5             386
# 6             386
# 7             386
# ============================================================
#   symbiota / Pterido Portal
#   URL:       https://pteridoportal.org/portal
#   Species:   Nephrodium filix-mas
#   Name type: synonym  (synonym of: Dryopteris filix-mas)
# ============================================================
# [Pterido Portal] 'api/v2/taxonomy/search' returned no results for 'Nephrodium filix-mas'.
# [Pterido Portal] 'api/v2/taxonomy' returned results for 'Nephrodium filix-mas'.
# Synonyms returned: 8
#          api_name kingdom phylum class family subfamily        genus  \
# 0  Pterido Portal       U      U     U      U         U   Dryopteris
# 1  Pterido Portal       U      U     U      U         U        Filix
# 2  Pterido Portal       U      U     U      U         U    Filix-mas
# 3  Pterido Portal       U      U     U      U         U    Filix-mas
# 4  Pterido Portal       U      U     U      U         U   Nephrodium
# 5  Pterido Portal       U      U     U      U         U   Polypodium
# 6  Pterido Portal       U      U     U      U         U  Polystichum
# 7  Pterido Portal       U      U     U      U         U  Polystichum
#
#        species         author publication_name publication_year status  \
# 0    filix-mas                               U                U      U
# 1    filix-mas                               U                U      U
# 2    filix-mas          Farw.                U                U      U
# 3     vulgaris  Hill ex Farw.                U                U      U
# 4    filix-mas     (L.) Rich.                U                U      U
# 5  umbilicatum          Poir.                U                U      U
# 6    filix-mas           Roth                U                U      U
# 7    polysorum           Tod.                U                U      U
#
#   source_name                                           api_link  \
# 0           U  https://pteridoportal.org/portal/taxa/index.ph...
# 1           U  https://pteridoportal.org/portal/taxa/index.ph...
# 2           U  https://pteridoportal.org/portal/taxa/index.ph...
# 3           U  https://pteridoportal.org/portal/taxa/index.ph...
# 4           U  https://pteridoportal.org/portal/taxa/index.ph...
# 5           U  https://pteridoportal.org/portal/taxa/index.ph...
# 6           U  https://pteridoportal.org/portal/taxa/index.ph...
# 7           U  https://pteridoportal.org/portal/taxa/index.ph...
#
#   api_internal_id
# 0             386
# 1             386
# 2             386
# 3             386
# 4             386
# 5             386
# 6             386
# 7             386
# ============================================================
#   symbiota / CNH
#   URL:       https://neherbaria.org/portal
#   Species:   Impatiens capensis
#   Name type: accepted
# ============================================================
# [CNH] 'api/v2/taxonomy/search' returned no results for 'Impatiens capensis'.
# [CNH] 'api/v2/taxonomy' returned results for 'Impatiens capensis'.
# Synonyms returned: 4
#   api_name kingdom phylum class family subfamily      genus   species  author  \
# 0      CNH       U      U     U      U         U  Impatiens  capensis  Meerb.
# 1      CNH       U      U     U      U         U  Impatiens   biflora  Walter
# 2      CNH       U      U     U      U         U  Impatiens     fulva   Nutt.
# 3      CNH       U      U     U      U         U  Impatiens  nortonii   Rydb.
#
#   publication_name publication_year status source_name  \
# 0                U                U      U           U
# 1                U                U      U           U
# 2                U                U      U           U
# 3                U                U      U           U
#
#                                             api_link api_internal_id
# 0  https://neherbaria.org/portal/taxa/index.php?t...          824846
# 1  https://neherbaria.org/portal/taxa/index.php?t...          824846
# 2  https://neherbaria.org/portal/taxa/index.php?t...          824846
# 3  https://neherbaria.org/portal/taxa/index.php?t...          824846
# ============================================================
#   symbiota / CNH
#   URL:       https://neherbaria.org/portal
#   Species:   Impatiens biflora
#   Name type: synonym  (synonym of: Impatiens capensis)
# ============================================================
# [CNH] 'api/v2/taxonomy/search' returned no results for 'Impatiens biflora'.
# [CNH] 'api/v2/taxonomy' returned results for 'Impatiens biflora'.
# Synonyms returned: 4
#   api_name kingdom phylum class family subfamily      genus   species  author  \
# 0      CNH       U      U     U      U         U  Impatiens  capensis  Meerb.
# 1      CNH       U      U     U      U         U  Impatiens   biflora  Walter
# 2      CNH       U      U     U      U         U  Impatiens     fulva   Nutt.
# 3      CNH       U      U     U      U         U  Impatiens  nortonii   Rydb.
#
#   publication_name publication_year status source_name  \
# 0                U                U      U           U
# 1                U                U      U           U
# 2                U                U      U           U
# 3                U                U      U           U
#
#                                             api_link api_internal_id
# 0  https://neherbaria.org/portal/taxa/index.php?t...          824846
# 1  https://neherbaria.org/portal/taxa/index.php?t...          824846
# 2  https://neherbaria.org/portal/taxa/index.php?t...          824846
# 3  https://neherbaria.org/portal/taxa/index.php?t...          824846
# ============================================================
#   symbiota / Mid-Atlantic Herbaria Consortium
#   URL:       https://midatlanticherbaria.org/portal
#   Species:   Quercus rubra
#   Name type: accepted
# ============================================================
# SymbiotaAPI fetch error [https://midatlanticherbaria.org/portal/api/v2/taxonomy/search]: HTTPSConnectionPool(host='midatlanticherbaria.org', port=443): Max retries exceeded with url: /portal/api/v2/taxonomy/search?taxon=Quercus+rubra&type=EXACT&limit=100&offset=0 (Caused by ConnectTimeoutError(<HTTPSConnection(host='midatlanticherbaria.org', port=443) at 0x309c0fe60>, 'Connection to midatlanticherbaria.org timed out. (connect timeout=10)'))
# [Mid-Atlantic Herbaria Consortium] 'api/v2/taxonomy/search' returned an error; trying next endpoint.
# SymbiotaAPI fetch error [https://midatlanticherbaria.org/portal/api/v2/taxonomy]: HTTPSConnectionPool(host='midatlanticherbaria.org', port=443): Max retries exceeded with url: /portal/api/v2/taxonomy?taxon=Quercus+rubra&type=EXACT&limit=100&offset=0 (Caused by ConnectTimeoutError(<HTTPSConnection(host='midatlanticherbaria.org', port=443) at 0x309c0fa10>, 'Connection to midatlanticherbaria.org timed out. (connect timeout=10)'))
# [Mid-Atlantic Herbaria Consortium] 'api/v2/taxonomy' returned an error; trying next endpoint.
# [Mid-Atlantic Herbaria Consortium] All search endpoints returned no results for 'Quercus rubra'. Attempting autocomplete search.
# SymbiotaAPI fetch error [https://midatlanticherbaria.org/portal/taxa/taxonomy/rpc/gettaxasuggest.php]: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# [Mid-Atlantic Herbaria Consortium] All searches failed or returned no results for 'Quercus rubra'.
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
# ============================================================
#   symbiota / Mid-Atlantic Herbaria Consortium
#   URL:       https://midatlanticherbaria.org/portal
#   Species:   Quercus maxima
#   Name type: synonym  (synonym of: Quercus rubra)
# ============================================================
# SymbiotaAPI fetch error [https://midatlanticherbaria.org/portal/api/v2/taxonomy/search]: HTTPSConnectionPool(host='midatlanticherbaria.org', port=443): Read timed out. (read timeout=10)
# [Mid-Atlantic Herbaria Consortium] 'api/v2/taxonomy/search' returned an error; trying next endpoint.
# SymbiotaAPI fetch error [https://midatlanticherbaria.org/portal/api/v2/taxonomy]: HTTPSConnectionPool(host='midatlanticherbaria.org', port=443): Read timed out. (read timeout=10)
# [Mid-Atlantic Herbaria Consortium] 'api/v2/taxonomy' returned an error; trying next endpoint.
# [Mid-Atlantic Herbaria Consortium] All search endpoints returned no results for 'Quercus maxima'. Attempting autocomplete search.
# [Mid-Atlantic Herbaria Consortium] Found match for 'Quercus maxima' via autocomplete.
# ERROR: 'tid'
#
# ============================================================
#   symbiota / swbiodiversity
#   URL:       https://swbiodiversity.org/seinet
#   Species:   Larrea tridentata
#   Name type: accepted
# ============================================================
# [swbiodiversity] 'api/v2/taxonomy/search' returned no results for 'Larrea tridentata'.
# SymbiotaAPI fetch error [https://swbiodiversity.org/seinet/api/v2/taxonomy]: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# [swbiodiversity] 'api/v2/taxonomy' returned an error; trying next endpoint.
# [swbiodiversity] All search endpoints returned no results for 'Larrea tridentata'. Attempting autocomplete search.
# [swbiodiversity] Found match for 'Larrea tridentata' via autocomplete.
# ERROR: 'tid'
#
# ============================================================
#   symbiota / swbiodiversity
#   URL:       https://swbiodiversity.org/seinet
#   Species:   Larrea mexicana
#   Name type: synonym  (synonym of: Larrea tridentata)
# ============================================================
# SymbiotaAPI fetch error [https://swbiodiversity.org/seinet/api/v2/taxonomy/search]: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# [swbiodiversity] 'api/v2/taxonomy/search' returned an error; trying next endpoint.
# SymbiotaAPI fetch error [https://swbiodiversity.org/seinet/api/v2/taxonomy]: HTTPSConnectionPool(host='swbiodiversity.org', port=443): Max retries exceeded with url: /seinet/api/v2/taxonomy?taxon=Larrea+mexicana&type=EXACT&limit=100&offset=0 (Caused by ConnectTimeoutError(<HTTPSConnection(host='swbiodiversity.org', port=443) at 0x309c23bf0>, 'Connection to swbiodiversity.org timed out. (connect timeout=10)'))
# [swbiodiversity] 'api/v2/taxonomy' returned an error; trying next endpoint.
# [swbiodiversity] All search endpoints returned no results for 'Larrea mexicana'. Attempting autocomplete search.
# SymbiotaAPI fetch error [https://swbiodiversity.org/seinet/taxa/taxonomy/rpc/gettaxasuggest.php]: HTTPSConnectionPool(host='swbiodiversity.org', port=443): Max retries exceeded with url: /seinet/taxa/taxonomy/rpc/gettaxasuggest.php?term=Larrea+mexicana (Caused by ConnectTimeoutError(<HTTPSConnection(host='swbiodiversity.org', port=443) at 0x309c219d0>, 'Connection to swbiodiversity.org timed out. (connect timeout=10)'))
# [swbiodiversity] All searches failed or returned no results for 'Larrea mexicana'.
# Synonyms returned: 0
# Empty DataFrame
# Columns: [api_name, kingdom, phylum, class, family, subfamily, genus, species, author, publication_name, publication_year, status, source_name, api_link, api_internal_id]
# Index: []
