# %% [markdown]
# # Test: `get_synonyms()` for all APIs_pipe clients
#
# Run from the **project root** so that `scripts/` is on the Python path.
#
# Covers:
# - COL, GBIF, GenBank, Index Fungorum, MushroomObserver, Tropicos
# - Symbiota portals: MyCoPortal, Lichen, Bryophyte, CCH2, SERNEC, NANSH, Macroalgae, Pterido, NE Herbaria, Mid-Atlantic, SW Biodiversity

# %%
import time
import sys, os
# Ensure the project root is on sys.path when running from notebooks.apis_pipe/
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from IPython.display import display

from scripts.apis_pipe.col import CO.api
from scripts.apis_pipe.gbif import GBI.api
from scripts.apis_pipe.genbank import GenBan.api
from scripts.apis_pipe.index_fungorum import IndexFungoru.api
from scripts.apis_pipe.mushroomobs import MushroomObserve.api
from scripts.apis_pipe.symbiota import Symbiot.api
from scripts.apis_pipe.tropicos import Tropico.api

# %% [markdown]
# ---
# ## Standard APIs

# %%
STANDARD_QUERIES = [
    # (key, client, accepted_species, synonym_of_accepted)
    ("col",            COLAPI(),               "Quercus robur",       "Quercus atrosanguinea"),
    ("gbif",           GBIFAPI(),              "Amanita muscaria",    "Agaricus muscarius"),
    ("index_fungorum", IndexFungorumAPI(),     "Amanita muscaria",    "Agaricus muscarius"),
    ("mushroomobs",    MushroomObserverAPI(),  "Amanita muscaria",    "Amanita amerimuscaria"),
    ("tropicos",       TropicosAPI(),          "Quercus robur",       "Quercus pedunculata"),
]

# %%
for key, client, accepted, synonym in STANDARD_QUERIES:
    for species, name_type in [(accepted, "accepted"), (synonym, "synonym")]:
        print(f"\n{'='*60}")
        print(f"  {key}  ({client.__class__.__name__})")
        print(f"  Species:   {species}")
        print(f"  Name type: {name_type}  (synonym of: {accepted})" if name_type == "synonym" else f"  Name type: {name_type}")
        print(f"{'='*60}")
        try:
            result = client.get_synonyms(species)
            print(f"Synonyms returned: {len(result)}")
            display(result)
        except Exception as e:
            print(f"ERROR: {e}")
# Out:
# ============================================================
#   col  (COLAPI)
#   Species:   Quercus robur
#   Name type: accepted
# ============================================================
# Synonyms returned: 17
# [{'name': 'Quercus robur',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5YN'},
#  {'name': 'Quercus atrosanguinea',
#   'author': 'hort.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SF5RP'},
#  {'name': 'Quercus belgica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4Z4'},
#  {'name': 'Quercus cupressoides',
#   'author': 'hort.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFBKJ'},
#  {'name': 'Quercus feminea',
#   'author': 'Mill.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFDVF'},
#  {'name': 'Quercus filicifolia',
#   'author': 'hort. ex A.DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFDXP'},
#  {'name': 'Quercus foemida',
#   'author': 'Mill.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4Y4'},
#  {'name': 'Quercus hentzei',
#   'author': 'Petz.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFGZ6'},
#  {'name': 'Quercus hohenackeri',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X52M'},
#  {'name': 'Quercus louettii',
#   'author': 'Dippel',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFMTB'},
#  {'name': 'Quercus malacophylla var. asterotricha',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R46R'},
#  {'name': 'Quercus pedunculata',
#   'author': 'Ehrh.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFRGP'},
#  {'name': 'Quercus pseudopeduncula',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFSTJ'},
#  {'name': 'Quercus robur f. pendula',
#   'author': '(Loudon) O. Schwarz',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFV5H'},
#  {'name': 'Quercus robur var. cuneifolia',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4FK'},
#  {'name': 'Quercus robur var. pedunculata',
#   'author': '(Hoffm.) Hook.f.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4GP'},
#  {'name': 'Quercus transiens',
#   'author': 'A.Reyn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/CDY39'}]
# ============================================================
#   col  (COLAPI)
#   Species:   Quercus atrosanguinea
#   Name type: synonym  (synonym of: Quercus robur)
# ============================================================
# Synonyms returned: 356
# [{'name': 'Quercus robur subsp. robur',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTTT'},
#  {'name': 'Quercus abbreviata',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R45Z'},
#  {'name': 'Quercus accessiva',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4Y9'},
#  {'name': 'Quercus accomodata',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4YB'},
#  {'name': 'Quercus acutiloba',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R46X'},
#  {'name': 'Quercus aesculus',
#   'author': 'Boiss.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R47D'},
#  {'name': 'Quercus aesculus var. intermedia',
#   'author': 'Heuff.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/9V354'},
#  {'name': 'Quercus aestivalis',
#   'author': 'Steven',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/78RQJ'},
#  {'name': 'Quercus afghanistanensis',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SF45D'},
#  {'name': 'Quercus alligata',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4YG'},
#  {'name': 'Quercus altissima',
#   'author': 'G.Kirchn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R48K'},
#  {'name': 'Quercus amoenifolia',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4YJ'},
#  {'name': 'Quercus annenkowii',
#   'author': 'Kauffm. ex Trautv.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R49N'},
#  {'name': 'Quercus appenina var. cylindracea',
#   'author': '(Guss. ex Parl.) Nyman',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R3HW'},
#  {'name': 'Quercus appenina var. rumelica',
#   'author': '(Griseb. & Schenk) Nyman',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R3HX'},
#  {'name': 'Quercus apula',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4YR'},
#  {'name': 'Quercus arenaria',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/6X42N'},
#  {'name': 'Quercus argentea',
#   'author': 'Mourgues',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/78S2N'},
#  {'name': 'Quercus assimilis',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4YV'},
#  {'name': 'Quercus asterotricha',
#   'author': 'Borbás & Csató',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4B9'},
#  {'name': 'Quercus astrotricha',
#   'author': '(Borbás & Csató) Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8Y94Y'},
#  {'name': 'Quercus asturica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4YW'},
#  {'name': 'Quercus atropurpurea',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4BG'},
#  {'name': 'Quercus atrosanguinea',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4BH'},
#  {'name': 'Quercus atrovirens',
#   'author': 'Sm.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4BJ'},
#  {'name': 'Quercus auzin',
#   'author': 'Secondat ex Bosc.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4C6'},
#  {'name': 'Quercus avellanoides',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4C8'},
#  {'name': 'Quercus banatica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4YZ'},
#  {'name': 'Quercus batavica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4Z2'},
#  {'name': 'Quercus bavarica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4Z3'},
#  {'name': 'Quercus bedoei',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4DL'},
#  {'name': 'Quercus belgica',
#   'author': 'Cand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SF6B9'},
#  {'name': 'Quercus bellogradensis',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4DR'},
#  {'name': 'Quercus borealis var. pilosa',
#   'author': '(Schur) Simonk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MKFF'},
#  {'name': 'Quercus brevipes',
#   'author': 'A.Kern.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4FT'},
#  {'name': 'Quercus brutia subsp. haas',
#   'author': '(Kotschy) O.Schwarz',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTNW'},
#  {'name': 'Quercus bruttia',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4G5'},
#  {'name': 'Quercus castanoides',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4JH'},
#  {'name': 'Quercus commiserata',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4ZG'},
#  {'name': 'Quercus comptoniifolia',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4MW'},
#  {'name': 'Quercus concordia',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SF9P6'},
#  {'name': 'Quercus condensata',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4N2'},
#  {'name': 'Quercus coriifolia',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4NX'},
#  {'name': 'Quercus cunisecta',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4QH'},
#  {'name': 'Quercus cuprea',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4QK'},
#  {'name': 'Quercus cupressoides',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4QM'},
#  {'name': 'Quercus cupulatus',
#   'author': 'Gilib.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4CN'},
#  {'name': 'Quercus cylindracea',
#   'author': 'Guss. ex Parl.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4QV'},
#  {'name': 'Quercus dacica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4G6'},
#  {'name': 'Quercus danubialis',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4ZQ'},
#  {'name': 'Quercus discredens',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4ZW'},
#  {'name': 'Quercus dissecta',
#   'author': 'hort. ex K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFCF6'},
#  {'name': 'Quercus emarginulata',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X524'},
#  {'name': 'Quercus esthonica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X527'},
#  {'name': 'Quercus estremadurensis',
#   'author': 'O.Schwarz',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4W3'},
#  {'name': 'Quercus ettingeri',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4W4'},
#  {'name': 'Quercus extensa',
#   'author': '(Schur) Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4WG'},
#  {'name': 'Quercus falkenbergensis',
#   'author': 'Booth ex Loudon',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4WS'},
#  {'name': 'Quercus farinosa',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4WX'},
#  {'name': 'Quercus fastigiata',
#   'author': 'Lam.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4X2'},
#  {'name': 'Quercus femina',
#   'author': 'Mill.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4X6'},
#  {'name': 'Quercus fennessii',
#   'author': 'A.DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/78S2X'},
#  {'name': 'Quercus filicifolia',
#   'author': 'Lem.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4XL'},
#  {'name': 'Quercus filipendula',
#   'author': 'Schloss. & Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4XP'},
#  {'name': 'Quercus foemina',
#   'author': 'Mill.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/9N2T7'},
#  {'name': 'Quercus fructipendula',
#   'author': 'Schrank',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4YL'},
#  {'name': 'Quercus frutetorum',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X528'},
#  {'name': 'Quercus geltowiensis',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4ZF'},
#  {'name': 'Quercus germanica',
#   'author': 'Lasch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R4ZQ'},
#  {'name': 'Quercus germanica f. puberula',
#   'author': 'Lasch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SWXV'},
#  {'name': 'Quercus germanica var. longipedunculata',
#   'author': 'Lasch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R3TN'},
#  {'name': 'Quercus germanica var. macrobalana',
#   'author': 'Lasch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R3TP'},
#  {'name': 'Quercus germanica var. pinnatifida',
#   'author': 'Lasch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R3TQ'},
#  {'name': 'Quercus grecescui',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X52G'},
#  {'name': 'Quercus haas',
#   'author': 'Kotschy',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R53Y'},
#  {'name': 'Quercus haerens',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X52H'},
#  {'name': 'Quercus hentzei',
#   'author': 'G.Kirchn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R555'},
#  {'name': 'Quercus hiemalis',
#   'author': 'Steven',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R55F'},
#  {'name': 'Quercus hispanica',
#   'author': 'Willk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/78RPD'},
#  {'name': 'Quercus hodginsii',
#   'author': 'Lodd. ex Steud.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X52L'},
#  {'name': 'Quercus hohenackeri',
#   'author': 'Cand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFH6Q'},
#  {'name': 'Quercus horizontalis',
#   'author': 'Dippel',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R564'},
#  {'name': 'Quercus hyemalis',
#   'author': 'Steven',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/6X3PD'},
#  {'name': 'Quercus immodica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X52N'},
#  {'name': 'Quercus implicata',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X52P'},
#  {'name': 'Quercus kunzei',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X532'},
#  {'name': 'Quercus laciniata',
#   'author': 'Lodd.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5BC'},
#  {'name': 'Quercus lasistana',
#   'author': 'Kotschy ex A.DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5CC'},
#  {'name': 'Quercus lentula',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X535'},
#  {'name': 'Quercus longaeva',
#   'author': 'Salisb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4DB'},
#  {'name': 'Quercus longiglans',
#   'author': 'Debeaux',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/6X3PT'},
#  {'name': 'Quercus longipedunculata',
#   'author': 'St.-Lag.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/6WRQ5'},
#  {'name': 'Quercus longipedunculata var. apennina',
#   'author': '(Lam.) St.-Lag.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/9NHV9'},
#  {'name': 'Quercus longipedunculata var. fastigiata',
#   'author': '(Lam.) St.-Lag.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/9NHVB'},
#  {'name': 'Quercus louettii',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/793Q5'},
#  {'name': 'Quercus lucorum',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/78RPS'},
#  {'name': 'Quercus ludens',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X53G'},
#  {'name': 'Quercus lugdunensis',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X53H'},
#  {'name': 'Quercus macroloba',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X53K'},
#  {'name': 'Quercus madritensis',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X53L'},
#  {'name': 'Quercus malacophylla',
#   'author': '(Schur) Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5GC'},
#  {'name': 'Quercus malacophylla var. astrotricha',
#   'author': 'Borbás & Csató',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8YH6Q'},
#  {'name': 'Quercus medwedewii',
#   'author': 'Sosn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8Y953'},
#  {'name': 'Quercus monorensis',
#   'author': 'Simonk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5KK'},
#  {'name': 'Quercus montivaga',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X53X'},
#  {'name': 'Quercus natalis',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X53Z'},
#  {'name': 'Quercus nescensis',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X543'},
#  {'name': 'Quercus nigricans',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5MG'},
#  {'name': 'Quercus oelandica',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X549'},
#  {'name': 'Quercus paleacea',
#   'author': 'Desv.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFR75'},
#  {'name': 'Quercus palmata',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5QT'},
#  {'name': 'Quercus parmenteria',
#   'author': 'Mutel',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5RC'},
#  {'name': 'Quercus pectinata',
#   'author': 'Anon.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X54G'},
#  {'name': 'Quercus pedemontana',
#   'author': 'Colla',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5RW'},
#  {'name': 'Quercus pedunculata',
#   'author': 'Hoffm.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5RY'},
#  {'name': 'Quercus pedunculata f. ettingeri',
#   'author': '(Vuk.) Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX56'},
#  {'name': 'Quercus pedunculata f. extensa',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX57'},
#  {'name': 'Quercus pedunculata f. patellulata',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX5B'},
#  {'name': 'Quercus pedunculata f. pendula-salicifolia',
#   'author': 'Zabel',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX5C'},
#  {'name': 'Quercus pedunculata f. stenocarpa',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/9LGKY'},
#  {'name': 'Quercus pedunculata f. tardissima',
#   'author': 'Simonk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MWHJ'},
#  {'name': 'Quercus pedunculata subsp. apennina',
#   'author': '(Lam.) Rouy',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/9N9TW'},
#  {'name': 'Quercus pedunculata subsp. extensa',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFRJP'},
#  {'name': 'Quercus pedunculata subsp. pilosa',
#   'author': '(Schur) Nyman',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTSM'},
#  {'name': 'Quercus pedunculata var. acutifolia',
#   'author': 'Bechst.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49J'},
#  {'name': 'Quercus pedunculata var. asplenifolia',
#   'author': 'G.Kirchn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49K'},
#  {'name': 'Quercus pedunculata var. aurea',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49L'},
#  {'name': 'Quercus pedunculata var. australis',
#   'author': 'Heuff.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49M'},
#  {'name': 'Quercus pedunculata var. borealis',
#   'author': 'Heuff.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49N'},
#  {'name': 'Quercus pedunculata var. brachybalanus',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49P'},
#  {'name': 'Quercus pedunculata var. brevipes',
#   'author': '(Simonk.) Heuff.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49Q'},
#  {'name': 'Quercus pedunculata var. comptonifolia',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49S'},
#  {'name': 'Quercus pedunculata var. concordia',
#   'author': 'Booth ex G.Kirchn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49T'},
#  {'name': 'Quercus pedunculata var. coriacea',
#   'author': 'Bechst.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJXH'},
#  {'name': 'Quercus pedunculata var. crassiuscula',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49V'},
#  {'name': 'Quercus pedunculata var. cuneifolia',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49W'},
#  {'name': 'Quercus pedunculata var. cylindrocarpa',
#   'author': 'Borbás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49X'},
#  {'name': 'Quercus pedunculata var. dauvessei',
#   'author': '(Herger) Rehder',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49Y'},
#  {'name': 'Quercus pedunculata var. dauvessei-pendula',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R49Z'},
#  {'name': 'Quercus pedunculata var. dissecta',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MK9H'},
#  {'name': 'Quercus pedunculata var. fastigiata',
#   'author': '(Lam.) Loudon',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJYC'},
#  {'name': 'Quercus pedunculata var. filicifolia',
#   'author': '(Lem.) de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJYB'},
#  {'name': 'Quercus pedunculata var. glaberrima',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJXW'},
#  {'name': 'Quercus pedunculata var. globulata',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJY8'},
#  {'name': 'Quercus pedunculata var. haas',
#   'author': '(Kotschy) Boiss.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MK9W'},
#  {'name': 'Quercus pedunculata var. heterophylla',
#   'author': 'Loudon',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJXV'},
#  {'name': 'Quercus pedunculata var. latifolia-cucullata',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJY7'},
#  {'name': 'Quercus pedunculata var. leptobalanos',
#   'author': 'Bolle',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MK9V'},
#  {'name': 'Quercus pedunculata var. macrobalanus',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJXT'},
#  {'name': 'Quercus pedunculata var. malacophylla',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJY5'},
#  {'name': 'Quercus pedunculata var. megabalana',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MK9T'},
#  {'name': 'Quercus pedunculata var. microbalanus',
#   'author': 'Heuff.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJXZ'},
#  {'name': 'Quercus pedunculata var. nigra',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MK9Z'},
#  {'name': 'Quercus pedunculata var. nigricans',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJXY'},
#  {'name': 'Quercus pedunculata var. opaca',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MK9Y'},
#  {'name': 'Quercus pedunculata var. pachycarpa',
#   'author': 'Debeaux',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJXX'},
#  {'name': 'Quercus pedunculata var. pectinata',
#   'author': 'G.Kirchn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJY9'},
#  {'name': 'Quercus pedunculata var. pendula',
#   'author': '(Neill) Loudon',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJZQ'},
#  {'name': 'Quercus pedunculata var. pendula-dauvessei',
#   'author': 'Ottol.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJZP'},
#  {'name': 'Quercus pedunculata var. pendula-heterophylla',
#   'author': 'Lavallée',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJZN'},
#  {'name': 'Quercus pedunculata var. pendula-libani',
#   'author': 'H.Jaeger',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJZT'},
#  {'name': 'Quercus pedunculata var. pilosa',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJZS'},
#  {'name': 'Quercus pedunculata var. pseudopedunculata',
#   'author': '(Vuk.) Nyman',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJZH'},
#  {'name': 'Quercus pedunculata var. pseudosessilis',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJZG'},
#  {'name': 'Quercus pedunculata var. pyramidalis',
#   'author': '(de Vos) de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJZM'},
#  {'name': 'Quercus pedunculata var. pyramidalis-cucullata',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJZL'},
#  {'name': 'Quercus pedunculata var. pyramidalis-punctata',
#   'author': 'de Vos',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4B2'},
#  {'name': 'Quercus pedunculata var. salicifolia-pendula',
#   'author': 'G.Kirchn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4B4'},
#  {'name': 'Quercus pedunculata var. sphaerobalanus',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4B5'},
#  {'name': 'Quercus pedunculata var. stenocarpa',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4B6'},
#  {'name': 'Quercus pedunculata var. subglobosa',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4B7'},
#  {'name': 'Quercus pedunculata var. tardiflora',
#   'author': '(Steven) P.Fourn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/9NCDH'},
#  {'name': 'Quercus pedunculata var. tricuspidata',
#   'author': 'Janka',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4B8'},
#  {'name': 'Quercus pedunculata var. tubulosa',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4B9'},
#  {'name': 'Quercus pendula',
#   'author': '(Neill) Lodd.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5S3'},
#  {'name': 'Quercus pendula var. viminalis',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4BF'},
#  {'name': 'Quercus pendulina var. filipendula',
#   'author': '(Schloss. & Vuk.) Nyman',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4BG'},
#  {'name': 'Quercus petropolitana',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X54H'},
#  {'name': 'Quercus pilosa',
#   'author': '(Schur) Simonk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5T3'},
#  {'name': 'Quercus pilosula',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X54K'},
#  {'name': 'Quercus plebeia',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X54M'},
#  {'name': 'Quercus pluriceps',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X54N'},
#  {'name': 'Quercus pseudodchorochensis',
#   'author': 'Boiss.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFSQM'},
#  {'name': 'Quercus pseudopedunculata',
#   'author': 'Vuk.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5VH'},
#  {'name': 'Quercus pseudoschorochensis',
#   'author': 'Boiss.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5VL'},
#  {'name': 'Quercus pseudosessilis',
#   'author': 'Schur',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5VP'},
#  {'name': 'Quercus pseudotscharakensis',
#   'author': 'Kotschy ex A.DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5VR'},
#  {'name': 'Quercus pulverulenta',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5W3'},
#  {'name': 'Quercus purpurea',
#   'author': 'Lodd. ex Loudon',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5W9'},
#  {'name': 'Quercus pyramidalis',
#   'author': 'C.C.Gmel.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5WF'},
#  {'name': 'Quercus quaerens',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X54T'},
#  {'name': 'Quercus racemosa var. nannetensis',
#   'author': 'DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MJQC'},
#  {'name': 'Quercus racemosa var. purpurascens',
#   'author': 'DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MK2C'},
#  {'name': 'Quercus roboris',
#   'author': 'Wallr.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/9V65L'},
#  {'name': 'Quercus robur f. asplenifolia',
#   'author': '(G.Kirchn.) Rehder',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX7Q'},
#  {'name': 'Quercus robur f. atropurpurea',
#   'author': '(Hartw. & Rümpler) C.K.Schneid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX7R'},
#  {'name': 'Quercus robur f. brachybalanus',
#   'author': '(Schur) F.M.Vázquez',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX7S'},
#  {'name': 'Quercus robur f. concordia',
#   'author': '(Booth ex G.Kirchn.) K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX7T'},
#  {'name': 'Quercus robur f. crassiuscula',
#   'author': '(Borbás) Erdesi & Gajić',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7N8HN'},
#  {'name': 'Quercus robur f. dissecta',
#   'author': 'K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/9VFP7'},
#  {'name': 'Quercus robur f. fastigiata',
#   'author': '(Lam.) O.Schwarz',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX7V'},
#  {'name': 'Quercus robur f. filicifolia',
#   'author': '(Lem.) C.K.Schneid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX7W'},
#  {'name': 'Quercus robur f. globulata',
#   'author': '(Schur) F.M.Vázquez',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX7X'},
#  {'name': 'Quercus robur f. heterophylla',
#   'author': '(Loudon) K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX7Y'},
#  {'name': 'Quercus robur f. holophylla',
#   'author': 'Rehder',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX7Z'},
#  {'name': 'Quercus robur f. macrobalanus',
#   'author': '(Schur) F.M.Vázquez',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX82'},
#  {'name': 'Quercus robur f. microbalanus',
#   'author': '(Heuff.) F.M.Vázquez',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX83'},
#  {'name': 'Quercus robur f. pectinata',
#   'author': '(G.Kirchn.) C.K.Schneid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX84'},
#  {'name': 'Quercus robur f. pendula',
#   'author': '(Neill) K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX85'},
#  {'name': 'Quercus robur f. purpurascens',
#   'author': '(DC.) K.Koch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX87'},
#  {'name': 'Quercus robur f. robur',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/SFVCR'},
#  {'name': 'Quercus robur f. slavonica',
#   'author': 'Gáyer',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX88'},
#  {'name': 'Quercus robur f. sphaerobalanus',
#   'author': '(Schur) F.M.Vázquez',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX89'},
#  {'name': 'Quercus robur f. subglobosa',
#   'author': '(Schur) F.M.Vázquez',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/7MWHM'},
#  {'name': 'Quercus robur f. subpraecox',
#   'author': 'Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX8B'},
#  {'name': 'Quercus robur f. tardissima',
#   'author': '(Simonk.) Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/L2MFG'},
#  {'name': 'Quercus robur f. variegata',
#   'author': '(Weston) Rehder',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5SX8D'},
#  {'name': 'Quercus robur subf. gayeri',
#   'author': 'Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8XH7Y'},
#  {'name': 'Quercus robur subf. hiemalis',
#   'author': '(Steven) Erdesi & Gajić',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8XH7Z'},
#  {'name': 'Quercus robur subf. longifolia',
#   'author': 'Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8XH82'},
#  {'name': 'Quercus robur subf. longiloba',
#   'author': 'Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8XH83'},
#  {'name': 'Quercus robur subf. pinnata',
#   'author': 'Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8XH84'},
#  {'name': 'Quercus robur subf. sublobulata',
#   'author': 'Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8XH85'},
#  {'name': 'Quercus robur subf. tardissima',
#   'author': '(Simonk.) Gáyer',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8XFW4'},
#  {'name': 'Quercus robur subsp. asterotricha',
#   'author': '(Borbás & Csató) Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTTB'},
#  {'name': 'Quercus robur subsp. astrotricha',
#   'author': '(Borbás & Csató) Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/CDXZV'},
#  {'name': 'Quercus robur subsp. brevipeduncula',
#   'author': 'Ehrh.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTTC'},
#  {'name': 'Quercus robur subsp. cuneifolia',
#   'author': '(Jáv.) Gajić & Erdesi',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/L2MFD'},
#  {'name': 'Quercus robur subsp. estremadurensis',
#   'author': '(O.Schwarz) A.Camus',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTTH'},
#  {'name': 'Quercus robur subsp. eurobur',
#   'author': 'A.Camus',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8XPDP'},
#  {'name': 'Quercus robur subsp. fastigiata',
#   'author': '(Lam.) A.Camus',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTTK'},
#  {'name': 'Quercus robur subsp. longipeduncula',
#   'author': 'Ehrh.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8YFFT'},
#  {'name': 'Quercus robur subsp. pedunculata',
#   'author': '(Hoffm.) A.DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTTP'},
#  {'name': 'Quercus robur subsp. pilosa',
#   'author': '(Schur) Gajić & Erdesi',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTTR'},
#  {'name': 'Quercus robur subsp. puberula',
#   'author': '(Lasch) Weim.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTTS'},
#  {'name': 'Quercus robur subsp. slavonica',
#   'author': '(Gáyer) Mátyás',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5KTTV'},
#  {'name': 'Quercus robur subvar. asterotricha',
#   'author': '(Borbás & Csató) Asch. & Graebn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8XC5H'},
#  {'name': 'Quercus robur subvar. bedoi',
#   'author': '(Borbás) Borbás ex Asch. & Graebn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8YJ2G'},
#  {'name': 'Quercus robur subvar. dilatata',
#   'author': 'Asch. & Graebn.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8YJ2H'},
#  {'name': 'Quercus robur subvar. praecox',
#   'author': 'Gürke',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8YJ2J'},
# ...
#   'author': 'Lam.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R5WT'},
#  {'name': 'Quercus robur var. laciniata',
#   'author': '(Lodd.) A.DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4G5'},
#  {'name': 'Quercus salicifolia',
#   'author': 'Steud.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4F6'},
#  {'name': 'Quercus sessiliflora var. microcarpa',
#   'author': '(Lapeyr.) Nyman',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/5R4L3'},
#  {'name': 'Quercus tomentosa',
#   'author': 'Ehrh. ex A.DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4FJ'},
#  {'name': 'Quercus tristis',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4FN'},
#  {'name': 'Quercus turbinata',
#   'author': 'Kit.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/4R6CC'},
#  {'name': 'Quercus vallicola',
#   'author': 'Gand.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.catalogueoflife.org/data/taxon/8X4FT'}]
# ============================================================
#   gbif  (GBIFAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# Synonyms returned: 15
# [{'name': 'Amanita muscaria',
#   'author': '',
#   'publication_year': '',
#   'publication_name': '',
#   'api_link': 'https://www.gbif.org/species/8168319'},
#  {'name': 'Agaricus aureolus',
#   'author': 'Kalchbr.',
#   'publication_year': '1873',
#   'publication_name': 'Icon. Sel. Hymenomyc. Hung. (Budapest) 1: 9.',
#   'api_link': 'https://www.gbif.org/species/5455639'},
#  {'name': 'Agaricus imperialis',
#   'author': 'Batsch',
#   'publication_year': '1783',
#   'publication_name': 'Elench. Fung. (Halle): 59.',
#   'api_link': 'https://www.gbif.org/species/5955425'},
#  {'name': 'Agaricus muscarius',
#   'author': 'L.',
#   'publication_year': '1753',
#   'publication_name': 'Sp. Pl. 2: 1172.',
#   'api_link': 'https://www.gbif.org/species/5451774'},
#  {'name': 'Agaricus nobilis',
#   'author': 'Bolton',
#   'publication_year': '1788',
#   'publication_name': 'Hist. Fung. Halifax (Huddersfield) 2: 46, Tab. 46.',
#   'api_link': 'https://www.gbif.org/species/3329091'},
#  {'name': 'Agaricus pseudoaurantiacus',
#   'author': 'Bull.',
#   'publication_year': '1792',
#   'publication_name': 'Hist. Champ. Fr. (Paris) 2(2): 673, Pl. 122.',
#   'api_link': 'https://www.gbif.org/species/3329092'},
#  {'name': 'Agaricus puellus',
#   'author': 'Batsch',
#   'publication_year': '1786',
#   'publication_name': 'Elench. Fung. (Halle): 59.',
#   'api_link': 'https://www.gbif.org/species/5452606'},
#  {'name': 'Amanita aureola',
#   'author': '(Kalchbr.) Sacc.',
#   'publication_year': '1887',
#   'publication_name': 'Syll. Fung. (Abellini) 5: 12.',
#   'api_link': 'https://www.gbif.org/species/5452441'},
#  {'name': 'Amanita circinnata',
#   'author': 'Gray',
#   'publication_year': '1821',
#   'publication_name': 'Nat. Arr. Brit. Pl. (London) 1: 600.',
#   'api_link': 'https://www.gbif.org/species/5452605'},
#  {'name': 'Amanita formosa',
#   'author': 'Gonn. & Rabenh.',
#   'publication_year': '1869',
#   'publication_name': 'Myc. Europ. (Dresden) 1-2: Tab. 10, Fig. 2.',
#   'api_link': 'https://www.gbif.org/species/5452657'},
#  {'name': 'Amanita muscaria',
#   'author': '(L.) Hook.',
#   'publication_year': '',
#   'publication_name': '',
#   'api_link': 'https://www.gbif.org/species/3329049'},
#  {'name': 'Amanita puella',
#   'author': '(Batsch) Gonnerm. & Rabenh.',
#   'publication_year': '',
#   'publication_name': '',
#   'api_link': 'https://www.gbif.org/species/5452294'},
#  {'name': 'Amanitaria muscaria',
#   'author': '(L.) E.-J.Gilbert',
#   'publication_year': '1940',
#   'publication_name': 'In Bresadola, Iconogr. mycol., Suppl. I (Milan) 27: 76.',
#   'api_link': 'https://www.gbif.org/species/3301084'},
#  {'name': 'Hypophyllum muscarium',
#   'author': '(L.) Paulet',
#   'publication_year': '1808',
#   'publication_name': 'Traité Champ. (Paris) 2: 346, Tab. 157, Figs 1-3 (’1793-1829′).',
#   'api_link': 'https://www.gbif.org/species/12357845'},
#  {'name': 'Venenarius muscarius',
#   'author': '(L.) Millsp.',
#   'publication_year': '1913',
#   'publication_name': 'West Virginia Geol. Surv., Ser. A 5(1): 131.',
#   'api_link': 'https://www.gbif.org/species/12282853'}]
# ============================================================
#   gbif  (GBIFAPI)
#   Species:   Agaricus muscarius
#   Name type: synonym  (synonym of: Amanita muscaria)
# ============================================================
# Synonyms returned: 15
# [{'name': 'Amanita muscaria',
#   'author': '(L.) Lam.',
#   'publication_year': '1783',
#   'publication_name': 'Encycl. Méth. Bot. (Paris) 1(1): 111.',
#   'api_link': 'https://www.gbif.org/species/8168319'},
#  {'name': 'Agaricus aureolus',
#   'author': 'Kalchbr.',
#   'publication_year': '1873',
#   'publication_name': 'Icon. Sel. Hymenomyc. Hung. (Budapest) 1: 9.',
#   'api_link': 'https://www.gbif.org/species/5455639'},
#  {'name': 'Agaricus imperialis',
#   'author': 'Batsch',
#   'publication_year': '1783',
#   'publication_name': 'Elench. Fung. (Halle): 59.',
#   'api_link': 'https://www.gbif.org/species/5955425'},
#  {'name': 'Agaricus muscarius',
#   'author': 'L.',
#   'publication_year': '1753',
#   'publication_name': 'Sp. Pl. 2: 1172.',
#   'api_link': 'https://www.gbif.org/species/5451774'},
#  {'name': 'Agaricus nobilis',
#   'author': 'Bolton',
#   'publication_year': '1788',
#   'publication_name': 'Hist. Fung. Halifax (Huddersfield) 2: 46, Tab. 46.',
#   'api_link': 'https://www.gbif.org/species/3329091'},
#  {'name': 'Agaricus pseudoaurantiacus',
#   'author': 'Bull.',
#   'publication_year': '1792',
#   'publication_name': 'Hist. Champ. Fr. (Paris) 2(2): 673, Pl. 122.',
#   'api_link': 'https://www.gbif.org/species/3329092'},
#  {'name': 'Agaricus puellus',
#   'author': 'Batsch',
#   'publication_year': '1786',
#   'publication_name': 'Elench. Fung. (Halle): 59.',
#   'api_link': 'https://www.gbif.org/species/5452606'},
#  {'name': 'Amanita aureola',
#   'author': '(Kalchbr.) Sacc.',
#   'publication_year': '1887',
#   'publication_name': 'Syll. Fung. (Abellini) 5: 12.',
#   'api_link': 'https://www.gbif.org/species/5452441'},
#  {'name': 'Amanita circinnata',
#   'author': 'Gray',
#   'publication_year': '1821',
#   'publication_name': 'Nat. Arr. Brit. Pl. (London) 1: 600.',
#   'api_link': 'https://www.gbif.org/species/5452605'},
#  {'name': 'Amanita formosa',
#   'author': 'Gonn. & Rabenh.',
#   'publication_year': '1869',
#   'publication_name': 'Myc. Europ. (Dresden) 1-2: Tab. 10, Fig. 2.',
#   'api_link': 'https://www.gbif.org/species/5452657'},
#  {'name': 'Amanita muscaria',
#   'author': '(L.) Hook.',
#   'publication_year': '',
#   'publication_name': '',
#   'api_link': 'https://www.gbif.org/species/3329049'},
#  {'name': 'Amanita puella',
#   'author': '(Batsch) Gonnerm. & Rabenh.',
#   'publication_year': '',
#   'publication_name': '',
#   'api_link': 'https://www.gbif.org/species/5452294'},
#  {'name': 'Amanitaria muscaria',
#   'author': '(L.) E.-J.Gilbert',
#   'publication_year': '1940',
#   'publication_name': 'In Bresadola, Iconogr. mycol., Suppl. I (Milan) 27: 76.',
#   'api_link': 'https://www.gbif.org/species/3301084'},
#  {'name': 'Hypophyllum muscarium',
#   'author': '(L.) Paulet',
#   'publication_year': '1808',
#   'publication_name': 'Traité Champ. (Paris) 2: 346, Tab. 157, Figs 1-3 (’1793-1829′).',
#   'api_link': 'https://www.gbif.org/species/12357845'},
#  {'name': 'Venenarius muscarius',
#   'author': '(L.) Millsp.',
#   'publication_year': '1913',
#   'publication_name': 'West Virginia Geol. Surv., Ser. A 5(1): 131.',
#   'api_link': 'https://www.gbif.org/species/12282853'}]
# ============================================================
#   index_fungorum  (IndexFungorumAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# Synonyms returned: 13
# [{'name': 'Agaricus aureolus',
#   'author': 'Kalchbr.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=298478'},
#  {'name': 'Agaricus imperialis',
#   'author': 'Batsch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=495382'},
#  {'name': 'Agaricus muscarius',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=375287'},
#  {'name': 'Agaricus nobilis',
#   'author': 'Bolton',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=450473'},
#  {'name': 'Agaricus pseudoaurantiacus',
#   'author': 'Bull.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=494787'},
#  {'name': 'Agaricus puellus',
#   'author': 'Batsch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=372222'},
#  {'name': 'Amanita aureola',
#   'author': '(Kalchbr.) Sacc.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=209653'},
#  {'name': 'Amanita circinnata',
#   'author': 'Gray',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=486444'},
#  {'name': 'Amanita formosa',
#   'author': 'Gonn. & Rabenh.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=212977'},
#  {'name': 'Amanita muscaria',
#   'author': '(L.) Lam.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=161267'},
#  {'name': 'Amanitaria muscaria',
#   'author': '(L.) E.-J. Gilbert',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=284092'},
#  {'name': 'Hypophyllum muscarium',
#   'author': '(L.) Paulet',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=652473'},
#  {'name': 'Venenarius muscarius',
#   'author': '(L.) Earle',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=100185'}]
# ============================================================
#   index_fungorum  (IndexFungorumAPI)
#   Species:   Agaricus muscarius
#   Name type: synonym  (synonym of: Amanita muscaria)
# ============================================================
# Synonyms returned: 13
# [{'name': 'Agaricus aureolus',
#   'author': 'Kalchbr.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=298478'},
#  {'name': 'Agaricus imperialis',
#   'author': 'Batsch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=495382'},
#  {'name': 'Agaricus muscarius',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=375287'},
#  {'name': 'Agaricus nobilis',
#   'author': 'Bolton',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=450473'},
#  {'name': 'Agaricus pseudoaurantiacus',
#   'author': 'Bull.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=494787'},
#  {'name': 'Agaricus puellus',
#   'author': 'Batsch',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=372222'},
#  {'name': 'Amanita aureola',
#   'author': '(Kalchbr.) Sacc.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=209653'},
#  {'name': 'Amanita circinnata',
#   'author': 'Gray',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=486444'},
#  {'name': 'Amanita formosa',
#   'author': 'Gonn. & Rabenh.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=212977'},
#  {'name': 'Amanita muscaria',
#   'author': '(L.) Lam.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=161267'},
#  {'name': 'Amanitaria muscaria',
#   'author': '(L.) E.-J. Gilbert',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=284092'},
#  {'name': 'Hypophyllum muscarium',
#   'author': '(L.) Paulet',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=652473'},
#  {'name': 'Venenarius muscarius',
#   'author': '(L.) Earle',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.indexfungorum.org/Names/NamesRecord.asp?RecordID=100185'}]
# ============================================================
#   mushroomobs  (MushroomObserverAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# Synonyms returned: 3
# [{'name': 'Amanita muscaria',
#   'author': '(L.) Lam.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'U'},
#  {'name': 'Amanita amerimuscaria',
#   'author': 'Tulloss & Geml nom. prov.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'U'},
#  {'name': 'Amanita muscaria',
#   'author': 'sensu auct. amer.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'U'}]
# ============================================================
#   mushroomobs  (MushroomObserverAPI)
#   Species:   Amanita amerimuscaria
#   Name type: synonym  (synonym of: Amanita muscaria)
# ============================================================
# Synonyms returned: 3
# [{'name': 'Amanita amerimuscaria',
#   'author': 'Tulloss & Geml nom. prov.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'U'},
#  {'name': 'Amanita amerimuscaria',
#   'author': 'Tulloss & Geml nom. prov.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'U'},
#  {'name': 'Amanita muscaria',
#   'author': 'sensu auct. amer.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'U'}]
# ============================================================
#   tropicos  (TropicosAPI)
#   Species:   Quercus robur
#   Name type: accepted
# ============================================================
# Synonyms returned: 2
# [{'name': 'Quercus robur',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.tropicos.org/name/13100004'},
#  {'name': 'Quercus pedunculata',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.tropicos.org/name/13100434'}]
# ============================================================
#   tropicos  (TropicosAPI)
#   Species:   Quercus pedunculata
#   Name type: synonym  (synonym of: Quercus robur)
# ============================================================
# Synonyms returned: 2
# [{'name': 'Quercus robur',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.tropicos.org/name/13100004'},
#  {'name': 'Quercus pedunculata',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.tropicos.org/name/13100434'}]

# %%
# GenBank is run separately because NCBI rate-limits unauthenticated callers
# to 3 req/s. Each get_synonyms() makes 2 requests (esearch + efetch), so we
# sleep 1s between calls to stay well under the limit.
GENBANK_QUERIES = [
    ("Amanita muscaria",  "accepted"),
    ("Agaricus muscarius", "synonym"),
]
genbank_client = GenBankAPI()
for species, name_type in GENBANK_QUERIES:
    print(f"\n{'='*60}")
    print(f"  genbank  (GenBankAPI)")
    print(f"  Species:   {species}")
    print(f"  Name type: {name_type}")
    print(f"{'='*60}")
    try:
        result = genbank_client.get_synonyms(species)
        print(f"Synonyms returned: {len(result)}")
        display(result)
    except Exception as e:
        print(f"ERROR: {e}")
    time.sleep(1.0)  # NCBI rate limit: max 3 req/s; each call makes 2 requests
# Out:
# ============================================================
#   genbank  (GenBankAPI)
#   Species:   Amanita muscaria
#   Name type: accepted
# ============================================================
# Synonyms returned: 2
# [{'name': 'Amanita muscaria',
#   'author': 'U',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.ncbi.nlm.nih.gov/taxonomy/41956'},
#  {'name': 'Agaricus muscarius',
#   'author': 'U',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://www.ncbi.nlm.nih.gov/taxonomy/41956'}]
# ============================================================
#   genbank  (GenBankAPI)
#   Species:   Agaricus muscarius
#   Name type: synonym
# ============================================================
# Synonyms returned: 0
# []

# %% [markdown]
# ---
# ## Symbiota Portals

# %%
_SYMBIOTA_PORTALS = [
    # (portal_key, base_url, accepted_species, synonym_of_accepted)
    ("mycoportal",     "https://mycoportal.org/portal",              "Agaricus campestris",     "Psalliota villatica"),
    ("lichen",         "https://lichenportal.org/portal",            "Xanthoria parietina",     "Physcia parietina"),
    ("bryophyte",      "https://bryophyteportal.org/portal",         "Pohlia nutans",           "Webera nutans"),
    # Photinia arbutifolia is a synonym OF Heteromeles arbutifolia (toyon)
    ("cch2",           "https://cch2.org/portal",                    "Heteromeles arbutifolia", "Photinia arbutifolia"),
    ("sernec",         "https://sernecportal.org/portal",            "Magnolia grandiflora",    "Magnolia foetida"),
    ("nansh",          "https://nansh.org/portal",                   "Rudbeckia hirta",         "Coreopsis hirta"),
    ("macroalgae",     "https://macroalgae.org/portal",              "Ulva intestinalis",       "Ilea intestinalis"),
    ("pterido",        "https://pteridoportal.org/portal",           "Dryopteris filix-mas",    "Nephrodium filix-mas"),
    ("neherbaria",     "https://neherbaria.org/portal",              "Impatiens capensis",      "Impatiens biflora"),
    ("midatlantic",    "https://midatlanticherbaria.org/portal",     "Quercus rubra",           "Quercus maxima"),
    ("swbiodiversity", "https://swbiodiversity.org/seinet",          "Larrea tridentata",       "Larrea mexicana"),
]

# %%
for portal_key, base_url, accepted, synonym in _SYMBIOTA_PORTALS:
    for species, name_type in [(accepted, "accepted"), (synonym, "synonym")]:
        print(f"\n{'='*60}")
        print(f"  symbiota / {portal_key}")
        print(f"  URL:       {base_url}")
        print(f"  Species:   {species}")
        print(f"  Name type: {name_type}  (synonym of: {accepted})" if name_type == "synonym" else f"  Name type: {name_type}")
        print(f"{'='*60}")
        try:
            client = SymbiotaAPI(base_url=base_url, portal_name=portal_key)
            result = client.get_synonyms(species)
            print(f"Synonyms returned: {len(result)}")
            display(result)
        except Exception as e:
            print(f"ERROR: {e}")
# Out:
# ============================================================
#   symbiota / mycoportal
#   URL:       https://mycoportal.org/portal
#   Species:   Agaricus campestris
#   Name type: accepted
# ============================================================
# [mycoportal] 'api/v2/taxonomy/search' returned results for 'Agaricus campestris'.
# Synonyms returned: 2
# [{'name': 'Agaricus campestris',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://mycoportal.org/portal/taxa/index.php?tid=214862'},
#  {'name': 'Psalliota villatica',
#   'author': '(Brond.) Bres.]',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://mycoportal.org/portal/taxa/index.php?taxon=214862'}]
# ============================================================
#   symbiota / mycoportal
#   URL:       https://mycoportal.org/portal
#   Species:   Psalliota villatica
#   Name type: synonym  (synonym of: Agaricus campestris)
# ============================================================
# [mycoportal] 'api/v2/taxonomy/search' returned results for 'Psalliota villatica'.
# Synonyms returned: 2
# [{'name': 'Agaricus campestris',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://mycoportal.org/portal/taxa/index.php?tid=214862'},
#  {'name': 'Psalliota villatica',
#   'author': '(Brond.) Bres.]',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://mycoportal.org/portal/taxa/index.php?taxon=214862'}]
# ============================================================
#   symbiota / lichen
#   URL:       https://lichenportal.org/portal
#   Species:   Xanthoria parietina
#   Name type: accepted
# ============================================================
# [lichen] 'api/v2/taxonomy/search' returned no results for 'Xanthoria parietina'.
# [lichen] 'api/v2/taxonomy' returned results for 'Xanthoria parietina'.
# Synonyms returned: 15
# [{'name': 'Xanthoria parietina',
#   'author': '(L.) Th. Fr.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?tid=56389'},
#  {'name': 'Blasteniospora parietina',
#   'author': '(L.) Trevis.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Geissodea parietina',
#   'author': '(L.) J. St.-Hill.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Imbricaria parietina',
#   'author': '(L.) DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Lecanora rutilans',
#   'author': '(Ach.) Ach.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Lichen rutilans',
#   'author': 'Ach.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Lobaria parietina',
#   'author': '(L.) Hoffm.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Parmelia rutilans',
#   'author': '(Ach.) Ach.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Physcia ectanea',
#   'author': '(Ach.) Linds.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Physcia parietina',
#   'author': '(L.) De Not.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Platysma parietinum',
#   'author': '(L.) Frege',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Teloschistes parietinus',
#   'author': '(Ach.) F. Wilson',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Xanthoria coomae',
#   'author': 'S.Y. Kondr. & Kärnefelt',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Xanthoria ectanea',
#   'author': '(Ach.) Räsänen ex Filson',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Xanthoria polessica',
#   'author': 'S. Y. Kondr. et A. P. Yatsyna',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'}]
# ============================================================
#   symbiota / lichen
#   URL:       https://lichenportal.org/portal
#   Species:   Physcia parietina
#   Name type: synonym  (synonym of: Xanthoria parietina)
# ============================================================
# [lichen] 'api/v2/taxonomy/search' returned no results for 'Physcia parietina'.
# [lichen] 'api/v2/taxonomy' returned results for 'Physcia parietina'.
# Synonyms returned: 15
# [{'name': 'Xanthoria parietina',
#   'author': '(L.) Th. Fr.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?tid=56389'},
#  {'name': 'Blasteniospora parietina',
#   'author': '(L.) Trevis.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Geissodea parietina',
#   'author': '(L.) J. St.-Hill.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Imbricaria parietina',
#   'author': '(L.) DC.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Lecanora rutilans',
#   'author': '(Ach.) Ach.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Lichen rutilans',
#   'author': 'Ach.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Lobaria parietina',
#   'author': '(L.) Hoffm.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Parmelia rutilans',
#   'author': '(Ach.) Ach.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Physcia ectanea',
#   'author': '(Ach.) Linds.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Physcia parietina',
#   'author': '(L.) De Not.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Platysma parietinum',
#   'author': '(L.) Frege',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Teloschistes parietinus',
#   'author': '(Ach.) F. Wilson',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Xanthoria coomae',
#   'author': 'S.Y. Kondr. & Kärnefelt',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Xanthoria ectanea',
#   'author': '(Ach.) Räsänen ex Filson',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'},
#  {'name': 'Xanthoria polessica',
#   'author': 'S. Y. Kondr. et A. P. Yatsyna',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://lichenportal.org/portal/taxa/index.php?taxon=56389'}]
# ============================================================
#   symbiota / bryophyte
#   URL:       https://bryophyteportal.org/portal
#   Species:   Pohlia nutans
#   Name type: accepted
# ============================================================
# [bryophyte] 'api/v2/taxonomy/search' returned no results for 'Pohlia nutans'.
# [bryophyte] 'api/v2/taxonomy' returned results for 'Pohlia nutans'.
# Synonyms returned: 74
# [{'name': 'Pohlia nutans',
#   'author': '(Hedw.) Lindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?tid=160406'},
#  {'name': 'Bryum afronutans',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum austronutans',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum basalticum',
#   'author': 'Warnst. & Geh.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum bealeyense',
#   'author': '(Huebener) Delogne',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum beccarii',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum caespitosum',
#   'author': '(Hoppe & Hornsch.) Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum canaliculatum',
#   'author': '(Müll. Hal. & Kindb.) Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum claviforme',
#   'author': 'Hampe',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum compactum',
#   'author': 'Dicks.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum cucullatiforme',
#   'author': 'Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum ecklonianum',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum gelidum',
#   'author': 'I. Hagen',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum gypsophilum',
#   'author': 'Wallr.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum humidulum',
#   'author': 'Sull. & Lesq.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum interruptum',
#   'author': 'Dicks.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum laxum',
#   'author': 'Reichardt',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum leptopelmatum',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum montanum',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum nigricans',
#   'author': 'Dicks.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum nutans',
#   'author': '(Hedw.) Turner',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum pertenellum',
#   'author': 'Bryhn & Ryan',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum rutilans',
#   'author': 'Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum schimperi',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum sphagnadelphus',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum subdenticulatum',
#   'author': 'Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum torlessense',
#   'author': 'R. Br. bis',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum umbrosum',
#   'author': 'Wallr.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Hypnum nutans',
#   'author': '(Hedw.) F. Weber & D. Mohr',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Lamprophyllum nutans',
#   'author': '(Hedw.) Lindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Mniobryum compactum',
#   'author': '(Dicks.) Baehni',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Mnium compactum',
#   'author': '(Dicks.) P. Beauv.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Mnium nigricans',
#   'author': '(Dicks.) Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia beccarii',
#   'author': '(Müll. Hal.) Watts & Whitel.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia caespitosa',
#   'author': '(Hoppe & Hornsch.) Lazarenko',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia claviformis',
#   'author': '(Hampe) Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia elatior',
#   'author': '(Dixon & Sainsbury) Sainsbury',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia leptopelmata',
#   'author': '(Müll. Hal.) Watts & Whitel.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia longifolia',
#   'author': '(A. Jaeger) Watts & Whitel.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia montana',
#   'author': '(Müll. Hal.) Watts & Whitel.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia polygama',
#   'author': 'Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia pulvinata',
#   'author': '(Kindb.) Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia racovitzae',
#   'author': '(Cardot) Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia rutilans',
#   'author': '(Schimp.) Lindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia schimperi',
#   'author': '(C. Müll.) Andrews in Grout',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia suzukii',
#   'author': 'Ochi',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia tomentosocaespitosa',
#   'author': 'Ochi',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia yanoi',
#   'author': 'Ochi',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pseudopohlia merrillii',
#   'author': 'Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera afronutans',
#   'author': '(Müll. Hal.) Paris',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera austronutans',
#   'author': '(Müll. Hal.) Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera beccarii',
#   'author': '(Müll. Hal.) Paris',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera bicolor',
#   'author': 'Hoppe & Hornsch.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera caespitosa',
#   'author': 'Hoppe & Hornsch.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera canaliculata',
#   'author': 'Müll. Hal. & Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera claviformis',
#   'author': '(Hampe) A. Jaeger',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera cucullatiformis',
#   'author': '(Kindb.) Paris',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera duriuscula',
#   'author': 'Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera eckloniana',
#   'author': '(Müll. Hal.) A. Jaeger',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera elatior',
#   'author': 'Dixon & Sainsbury',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera longifolia',
#   'author': 'A. Jaeger',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera longiseta',
#   'author': 'Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera montana',
#   'author': '(Müll. Hal.) Paris',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera nigricans',
#   'author': '(Dicks.) Buse',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera nutans',
#   'author': 'Hedw.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera pendula',
#   'author': 'Hornsch.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera polygama',
#   'author': '(Kindb.) Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera pulvinata',
#   'author': 'Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera racovitzae',
#   'author': 'Cardot',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera rutilans',
#   'author': 'Schimp.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera schimperi',
#   'author': '(Müll. Hal.) Schimp.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera sphagnadelphus',
#   'author': '(Müll. Hal.) Besch.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera strangulata',
#   'author': 'Nees',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera subdenticulata',
#   'author': '(Brid.) Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'}]
# ============================================================
#   symbiota / bryophyte
#   URL:       https://bryophyteportal.org/portal
#   Species:   Webera nutans
#   Name type: synonym  (synonym of: Pohlia nutans)
# ============================================================
# [bryophyte] 'api/v2/taxonomy/search' returned no results for 'Webera nutans'.
# [bryophyte] 'api/v2/taxonomy' returned results for 'Webera nutans'.
# Synonyms returned: 74
# [{'name': 'Pohlia nutans',
#   'author': '(Hedw.) Lindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?tid=160406'},
#  {'name': 'Bryum afronutans',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum austronutans',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum basalticum',
#   'author': 'Warnst. & Geh.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum bealeyense',
#   'author': '(Huebener) Delogne',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum beccarii',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum caespitosum',
#   'author': '(Hoppe & Hornsch.) Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum canaliculatum',
#   'author': '(Müll. Hal. & Kindb.) Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum claviforme',
#   'author': 'Hampe',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum compactum',
#   'author': 'Dicks.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum cucullatiforme',
#   'author': 'Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum ecklonianum',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum gelidum',
#   'author': 'I. Hagen',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum gypsophilum',
#   'author': 'Wallr.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum humidulum',
#   'author': 'Sull. & Lesq.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum interruptum',
#   'author': 'Dicks.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum laxum',
#   'author': 'Reichardt',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum leptopelmatum',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum montanum',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum nigricans',
#   'author': 'Dicks.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum nutans',
#   'author': '(Hedw.) Turner',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum pertenellum',
#   'author': 'Bryhn & Ryan',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum rutilans',
#   'author': 'Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum schimperi',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum sphagnadelphus',
#   'author': 'Müll. Hal.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum subdenticulatum',
#   'author': 'Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum torlessense',
#   'author': 'R. Br. bis',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Bryum umbrosum',
#   'author': 'Wallr.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Hypnum nutans',
#   'author': '(Hedw.) F. Weber & D. Mohr',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Lamprophyllum nutans',
#   'author': '(Hedw.) Lindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Mniobryum compactum',
#   'author': '(Dicks.) Baehni',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Mnium compactum',
#   'author': '(Dicks.) P. Beauv.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Mnium nigricans',
#   'author': '(Dicks.) Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia beccarii',
#   'author': '(Müll. Hal.) Watts & Whitel.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia caespitosa',
#   'author': '(Hoppe & Hornsch.) Lazarenko',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia claviformis',
#   'author': '(Hampe) Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia elatior',
#   'author': '(Dixon & Sainsbury) Sainsbury',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia leptopelmata',
#   'author': '(Müll. Hal.) Watts & Whitel.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia longifolia',
#   'author': '(A. Jaeger) Watts & Whitel.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia montana',
#   'author': '(Müll. Hal.) Watts & Whitel.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia polygama',
#   'author': 'Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia pulvinata',
#   'author': '(Kindb.) Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia racovitzae',
#   'author': '(Cardot) Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia rutilans',
#   'author': '(Schimp.) Lindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia schimperi',
#   'author': '(C. Müll.) Andrews in Grout',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia suzukii',
#   'author': 'Ochi',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia tomentosocaespitosa',
#   'author': 'Ochi',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pohlia yanoi',
#   'author': 'Ochi',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Pseudopohlia merrillii',
#   'author': 'Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera afronutans',
#   'author': '(Müll. Hal.) Paris',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera austronutans',
#   'author': '(Müll. Hal.) Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera beccarii',
#   'author': '(Müll. Hal.) Paris',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera bicolor',
#   'author': 'Hoppe & Hornsch.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera caespitosa',
#   'author': 'Hoppe & Hornsch.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera canaliculata',
#   'author': 'Müll. Hal. & Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera claviformis',
#   'author': '(Hampe) A. Jaeger',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera cucullatiformis',
#   'author': '(Kindb.) Paris',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera duriuscula',
#   'author': 'Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera eckloniana',
#   'author': '(Müll. Hal.) A. Jaeger',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera elatior',
#   'author': 'Dixon & Sainsbury',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera longifolia',
#   'author': 'A. Jaeger',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera longiseta',
#   'author': 'Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera montana',
#   'author': '(Müll. Hal.) Paris',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera nigricans',
#   'author': '(Dicks.) Buse',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera nutans',
#   'author': 'Hedw.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera pendula',
#   'author': 'Hornsch.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera polygama',
#   'author': '(Kindb.) Broth.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera pulvinata',
#   'author': 'Kindb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera racovitzae',
#   'author': 'Cardot',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera rutilans',
#   'author': 'Schimp.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera schimperi',
#   'author': '(Müll. Hal.) Schimp.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera sphagnadelphus',
#   'author': '(Müll. Hal.) Besch.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera strangulata',
#   'author': 'Nees',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'},
#  {'name': 'Webera subdenticulata',
#   'author': '(Brid.) Brid.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://bryophyteportal.org/portal/taxa/index.php?taxon=160406'}]
# ============================================================
#   symbiota / cch2
#   URL:       https://cch2.org/portal
#   Species:   Heteromeles arbutifolia
#   Name type: accepted
# ============================================================
# [cch2] 'api/v2/taxonomy/search' returned no results for 'Heteromeles arbutifolia'.
# [cch2] 'api/v2/taxonomy' returned results for 'Heteromeles arbutifolia'.
# Synonyms returned: 5
# [{'name': 'Heteromeles arbutifolia',
#   'author': '(Lindl.) M. Roem.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?tid=22929'},
#  {'name': 'Heteromeles fremontiana',
#   'author': 'Decne.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?taxon=22929'},
#  {'name': 'Heteromeles salicifolia',
#   'author': '(C. Presl) Abrams',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?taxon=22929'},
#  {'name': 'Photinia arbutifolia',
#   'author': 'Lindl.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?taxon=22929'},
#  {'name': 'Photinia salicifolia',
#   'author': 'C. Presl',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?taxon=22929'}]
# ============================================================
#   symbiota / cch2
#   URL:       https://cch2.org/portal
#   Species:   Photinia arbutifolia
#   Name type: synonym  (synonym of: Heteromeles arbutifolia)
# ============================================================
# [cch2] 'api/v2/taxonomy/search' returned no results for 'Photinia arbutifolia'.
# [cch2] 'api/v2/taxonomy' returned results for 'Photinia arbutifolia'.
# Synonyms returned: 5
# [{'name': 'Heteromeles arbutifolia',
#   'author': '(Lindl.) M. Roem.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?tid=22929'},
#  {'name': 'Heteromeles fremontiana',
#   'author': 'Decne.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?taxon=22929'},
#  {'name': 'Heteromeles salicifolia',
#   'author': '(C. Presl) Abrams',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?taxon=22929'},
#  {'name': 'Photinia arbutifolia',
#   'author': 'Lindl.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?taxon=22929'},
#  {'name': 'Photinia salicifolia',
#   'author': 'C. Presl',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://cch2.org/portal/taxa/index.php?taxon=22929'}]
# ============================================================
#   symbiota / sernec
#   URL:       https://sernecportal.org/portal
#   Species:   Magnolia grandiflora
#   Name type: accepted
# ============================================================
# [sernec] 'api/v2/taxonomy/search' returned no results for 'Magnolia grandiflora'.
# [sernec] 'api/v2/taxonomy' returned results for 'Magnolia grandiflora'.
# Synonyms returned: 3
# [{'name': 'Magnolia grandiflora',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://sernecportal.org/portal/taxa/index.php?tid=17263'},
#  {'name': 'Magnolia foetida',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://sernecportal.org/portal/taxa/index.php?taxon=17263'},
#  {'name': 'Magnolia tomentosa',
#   'author': 'Ser.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://sernecportal.org/portal/taxa/index.php?taxon=17263'}]
# ============================================================
#   symbiota / sernec
#   URL:       https://sernecportal.org/portal
#   Species:   Magnolia foetida
#   Name type: synonym  (synonym of: Magnolia grandiflora)
# ============================================================
# [sernec] 'api/v2/taxonomy/search' returned no results for 'Magnolia foetida'.
# [sernec] 'api/v2/taxonomy' returned results for 'Magnolia foetida'.
# Synonyms returned: 3
# [{'name': 'Magnolia grandiflora',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://sernecportal.org/portal/taxa/index.php?tid=17263'},
#  {'name': 'Magnolia foetida',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://sernecportal.org/portal/taxa/index.php?taxon=17263'},
#  {'name': 'Magnolia tomentosa',
#   'author': 'Ser.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://sernecportal.org/portal/taxa/index.php?taxon=17263'}]
# ============================================================
#   symbiota / nansh
#   URL:       https://nansh.org/portal
#   Species:   Rudbeckia hirta
#   Name type: accepted
# ============================================================
# [nansh] 'api/v2/taxonomy/search' returned no results for 'Rudbeckia hirta'.
# [nansh] 'api/v2/taxonomy' returned results for 'Rudbeckia hirta'.
# Synonyms returned: 2
# [{'name': 'Rudbeckia hirta',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://nansh.org/portal/taxa/index.php?tid=17308'},
#  {'name': 'Coreopsis hirta',
#   'author': ']',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://nansh.org/portal/taxa/index.php?taxon=17308'}]
# ============================================================
#   symbiota / nansh
#   URL:       https://nansh.org/portal
#   Species:   Coreopsis hirta
#   Name type: synonym  (synonym of: Rudbeckia hirta)
# ============================================================
# [nansh] 'api/v2/taxonomy/search' returned no results for 'Coreopsis hirta'.
# [nansh] 'api/v2/taxonomy' returned results for 'Coreopsis hirta'.
# Synonyms returned: 2
# [{'name': 'Rudbeckia hirta',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://nansh.org/portal/taxa/index.php?tid=17308'},
#  {'name': 'Coreopsis hirta',
#   'author': ']',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://nansh.org/portal/taxa/index.php?taxon=17308'}]
# ============================================================
#   symbiota / macroalgae
#   URL:       https://macroalgae.org/portal
#   Species:   Ulva intestinalis
#   Name type: accepted
# ============================================================
# [macroalgae] 'api/v2/taxonomy/search' returned no results for 'Ulva intestinalis'.
# [macroalgae] 'api/v2/taxonomy' returned results for 'Ulva intestinalis'.
# Synonyms returned: 3
# [{'name': 'Ulva intestinalis',
#   'author': 'Linnaeus',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://macroalgae.org/portal/taxa/index.php?tid=76122'},
#  {'name': 'Ilea intestinalis',
#   'author': '(Linnaeus) Leiblein',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://macroalgae.org/portal/taxa/index.php?taxon=76122'},
#  {'name': 'Tetraspora intestinalis',
#   'author': '(Linnaeus) Desvaux',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://macroalgae.org/portal/taxa/index.php?taxon=76122'}]
# ============================================================
#   symbiota / macroalgae
#   URL:       https://macroalgae.org/portal
#   Species:   Ilea intestinalis
#   Name type: synonym  (synonym of: Ulva intestinalis)
# ============================================================
# [macroalgae] 'api/v2/taxonomy/search' returned no results for 'Ilea intestinalis'.
# [macroalgae] 'api/v2/taxonomy' returned results for 'Ilea intestinalis'.
# Synonyms returned: 3
# [{'name': 'Ulva intestinalis',
#   'author': 'Linnaeus',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://macroalgae.org/portal/taxa/index.php?tid=76122'},
#  {'name': 'Ilea intestinalis',
#   'author': '(Linnaeus) Leiblein',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://macroalgae.org/portal/taxa/index.php?taxon=76122'},
#  {'name': 'Tetraspora intestinalis',
#   'author': '(Linnaeus) Desvaux',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://macroalgae.org/portal/taxa/index.php?taxon=76122'}]
# ============================================================
#   symbiota / pterido
#   URL:       https://pteridoportal.org/portal
#   Species:   Dryopteris filix-mas
#   Name type: accepted
# ============================================================
# [pterido] 'api/v2/taxonomy/search' returned no results for 'Dryopteris filix-mas'.
# [pterido] 'api/v2/taxonomy' returned results for 'Dryopteris filix-mas'.
# Synonyms returned: 8
# [{'name': 'Dryopteris filix-mas',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?tid=386'},
#  {'name': 'Filix filix-mas',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Filix-mas filix-mas',
#   'author': 'Farw.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Filix-mas vulgaris',
#   'author': 'Hill ex Farw.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Nephrodium filix-mas',
#   'author': '(L.) Rich.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Polypodium umbilicatum',
#   'author': 'Poir.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Polystichum filix-mas',
#   'author': 'Roth',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Polystichum polysorum',
#   'author': 'Tod.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'}]
# ============================================================
#   symbiota / pterido
#   URL:       https://pteridoportal.org/portal
#   Species:   Nephrodium filix-mas
#   Name type: synonym  (synonym of: Dryopteris filix-mas)
# ============================================================
# [pterido] 'api/v2/taxonomy/search' returned no results for 'Nephrodium filix-mas'.
# [pterido] 'api/v2/taxonomy' returned results for 'Nephrodium filix-mas'.
# Synonyms returned: 8
# [{'name': 'Dryopteris filix-mas',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?tid=386'},
#  {'name': 'Filix filix-mas',
#   'author': '',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Filix-mas filix-mas',
#   'author': 'Farw.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Filix-mas vulgaris',
#   'author': 'Hill ex Farw.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Nephrodium filix-mas',
#   'author': '(L.) Rich.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Polypodium umbilicatum',
#   'author': 'Poir.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Polystichum filix-mas',
#   'author': 'Roth',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'},
#  {'name': 'Polystichum polysorum',
#   'author': 'Tod.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://pteridoportal.org/portal/taxa/index.php?taxon=386'}]
# ============================================================
#   symbiota / neherbaria
#   URL:       https://neherbaria.org/portal
#   Species:   Impatiens capensis
#   Name type: accepted
# ============================================================
# [neherbaria] 'api/v2/taxonomy/search' returned no results for 'Impatiens capensis'.
# [neherbaria] 'api/v2/taxonomy' returned results for 'Impatiens capensis'.
# Synonyms returned: 4
# [{'name': 'Impatiens capensis',
#   'author': 'Meerb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://neherbaria.org/portal/taxa/index.php?tid=824846'},
#  {'name': 'Impatiens biflora',
#   'author': 'Walter',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://neherbaria.org/portal/taxa/index.php?taxon=824846'},
#  {'name': 'Impatiens fulva',
#   'author': 'Nutt.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://neherbaria.org/portal/taxa/index.php?taxon=824846'},
#  {'name': 'Impatiens nortonii',
#   'author': 'Rydb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://neherbaria.org/portal/taxa/index.php?taxon=824846'}]
# ============================================================
#   symbiota / neherbaria
#   URL:       https://neherbaria.org/portal
#   Species:   Impatiens biflora
#   Name type: synonym  (synonym of: Impatiens capensis)
# ============================================================
# [neherbaria] 'api/v2/taxonomy/search' returned no results for 'Impatiens biflora'.
# [neherbaria] 'api/v2/taxonomy' returned results for 'Impatiens biflora'.
# Synonyms returned: 4
# [{'name': 'Impatiens capensis',
#   'author': 'Meerb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://neherbaria.org/portal/taxa/index.php?tid=824846'},
#  {'name': 'Impatiens biflora',
#   'author': 'Walter',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://neherbaria.org/portal/taxa/index.php?taxon=824846'},
#  {'name': 'Impatiens fulva',
#   'author': 'Nutt.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://neherbaria.org/portal/taxa/index.php?taxon=824846'},
#  {'name': 'Impatiens nortonii',
#   'author': 'Rydb.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://neherbaria.org/portal/taxa/index.php?taxon=824846'}]
# ============================================================
#   symbiota / midatlantic
#   URL:       https://midatlanticherbaria.org/portal
#   Species:   Quercus rubra
#   Name type: accepted
# ============================================================
# [midatlantic] 'api/v2/taxonomy/search' returned no results for 'Quercus rubra'.
# [midatlantic] 'api/v2/taxonomy' returned results for 'Quercus rubra'.
# Synonyms returned: 3
# [{'name': 'Quercus rubra',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://midatlanticherbaria.org/portal/taxa/index.php?tid=46960'},
#  {'name': 'Quercus borealis',
#   'author': 'Michx. f.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://midatlanticherbaria.org/portal/taxa/index.php?taxon=46960'},
#  {'name': 'Quercus maxima',
#   'author': '(Marsh.) Ashe',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://midatlanticherbaria.org/portal/taxa/index.php?taxon=46960'}]
# ============================================================
#   symbiota / midatlantic
#   URL:       https://midatlanticherbaria.org/portal
#   Species:   Quercus maxima
#   Name type: synonym  (synonym of: Quercus rubra)
# ============================================================
# [midatlantic] 'api/v2/taxonomy/search' returned no results for 'Quercus maxima'.
# [midatlantic] 'api/v2/taxonomy' returned results for 'Quercus maxima'.
# Synonyms returned: 3
# [{'name': 'Quercus rubra',
#   'author': 'L.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://midatlanticherbaria.org/portal/taxa/index.php?tid=46960'},
#  {'name': 'Quercus borealis',
#   'author': 'Michx. f.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://midatlanticherbaria.org/portal/taxa/index.php?taxon=46960'},
#  {'name': 'Quercus maxima',
#   'author': '(Marsh.) Ashe',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://midatlanticherbaria.org/portal/taxa/index.php?taxon=46960'}]
# ============================================================
#   symbiota / swbiodiversity
#   URL:       https://swbiodiversity.org/seinet
#   Species:   Larrea tridentata
#   Name type: accepted
# ============================================================
# [swbiodiversity] 'api/v2/taxonomy/search' returned no results for 'Larrea tridentata'.
# [swbiodiversity] 'api/v2/taxonomy' returned results for 'Larrea tridentata'.
# Synonyms returned: 2
# [{'name': 'Larrea tridentata',
#   'author': '(Sessé & Moc. ex DC.) Coville',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://swbiodiversity.org/seinet/taxa/index.php?tid=2671'},
#  {'name': 'Larrea mexicana',
#   'author': 'Moric.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://swbiodiversity.org/seinet/taxa/index.php?taxon=2671'}]
# ============================================================
#   symbiota / swbiodiversity
#   URL:       https://swbiodiversity.org/seinet
#   Species:   Larrea mexicana
#   Name type: synonym  (synonym of: Larrea tridentata)
# ============================================================
# [swbiodiversity] 'api/v2/taxonomy/search' returned no results for 'Larrea mexicana'.
# [swbiodiversity] 'api/v2/taxonomy' returned results for 'Larrea mexicana'.
# Synonyms returned: 2
# [{'name': 'Larrea tridentata',
#   'author': '(Sessé & Moc. ex DC.) Coville',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://swbiodiversity.org/seinet/taxa/index.php?tid=2671'},
#  {'name': 'Larrea mexicana',
#   'author': 'Moric.',
#   'publication_year': 'U',
#   'publication_name': 'U',
#   'api_link': 'https://swbiodiversity.org/seinet/taxa/index.php?taxon=2671'}]
