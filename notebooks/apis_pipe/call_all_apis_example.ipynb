# %% [markdown]
# # call_apis example
#
# Demonstrates calling `call_apis` with a query and a list of sources, then displaying the resulting DataFrame.

# %%
import pandas as pd

from scripts.utils.call_apis_pipe import call_apis

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

query = "Amanita muscaria"
sources = ["GBIF", "COL", "MyCoPortal"]

df = call_apis(query, sources)
df
# Out:
# [MyCoPortal] 'api/v2/taxonomy/search' returned results for 'Amanita muscaria'.
#       api_name kingdom phylum class family subfamily        genus  \
# 0         GBIF       U      U     U      U         U      Amanita
# 1         GBIF       U      U     U      U         U     Agaricus
# 2         GBIF       U      U     U      U         U     Agaricus
# 3         GBIF       U      U     U      U         U     Agaricus
# 4         GBIF       U      U     U      U         U     Agaricus
# 5         GBIF       U      U     U      U         U     Agaricus
# 6         GBIF       U      U     U      U         U     Agaricus
# 7         GBIF       U      U     U      U         U      Amanita
# 8         GBIF       U      U     U      U         U      Amanita
# 9         GBIF       U      U     U      U         U      Amanita
# 10        GBIF       U      U     U      U         U      Amanita
# 11        GBIF       U      U     U      U         U      Amanita
# ...
