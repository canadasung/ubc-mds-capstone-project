# %% [markdown]
# # Call APIs Example
#
# A quick way to see the table results of a query with one or more portals.
#
# Edit the `query` and `sources` variables in the cell below to query different species names or select different portals, then run the cell to see the results. Make sure the sources list only includes the following available sources.

# %%
from scripts.utils.call_apis_pipe import call_apis, _PORTAL_REGISTRY

# All available portal names that can be passed to `sources`
list(_PORTAL_REGISTRY.keys())

# %%
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# --- Adjust these to test different queries and sources ---

# The scientific name to search for
query = "Amanita muscaria"

# List of portal display names to query (see cell above for all options)
sources = ["GBIF", "COL", "MyCoPortal"]

# ---------------------------------------------------------

df = call_apis(query, sources)
df
